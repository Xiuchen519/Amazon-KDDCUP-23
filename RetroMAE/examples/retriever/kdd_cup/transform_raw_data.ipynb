# %%
import os
import numpy as np
import pandas as pd
from functools import lru_cache
import json
from tqdm import tqdm 
from numba import jit

# %%
data_for_recstudio  = '/root/autodl-tmp/xiaolong/WorkSpace/Amazon-KDDCUP-23/data_for_recstudio'
raw_data_dir = '/root/autodl-tmp/xiaolong/WorkSpace/Amazon-KDDCUP-23/raw_data'

# %%
@lru_cache(maxsize=1)
def read_product_data():
    return pd.read_csv(os.path.join(raw_data_dir, f'products_train.csv'))

@lru_cache(maxsize=1)
def read_train_data():
    return pd.read_csv(os.path.join(data_for_recstudio, 'all_task_1_train_sessions.csv'))

@lru_cache(maxsize=1)
def read_valid_data():
    return pd.read_csv(os.path.join(data_for_recstudio, 'all_task_1_valid_sessions.csv'))

@lru_cache(maxsize=3)
def read_test_data(task):
    return pd.read_csv(os.path.join(raw_data_dir, f'sessions_test_{task}.csv'))

@lru_cache(maxsize=3)
def read_test1_data(locale):
    return pd.read_csv(os.path.join(data_for_recstudio, f'session_test_task1_{locale}.csv'))

# %%
product_data = read_product_data()
train_sessions = read_train_data()
valid_sessions = read_valid_data()
test1_UK_data = read_test1_data('UK')

# %%
# title fill nan 
product_data['title'] = product_data['title'].fillna("")

# %%
product_map_id = {}
reindex_product_data = product_data.set_index(product_data['id'] + '_' + product_data['locale'])
for i in tqdm(range(len(reindex_product_data))):
    product_map_id[reindex_product_data.index[i]] = i
product_map_id
# Out:
# 100%|██████████| 1551057/1551057 [00:03<00:00, 465666.67it/s]
# {'B005ZSSN10_DE': 0,
#  'B08PRYN6LD_DE': 1,
#  'B09MBZJ48V_DE': 2,
#  'B08ZN6F26S_DE': 3,
#  'B094DGRV7D_DE': 4,
#  'B09JNNBDH5_DE': 5,
#  'B08R62WZ1Y_DE': 6,
#  'B09WK4YNX8_DE': 7,
#  'B07KTKFYYS_DE': 8,
#  'B0B9MPKYJK_DE': 9,
#  'B0B5RMZ9FQ_DE': 10,
#  'B000LXWTUU_DE': 11,
#  'B06XKPB3GT_DE': 12,
#  'B07Q3471S2_DE': 13,
#  'B0BG4V5PBQ_DE': 14,
#  'B094V3614V_DE': 15,
#  'B07K27BTM8_DE': 16,
#  'B078RFH53S_DE': 17,
#  'B08K8MHZ4N_DE': 18,
#  'B087JPRYFZ_DE': 19,
#  'B00V5BR1RS_DE': 20,
#  'B07K15DDKQ_DE': 21,
#  'B0B3JRWV4S_DE': 22,
#  'B084GYK4B9_DE': 23,
#  'B08BR2NLTN_DE': 24,
#  'B096B95D9Y_DE': 25,
#  'B07J65G9DD_DE': 26,
#  'B07XPFNBHW_DE': 27,
#  'B0868TBNZZ_DE': 28,
#  'B000S1KWPE_DE': 29,
#  'B0916LVFGG_DE': 30,
#  'B087BKQ98X_DE': 31,
#  'B01MREMJ90_DE': 32,
#  'B09QMCVW6P_DE': 33,
#  'B09JCC7FVK_DE': 34,
#  'B00IK6I6YS_DE': 35,
#  'B00V07XW3E_DE': 36,
#  'B07PNR4KM2_DE': 37,
#  'B0B8YBSMJ1_DE': 38,
#  'B06XTTLZ1B_DE': 39,
#  'B0009585PI_DE': 40,
#  '3954531038_DE': 41,
#  'B09TV4BNB9_DE': 42,
#  'B09TLCZ14D_DE': 43,
#  'B075TL67K8_DE': 44,
#  'B07NWCJZWV_DE': 45,
#  'B07DM8V3KS_DE': 46,
#  'B09WK5NBZ1_DE': 47,
#  'B09L85HNCT_DE': 48,
#  'B002RAWQ3K_DE': 49,
#  'B0BGHXC7CL_DE': 50,
#  'B07Y25MGQL_DE': 51,
#  'B01L7456JW_DE': 52,
#  'B07QBL9HYF_DE': 53,
#  'B0B59DRXBT_DE': 54,
#  'B07ZH9JTM4_DE': 55,
#  'B08JQL5F31_DE': 56,
#  'B08ZNQD1NL_DE': 57,
#  'B07QCQK6CV_DE': 58,
#  'B00VW4SYQ0_DE': 59,
#  'B0BD7145W7_DE': 60,
#  'B0B5DDKVPD_DE': 61,
#  'B0744DTMHH_DE': 62,
#  'B09LYVGMJV_DE': 63,
#  'B0953TN3KH_DE': 64,
#  'B09J13MPFJ_DE': 65,
#  'B08VGQG3VP_DE': 66,
#  'B07CKPD4RP_DE': 67,
#  'B099RB4X99_DE': 68,
#  'B08JVGH7RN_DE': 69,
#  'B08BPH1WMD_DE': 70,
#  'B09D89LNLV_DE': 71,
#  'B08DKHWNVH_DE': 72,
#  'B07ZHZPXZ7_DE': 73,
#  'B09YRG6FPR_DE': 74,
#  'B07SJ6SMXH_DE': 75,
#  'B0B2KKWHKF_DE': 76,
#  'B01MXIDQOS_DE': 77,
#  'B0B772VMPH_DE': 78,
#  'B0B8VXQFRL_DE': 79,
#  'B07RF96S2K_DE': 80,
#  'B01NBLDOJN_DE': 81,
#  'B08PW1VS3R_DE': 82,
#  'B08H21WG6P_DE': 83,
#  'B0B4QQTGTR_DE': 84,
#  'B0881P6YFK_DE': 85,
#  'B00IK6JWZK_DE': 86,
#  'B0834WLBBF_DE': 87,
#  'B0B3LS7QJQ_DE': 88,
#  'B005IQ2ARM_DE': 89,
#  'B0B6VGP3X9_DE': 90,
#  'B08B85T2J4_DE': 91,
#  'B0B4X29L7T_DE': 92,
#  'B076G629HF_DE': 93,
#  'B093GH3HK6_DE': 94,
#  'B07668GJP6_DE': 95,
#  'B08B3GX3ZJ_DE': 96,
#  'B07XG8JP9L_DE': 97,
#  'B079QB6LCR_DE': 98,
#  'B0BHWPR939_DE': 99,
#  'B0BG2WKWWV_DE': 100,
#  'B09V1G76T1_DE': 101,
#  'B0971M2F8R_DE': 102,
#  'B09G2HSPY9_DE': 103,
#  'B08944LJHT_DE': 104,
#  'B09YR3MWCK_DE': 105,
#  'B08ND18XT6_DE': 106,
#  'B09NZBDB7Y_DE': 107,
#  'B08L56S5BF_DE': 108,
#  'B09T76TBS7_DE': 109,
#  'B08M63GCY5_DE': 110,
#  'B08ML31GMS_DE': 111,
#  'B09WKCHZ31_DE': 112,
#  'B07YZF6Z33_DE': 113,
#  'B093V64P7V_DE': 114,
#  'B08LK197RM_DE': 115,
#  'B06X6MZ3KP_DE': 116,
#  'B09NY742DK_DE': 117,
#  'B097P1HRPW_DE': 118,
#  'B08QS4TNDR_DE': 119,
#  'B07G19G4GL_DE': 120,
#  'B07MH5T4NK_DE': 121,
#  'B07WWJ4J3L_DE': 122,
#  'B0B5CY5T87_DE': 123,
#  'B08L2DHYPH_DE': 124,
#  'B09BF18ZBT_DE': 125,
#  '3840189624_DE': 126,
#  'B09FG6W73L_DE': 127,
#  'B0B3D7FKZY_DE': 128,
#  'B0015ZCGL0_DE': 129,
#  'B0BJW49PK8_DE': 130,
#  'B08KY3VZ3J_DE': 131,
#  'B07Q8QZ1ZF_DE': 132,
#  'B08R8HX27D_DE': 133,
#  'B0B587ZBKT_DE': 134,
#  'B000FNIOG4_DE': 135,
#  'B07HX679CQ_DE': 136,
#  'B01N5RES79_DE': 137,
#  'B082YNW3WH_DE': 138,
#  '3840191963_DE': 139,
#  'B01MZ6FPV0_DE': 140,
#  'B082BHJGZM_DE': 141,
#  'B09YVCLL1G_DE': 142,
#  'B08P7S7SF8_DE': 143,
#  'B07JYQ23M1_DE': 144,
#  'B012I6GBX8_DE': 145,
#  'B09BTSDSJ5_DE': 146,
#  'B08K79CSJB_DE': 147,
#  'B0BC12J8YG_DE': 148,
#  'B08NX1XTJF_DE': 149,
#  'B0BGJ7PJC4_DE': 150,
#  'B08ZFT5TGN_DE': 151,
#  'B002SA4QPU_DE': 152,
#  'B07XY7PRJM_DE': 153,
#  'B007HM2728_DE': 154,
#  'B07MW4W18M_DE': 155,
#  'B07JM13T83_DE': 156,
#  'B000BC7QMM_DE': 157,
#  'B099QY8MS8_DE': 158,
#  'B08F2PGZ3B_DE': 159,
#  'B006H1MO2I_DE': 160,
#  'B08GCTL9ZK_DE': 161,
#  'B00XCAF69A_DE': 162,
#  'B08LV76DP8_DE': 163,
#  'B009TLAQ3M_DE': 164,
#  'B0BGXNCNNK_DE': 165,
#  'B0BB2G1NPL_DE': 166,
#  'B08ZHNNDLB_DE': 167,
#  'B09VXVFTHG_DE': 168,
#  'B09X1WGLYL_DE': 169,
#  'B01LTHZ8IG_DE': 170,
#  'B008UQ8JWC_DE': 171,
#  'B081D9G31W_DE': 172,
#  'B09X48GLFM_DE': 173,
#  'B000PHCQEG_DE': 174,
#  'B07DKCRMNF_DE': 175,
#  'B07SSLZJY4_DE': 176,
#  'B09WPB1BJG_DE': 177,
#  'B08ZMY5X2Y_DE': 178,
#  'B00LW3FEAK_DE': 179,
#  'B07HXMXHCV_DE': 180,
#  'B09MD6BLQ5_DE': 181,
#  'B0BFDHR9NS_DE': 182,
#  'B0B1TC5SYZ_DE': 183,
#  'B09XQ2CX1L_DE': 184,
#  'B08YS3ZX9C_DE': 185,
#  'B0B9G8SX77_DE': 186,
#  'B076KQ1693_DE': 187,
#  'B072LB3XHK_DE': 188,
#  'B09D3YGGGT_DE': 189,
#  'B087QHQF2Q_DE': 190,
#  'B09VBWMKPV_DE': 191,
#  'B07XDXMPNC_DE': 192,
#  'B07G31T52J_DE': 193,
#  'B09G3F43GB_DE': 194,
#  'B07WQ2144X_DE': 195,
#  'B0792HD8W3_DE': 196,
#  'B09VYNZS1G_DE': 197,
#  'B004C2MWVW_DE': 198,
#  'B01DQ9AAL0_DE': 199,
#  'B07XJQZKL2_DE': 200,
#  'B0B5H4LVZH_DE': 201,
#  'B08GM3X7W4_DE': 202,
#  'B07YDMD24H_DE': 203,
#  'B09F18QWQT_DE': 204,
#  'B07RZTNTD5_DE': 205,
#  'B0B4BJD816_DE': 206,
#  'B084KX6QCJ_DE': 207,
#  'B095YVT53M_DE': 208,
#  'B081B3N476_DE': 209,
#  'B09HZDBR6F_DE': 210,
#  'B07JK2NJD8_DE': 211,
#  'B07MBWCZ2K_DE': 212,
#  'B09C3RQKS5_DE': 213,
#  'B092D6P7XM_DE': 214,
#  'B01M10T4BK_DE': 215,
#  'B08JPCYM1C_DE': 216,
#  'B01N26SQ87_DE': 217,
#  'B01MU6O42P_DE': 218,
#  'B005HIMQPW_DE': 219,
#  'B09QD42ZX7_DE': 220,
#  'B07GNMV7GP_DE': 221,
#  'B08QW5S6N6_DE': 222,
#  'B0BLD48MMS_DE': 223,
#  'B01N5TKXP3_DE': 224,
#  'B00BFS9MQO_DE': 225,
#  'B0B6C8GK7X_DE': 226,
#  'B00IM1EGNG_DE': 227,
#  'B09W16PSQL_DE': 228,
#  'B08Z897L2Q_DE': 229,
#  'B00KYLFMK8_DE': 230,
#  'B097XKW2ST_DE': 231,
#  'B086Q2PLW6_DE': 232,
#  'B01MDQ8FBZ_DE': 233,
#  'B07H2BKYQV_DE': 234,
#  'B09879W97H_DE': 235,
#  'B085TGD13G_DE': 236,
#  'B01N3V832S_DE': 237,
#  'B096Y3NT67_DE': 238,
#  'B07XR9N7QD_DE': 239,
#  'B09C1QT67D_DE': 240,
#  'B09B2ZGL8K_DE': 241,
#  'B09NKJFPFZ_DE': 242,
#  'B0B6PH962S_DE': 243,
#  'B09DKMWK68_DE': 244,
#  'B01EQFHYEY_DE': 245,
#  'B0895QDL2H_DE': 246,
#  'B096ZVBH6B_DE': 247,
#  'B09Z664FNS_DE': 248,
#  'B07YK8R1D1_DE': 249,
#  'B09N6JFPRB_DE': 250,
#  'B09B2JQSQM_DE': 251,
#  'B08XM8R3DG_DE': 252,
#  'B00CL8F8D8_DE': 253,
#  'B00KKGDJ4S_DE': 254,
#  'B0BKGQ7SHZ_DE': 255,
#  'B07XJPW75V_DE': 256,
#  'B08DJ325B1_DE': 257,
#  'B082WGLJ6F_DE': 258,
#  'B0776F41F9_DE': 259,
#  'B0002HVOVK_DE': 260,
#  'B089K7V3CF_DE': 261,
#  'B085VSBVKW_DE': 262,
#  'B003MVH17Y_DE': 263,
#  'B0B9TPF8D4_DE': 264,
#  'B09PDH7LLC_DE': 265,
#  'B0BKD671BZ_DE': 266,
#  'B07P9JWBBH_DE': 267,
#  'B0B5LHW9TD_DE': 268,
#  'B07JN12LFD_DE': 269,
#  'B002ORJHZ6_DE': 270,
#  'B09QPKS6B1_DE': 271,
#  'B0B7N11N8L_DE': 272,
#  'B07Y8D7HZ7_DE': 273,
#  'B079WXY12Y_DE': 274,
#  'B0BLHRNMTV_DE': 275,
#  'B0752MLDLH_DE': 276,
#  'B093L5QTW6_DE': 277,
#  'B08SC3SMVF_DE': 278,
#  'B09K34Z12C_DE': 279,
#  'B097GWXS5T_DE': 280,
#  'B09Q32MR27_DE': 281,
#  'B0849T2769_DE': 282,
#  'B09R6C74J9_DE': 283,
#  'B097NCP81Z_DE': 284,
#  'B003S5QVH0_DE': 285,
#  'B006FGZQ2A_DE': 286,
#  'B08C636KBK_DE': 287,
#  'B08BYLMK7C_DE': 288,
#  'B09SFR6L8B_DE': 289,
#  'B0013BE8QC_DE': 290,
#  'B09BNXSV1L_DE': 291,
#  'B07SFJH786_DE': 292,
#  'B0182F0MXE_DE': 293,
#  'B07VGG5N2V_DE': 294,
#  'B07NDH2XXG_DE': 295,
#  'B08VRFV94T_DE': 296,
#  'B08NSHKRVH_DE': 297,
#  'B07NNQTKJT_DE': 298,
#  'B0BFB3V153_DE': 299,
#  'B09B12M8R4_DE': 300,
#  'B0BGB7RWKC_DE': 301,
#  'B099KL4H7L_DE': 302,
#  'B09VH27DJ4_DE': 303,
#  'B09ZVJW24W_DE': 304,
#  'B093QHH6Y8_DE': 305,
#  'B0848ML4XC_DE': 306,
#  'B07GQ3LBM4_DE': 307,
#  'B00VYM5I9G_DE': 308,
#  'B004ROTFSS_DE': 309,
#  'B07YYNM8NQ_DE': 310,
#  'B08LD9NHHX_DE': 311,
#  'B00BK0DE1Q_DE': 312,
#  'B09XLD3Y1G_DE': 313,
#  'B083DF3734_DE': 314,
#  'B07W5P7D9L_DE': 315,
#  'B098K55CJR_DE': 316,
#  'B07JWJBSR9_DE': 317,
#  'B09WCF89G6_DE': 318,
#  'B01MCRYLIF_DE': 319,
#  'B08X2Q1J1C_DE': 320,
#  'B08R5PXBL8_DE': 321,
#  'B08J45KT6B_DE': 322,
#  'B07JQ3XMTB_DE': 323,
#  'B01LNNCI3O_DE': 324,
#  'B071214BFC_DE': 325,
#  'B004WO6GPI_DE': 326,
#  'B08MT74LX8_DE': 327,
#  'B0B3RPSBVR_DE': 328,
#  'B09NCBGS7R_DE': 329,
#  'B083S87PZT_DE': 330,
#  'B09N8JNLPJ_DE': 331,
#  'B0B7Q9X9JX_DE': 332,
#  'B07NDNJSVF_DE': 333,
#  'B08Q814Q95_DE': 334,
#  'B07B3ZMY6Q_DE': 335,
#  'B07GCF9TQC_DE': 336,
#  'B07KGG49MB_DE': 337,
#  'B0B9X84G7P_DE': 338,
#  'B0B1JDCVYG_DE': 339,
#  'B09DD3436N_DE': 340,
#  'B01LZ8WBVF_DE': 341,
#  'B0BBZDT79C_DE': 342,
#  'B071GP976C_DE': 343,
#  'B0777QVMHH_DE': 344,
#  'B085J193FC_DE': 345,
#  'B0084D3RK0_DE': 346,
#  'B07VHNBWYV_DE': 347,
#  'B08M8YV77N_DE': 348,
#  'B07WMQ62FN_DE': 349,
#  'B075NCSGCT_DE': 350,
#  '3881002138_DE': 351,
#  'B000KJK9JI_DE': 352,
#  'B000WL3R5M_DE': 353,
#  'B0989S9Q64_DE': 354,
#  'B09FN2JXDN_DE': 355,
#  'B089H1CMLH_DE': 356,
#  'B01M0SH124_DE': 357,
#  'B09MV39LTC_DE': 358,
#  'B0796RZ2NX_DE': 359,
#  'B07QBYBWY2_DE': 360,
#  'B09GJYNHBZ_DE': 361,
#  'B07DSVGQGZ_DE': 362,
#  'B0B4RTDDN4_DE': 363,
#  'B09Z7K43JH_DE': 364,
#  'B0B1H1YPG1_DE': 365,
#  '3958186416_DE': 366,
#  'B0BGHLDLKW_DE': 367,
#  'B09Q69LMC1_DE': 368,
#  'B07VKBXHTZ_DE': 369,
#  'B07DTBZGWZ_DE': 370,
#  'B07WR7W59J_DE': 371,
#  'B088RBT4C7_DE': 372,
#  'B0B392TXXS_DE': 373,
#  'B0B7K4KP2W_DE': 374,
#  'B09HQZ34NS_DE': 375,
#  'B097M3TVBY_DE': 376,
#  'B006R58KYK_DE': 377,
#  'B07H29LJZ9_DE': 378,
#  'B07TGTP1KJ_DE': 379,
#  'B01FXIP6K2_DE': 380,
#  'B01MZ8SDGW_DE': 381,
#  '3788639695_DE': 382,
#  'B0B6ZWCKZS_DE': 383,
#  'B00HYZ493I_DE': 384,
#  'B081B7QRQB_DE': 385,
#  'B096LB5V9N_DE': 386,
#  'B07TW8KX3G_DE': 387,
#  'B00IE5RT0M_DE': 388,
#  'B08X6DX7F4_DE': 389,
#  'B08ZD84ZB8_DE': 390,
#  'B07FWTQP27_DE': 391,
#  'B0B24V3TP7_DE': 392,
#  'B006YVOOD8_DE': 393,
#  'B098QF2KLQ_DE': 394,
#  'B0029N3OTU_DE': 395,
#  'B07SS2WVWS_DE': 396,
#  '3548066011_DE': 397,
#  'B089GGV8CQ_DE': 398,
#  'B09T4TNSRF_DE': 399,
#  'B096MK1QPW_DE': 400,
#  'B086WJ87FF_DE': 401,
#  'B08VQFSPGL_DE': 402,
#  'B000KT7E0U_DE': 403,
#  'B08N8WV32Q_DE': 404,
#  'B00DO0CJLG_DE': 405,
#  'B09JGHGKTX_DE': 406,
#  'B07CM3DTSR_DE': 407,
#  'B0B56LR3N7_DE': 408,
#  'B08CV3N1D3_DE': 409,
#  'B09B8NQWLF_DE': 410,
#  'B002KLSL9E_DE': 411,
#  '3423262850_DE': 412,
#  'B086V8ZCCW_DE': 413,
#  'B099ZWZKVY_DE': 414,
#  'B07L9932K1_DE': 415,
#  'B01GQ26R48_DE': 416,
#  '3407799020_DE': 417,
#  'B0B7BLJ2MT_DE': 418,
#  'B00VB15GC4_DE': 419,
#  'B008OYL3G4_DE': 420,
#  'B08SKYVRT8_DE': 421,
#  'B09J2HD7QG_DE': 422,
#  'B09WR4DLD1_DE': 423,
#  'B08XM9KFGT_DE': 424,
#  'B06XKRJC28_DE': 425,
#  'B0B6G8D1GX_DE': 426,
#  'B07SBJ82HJ_DE': 427,
#  'B0BC28KNN8_DE': 428,
#  'B09ZZ7Z8LG_DE': 429,
#  'B00J5MD8HQ_DE': 430,
#  'B07PN3956C_DE': 431,
#  'B01IPGI05W_DE': 432,
#  'B099KGHWCP_DE': 433,
#  'B008BFOD4A_DE': 434,
#  'B07PMTKXBG_DE': 435,
#  'B09Q5GZQYY_DE': 436,
#  'B09GYWR3DH_DE': 437,
#  'B07FP3D43K_DE': 438,
#  'B088LT37JX_DE': 439,
#  'B09N3T8CF5_DE': 440,
#  'B076KY7GWD_DE': 441,
#  'B078MSQR47_DE': 442,
#  'B08PZ47MX5_DE': 443,
#  'B0751DBV82_DE': 444,
#  '3453292472_DE': 445,
#  'B094C1GFFH_DE': 446,
#  'B09D2T7V9H_DE': 447,
#  'B09GLLYV1D_DE': 448,
#  'B095J1NBQV_DE': 449,
#  'B0BD4NH8GT_DE': 450,
#  'B09QT2GLS3_DE': 451,
#  'B093ZVM4DZ_DE': 452,
#  'B07MXVF67Z_DE': 453,
#  'B07Y4D7NVJ_DE': 454,
#  'B07YT4CDWL_DE': 455,
#  'B07JQ133W7_DE': 456,
#  'B09VGVYJ1D_DE': 457,
#  'B07HYC4TSF_DE': 458,
#  'B07HKC8KZP_DE': 459,
#  '386453223X_DE': 460,
#  'B0989M7NB7_DE': 461,
#  'B08L7Z5GD1_DE': 462,
#  'B09W5QY7XT_DE': 463,
#  'B0811LR79T_DE': 464,
#  'B08NDB5NWP_DE': 465,
#  'B0B8SPSJMF_DE': 466,
#  'B0BHSLXJGS_DE': 467,
#  'B095W4DXVZ_DE': 468,
#  'B09VGMDQBM_DE': 469,
#  'B0B518JZM9_DE': 470,
#  'B0BD29H45V_DE': 471,
#  'B0895TVW6R_DE': 472,
#  'B07NPNY89H_DE': 473,
#  'B09S67JPCR_DE': 474,
#  'B076MFRXND_DE': 475,
#  'B09BCJMG6X_DE': 476,
#  'B075QKYDVZ_DE': 477,
#  'B099KFD7W3_DE': 478,
#  'B07X2XQ8JB_DE': 479,
#  'B00E5A8QZC_DE': 480,
#  'B0792H4HFL_DE': 481,
#  'B0B2R5Z4S8_DE': 482,
#  'B0946RRSJ3_DE': 483,
#  'B002RXHW6S_DE': 484,
#  'B08Z372JZD_DE': 485,
#  'B099DSTRRL_DE': 486,
#  'B07RYLDRQT_DE': 487,
#  'B07Y54J14F_DE': 488,
#  'B09MFBTPDV_DE': 489,
#  'B07YQW4XK6_DE': 490,
#  'B07KVCNH1W_DE': 491,
#  'B003ZULCE0_DE': 492,
#  'B07H5LGG5W_DE': 493,
#  'B08L9HFRR8_DE': 494,
#  'B08D3G5YQG_DE': 495,
#  'B09J2976L5_DE': 496,
#  'B00Q4P21ZC_DE': 497,
#  'B005TTYWYM_DE': 498,
#  'B0BBQZ7GJS_DE': 499,
#  'B00O8OC3B8_DE': 500,
#  'B09VMMJXF9_DE': 501,
#  'B08P3VBRZ8_DE': 502,
#  'B094NMSZQV_DE': 503,
#  'B08K7NYKVH_DE': 504,
#  'B00V3JR5EQ_DE': 505,
#  'B0788D51SJ_DE': 506,
#  'B096ZMQLQG_DE': 507,
#  'B08CX878FX_DE': 508,
#  'B09N97S13W_DE': 509,
#  'B07N8TRYDZ_DE': 510,
#  'B0B1HY26XJ_DE': 511,
#  'B0977KMPY7_DE': 512,
#  'B0B2TLJQGD_DE': 513,
#  'B09NNGWFC8_DE': 514,
#  'B09YQZP7Q1_DE': 515,
#  'B0797PPTTP_DE': 516,
#  'B001EA54GA_DE': 517,
#  'B09MB5JQJT_DE': 518,
#  'B000VP8GVE_DE': 519,
#  'B0B7QZ2WWT_DE': 520,
#  'B07CNCNL39_DE': 521,
#  'B096B31PS4_DE': 522,
#  'B07T2BP94Y_DE': 523,
#  'B07B3XM695_DE': 524,
#  'B06WP6YRKS_DE': 525,
#  'B076VDWDZ2_DE': 526,
#  'B07TFBS4RS_DE': 527,
#  'B08MKSD56C_DE': 528,
#  'B09L3HMLLP_DE': 529,
#  'B09B7QVZB7_DE': 530,
#  'B07G8MT1C9_DE': 531,
#  'B00140OT0W_DE': 532,
#  'B005ZKZEQA_DE': 533,
#  'B08HQ2PKSC_DE': 534,
#  'B09KTWXWFF_DE': 535,
#  'B0B4WSRZXG_DE': 536,
#  'B0012RW6E8_DE': 537,
#  'B0042SGDQG_DE': 538,
#  'B087G2KJ7B_DE': 539,
#  '3625180863_DE': 540,
#  'B07FR2GNNX_DE': 541,
#  'B0886J2R3V_DE': 542,
#  'B089GZM46M_DE': 543,
#  'B096X6FJVM_DE': 544,
#  'B09KZX64D6_DE': 545,
#  'B08LGMSRHR_DE': 546,
#  'B08GKGYRNQ_DE': 547,
#  'B09BCS2X62_DE': 548,
#  'B09WQBKSNP_DE': 549,
#  'B00IGJQ5YM_DE': 550,
#  'B0B14NZ1LQ_DE': 551,
#  'B00J04P0UW_DE': 552,
#  'B001921TV2_DE': 553,
#  '3473385360_DE': 554,
#  'B08PHG6ZX4_DE': 555,
#  'B00EQZTUGU_DE': 556,
#  'B09KG582C9_DE': 557,
#  'B07PW4CFB7_DE': 558,
#  'B09ZQ1R1YQ_DE': 559,
#  'B09X7DB812_DE': 560,
#  'B075395GHZ_DE': 561,
#  'B07541LP5K_DE': 562,
#  'B0B81TB5SP_DE': 563,
#  'B08G4D3P1T_DE': 564,
#  'B07RP1ST1X_DE': 565,
#  'B087WZ53Y1_DE': 566,
#  'B07V6J4W7Q_DE': 567,
#  'B07PSSDGF4_DE': 568,
#  'B09RTLDQ63_DE': 569,
#  'B01KOFWW92_DE': 570,
#  'B085TRZ9QH_DE': 571,
#  '3480237851_DE': 572,
#  'B08Z8LQP5Q_DE': 573,
#  'B09GB7BCQH_DE': 574,
#  'B083LCPGQP_DE': 575,
#  'B09VGNBJJ8_DE': 576,
#  'B09V4NLQLK_DE': 577,
#  'B09ZCYBDMG_DE': 578,
#  'B08SG4C7Y4_DE': 579,
#  'B07DVY9BLN_DE': 580,
#  'B0816KZFDJ_DE': 581,
#  '3551187924_DE': 582,
#  'B07S1XBZ7B_DE': 583,
#  'B07C5QQ38Q_DE': 584,
#  '3881002995_DE': 585,
#  'B06XWJX6DS_DE': 586,
#  'B07CMN746Z_DE': 587,
#  'B08CY7HF5T_DE': 588,
#  'B08PNHCNNL_DE': 589,
#  'B07GYR3G47_DE': 590,
#  'B09SH1VTLJ_DE': 591,
#  'B07BDY15ZW_DE': 592,
#  'B07W9L27D4_DE': 593,
#  'B0B68HBW6D_DE': 594,
#  'B08ZMZSG9L_DE': 595,
#  'B0B9BX23SK_DE': 596,
#  'B09DSFH9YD_DE': 597,
#  'B09B8YPWZB_DE': 598,
#  'B0076MGACC_DE': 599,
#  'B07QZNP7R6_DE': 600,
#  'B08Y55Z1WD_DE': 601,
#  'B09YS69R2B_DE': 602,
#  'B09G6V3CGT_DE': 603,
#  'B092LSY1V4_DE': 604,
#  'B07MX6NK6J_DE': 605,
#  'B00EC6EV80_DE': 606,
#  'B08669LWNB_DE': 607,
#  'B009S71C0I_DE': 608,
#  'B00E67E4PA_DE': 609,
#  'B0B7XNJRSV_DE': 610,
#  'B07LFMJ9PY_DE': 611,
#  'B073FB96CW_DE': 612,
#  'B08NZ2N5PG_DE': 613,
#  'B07XLSQRNN_DE': 614,
#  'B0B5F5SD6V_DE': 615,
#  'B07Z4YL8H9_DE': 616,
#  'B07PV1863W_DE': 617,
#  'B08PFR5KVV_DE': 618,
#  'B079HZRJS3_DE': 619,
#  'B0BDLJNHDR_DE': 620,
#  'B07P5PTP32_DE': 621,
#  'B072L7HSBG_DE': 622,
#  'B0833WS8KZ_DE': 623,
#  'B073XLLTTP_DE': 624,
#  'B00004W482_DE': 625,
#  'B08L7NN3GK_DE': 626,
#  'B085LB5YP3_DE': 627,
#  'B07XHBP837_DE': 628,
#  'B07DGK3PYM_DE': 629,
#  'B08HRJV86P_DE': 630,
#  'B089SHHZ89_DE': 631,
#  'B0BFBJ6JB9_DE': 632,
#  'B091V12DT7_DE': 633,
#  'B0967DHL9N_DE': 634,
#  'B097H8F8BB_DE': 635,
#  'B004RGOB1C_DE': 636,
#  'B091PN8ZT7_DE': 637,
#  'B07X12H6ZX_DE': 638,
#  'B07F7TK43G_DE': 639,
#  'B0BGMJJCY8_DE': 640,
#  'B07D4RTX1F_DE': 641,
#  'B07XP7KH41_DE': 642,
#  'B07ZJFKWGC_DE': 643,
#  'B0865WT9VS_DE': 644,
#  'B01NA7VGAR_DE': 645,
#  'B097DLX4YW_DE': 646,
#  'B0BJVSSR1Y_DE': 647,
#  'B00A7R8MJC_DE': 648,
#  'B08YDK32KW_DE': 649,
#  'B0831MRFVB_DE': 650,
#  'B08FTK1RP3_DE': 651,
#  'B0BGQKBDNC_DE': 652,
#  'B09CGXZT6V_DE': 653,
#  'B086H5Q9CN_DE': 654,
#  'B004ORG6KI_DE': 655,
#  'B09HC1GT7B_DE': 656,
#  'B0946Z892Z_DE': 657,
#  'B098WYVP33_DE': 658,
#  '3742310763_DE': 659,
#  'B088RLHJPT_DE': 660,
#  'B09MHJZY7W_DE': 661,
#  'B0B7JFPCK8_DE': 662,
#  'B08T62M9HJ_DE': 663,
#  'B09MF5V6PV_DE': 664,
#  'B088KL8CMJ_DE': 665,
#  'B0B5F6HK18_DE': 666,
#  'B09ZLHSQC5_DE': 667,
#  'B095RQ4MDJ_DE': 668,
#  'B07PM54855_DE': 669,
#  'B08XYFJDN5_DE': 670,
#  'B017HAHZGM_DE': 671,
#  'B07BT9VT4Q_DE': 672,
#  'B09MB2KYN2_DE': 673,
#  'B01IHLW0CY_DE': 674,
#  'B0863BKJK6_DE': 675,
#  'B07926F64D_DE': 676,
#  'B089357LC4_DE': 677,
#  'B07HKQD7R2_DE': 678,
#  'B07ZJDJ18B_DE': 679,
#  'B0B65G8NMR_DE': 680,
#  'B07GRGPQ5R_DE': 681,
#  'B0BCPP1TWH_DE': 682,
#  'B07THV1JPN_DE': 683,
#  'B09KQ83BK5_DE': 684,
#  'B0B6VZW6YZ_DE': 685,
#  'B0798PVTQ6_DE': 686,
#  'B011BHJJTS_DE': 687,
#  'B09B7X3XKH_DE': 688,
#  'B0B2HXLHFN_DE': 689,
#  'B09PGKYNF4_DE': 690,
#  'B08G4F28S2_DE': 691,
#  'B09QDV5VFK_DE': 692,
#  'B0B1MY5HGK_DE': 693,
#  'B008LACDRO_DE': 694,
#  'B09X1XPLCG_DE': 695,
#  'B0748G4P9S_DE': 696,
#  'B0BB7Q3QN5_DE': 697,
#  'B0BFB21RTC_DE': 698,
#  'B0888S1D97_DE': 699,
#  'B08DPLKH9Q_DE': 700,
#  'B08BCSRB62_DE': 701,
#  'B09QFVY5CM_DE': 702,
#  'B073BPLS18_DE': 703,
#  'B08YNR9WPF_DE': 704,
#  'B08BJ4BL3T_DE': 705,
#  'B01MTSB95A_DE': 706,
#  'B09F9NGFYX_DE': 707,
#  'B07SPDSS83_DE': 708,
#  'B09J5HNK36_DE': 709,
#  'B009O8LSM8_DE': 710,
#  'B074L5Q51Y_DE': 711,
#  'B09X7G1KL7_DE': 712,
#  'B09L84Y737_DE': 713,
#  'B00JIL9C5G_DE': 714,
#  'B088611MW8_DE': 715,
#  'B09GYCV1CS_DE': 716,
#  'B09PTSTQW8_DE': 717,
#  'B0818J4JG2_DE': 718,
#  'B09J2R4QYR_DE': 719,
#  'B096J39VQW_DE': 720,
#  'B07289Y76K_DE': 721,
#  'B01BWP9WHI_DE': 722,
#  'B07SZMYMMN_DE': 723,
#  'B09WMSLHYP_DE': 724,
#  'B09LY89DB2_DE': 725,
#  'B00HSO4S5Y_DE': 726,
#  'B00ZW9265G_DE': 727,
#  'B08D98GQH2_DE': 728,
#  'B07GTZMYFH_DE': 729,
#  'B08JCVWK56_DE': 730,
#  'B09HK3N29V_DE': 731,
#  'B08YNMTV9H_DE': 732,
#  'B09RKKN8WF_DE': 733,
#  'B0B38VVT4R_DE': 734,
#  'B07WHTBGVV_DE': 735,
#  'B0BCGJLHKS_DE': 736,
#  'B0BFC9YMM5_DE': 737,
#  'B0B1B67RZT_DE': 738,
#  'B086X6SWFS_DE': 739,
#  'B07T7PDQYJ_DE': 740,
#  '342371820X_DE': 741,
#  'B09FKC834P_DE': 742,
#  'B000W4NTKC_DE': 743,
#  'B0BCJNLVQH_DE': 744,
#  'B00A6M3I9W_DE': 745,
#  'B08KVVNCDB_DE': 746,
#  'B08GD4C8TQ_DE': 747,
#  'B07NC8PWDM_DE': 748,
#  'B09YRHGC4D_DE': 749,
#  'B07ZCXW74Y_DE': 750,
#  'B07M9TNCDT_DE': 751,
#  'B08NDM6NCP_DE': 752,
#  'B0035T3POG_DE': 753,
#  'B08KGQF8FT_DE': 754,
#  'B097TC5JS8_DE': 755,
#  'B0B8YDJRV6_DE': 756,
#  'B0855TGPKD_DE': 757,
#  'B07YQ8TGVH_DE': 758,
#  'B00ILHAZNQ_DE': 759,
#  'B07B4WJ7KV_DE': 760,
#  'B07YXTQ86D_DE': 761,
#  'B07282GZZT_DE': 762,
#  'B006DAHSF6_DE': 763,
#  'B00IN58R68_DE': 764,
#  'B08PQS432L_DE': 765,
#  'B077RQ6GN6_DE': 766,
#  'B09GV1MGJF_DE': 767,
#  'B0852PLG4W_DE': 768,
#  'B07N8YH1ZB_DE': 769,
#  'B09P8Z2QZX_DE': 770,
#  'B00BVOAOCI_DE': 771,
#  'B09FLCBY4X_DE': 772,
#  'B07VF5GMZ6_DE': 773,
#  'B074TGWFMN_DE': 774,
#  'B08BZ6C4DD_DE': 775,
#  'B09F3MJ3MK_DE': 776,
#  'B0038JDN8Q_DE': 777,
#  'B07DK93NGP_DE': 778,
#  'B0B34MFX43_DE': 779,
#  'B096ZLWPT8_DE': 780,
#  'B07G5R1SZ9_DE': 781,
#  'B094J7W5PD_DE': 782,
#  'B077HTWCT8_DE': 783,
#  'B07FN41SFX_DE': 784,
#  'B07JFG6HD3_DE': 785,
#  'B08RDDB94G_DE': 786,
#  'B0789BVVY6_DE': 787,
#  'B0983HV31S_DE': 788,
#  'B089KC34BV_DE': 789,
#  'B086BXBS73_DE': 790,
#  'B00HVSOS2A_DE': 791,
#  'B09QQ75NSX_DE': 792,
#  'B00DTQCN3O_DE': 793,
#  'B09BFLV76P_DE': 794,
#  'B08L3TB191_DE': 795,
#  'B08JJ7L5LH_DE': 796,
#  'B082X38LJK_DE': 797,
#  'B0823QG66F_DE': 798,
#  'B07C7NP48N_DE': 799,
#  'B09HZLPKHH_DE': 800,
#  'B09SLP9KGM_DE': 801,
#  'B07VCFWQ85_DE': 802,
#  'B0859B8NFG_DE': 803,
#  'B09VBRHV9G_DE': 804,
#  'B0BCDVK166_DE': 805,
#  'B07L9QNRCK_DE': 806,
#  'B0B7496N14_DE': 807,
#  'B0B9MM4QH2_DE': 808,
#  'B09RPRDWQV_DE': 809,
#  'B094TXDNHS_DE': 810,
#  'B08Z3QD8PB_DE': 811,
#  'B07HS4R7QQ_DE': 812,
#  'B08NCXT8GH_DE': 813,
#  'B099Z9RVY2_DE': 814,
#  'B09WJ3277P_DE': 815,
#  'B08W56MC2S_DE': 816,
#  'B08SZLBGH8_DE': 817,
#  'B07XG2C28T_DE': 818,
#  'B09HXJL9HT_DE': 819,
#  'B0BGGZ9G3Z_DE': 820,
#  'B01J3L95ZW_DE': 821,
#  'B07T3JZZX6_DE': 822,
#  'B09ZHWBKB5_DE': 823,
#  'B0BC95HHMR_DE': 824,
#  'B0B64VQ44P_DE': 825,
#  'B085Y254P9_DE': 826,
#  'B0002YQ3M8_DE': 827,
#  'B07JM3C1Z8_DE': 828,
#  'B09ZJ4BZ6P_DE': 829,
#  'B0B1C3K6TD_DE': 830,
#  'B095K8PG8H_DE': 831,
#  'B09929XH15_DE': 832,
#  'B08P6T7468_DE': 833,
#  'B082CWVM2M_DE': 834,
#  'B0B8837R43_DE': 835,
#  'B000P4MW5W_DE': 836,
#  'B0B8J5CBL4_DE': 837,
#  'B09JNQFDW1_DE': 838,
#  'B00IGTL08I_DE': 839,
#  'B09B7G1PZZ_DE': 840,
#  'B08HR4GQWY_DE': 841,
#  'B09Q2W3LS8_DE': 842,
#  'B07BRQ4TDF_DE': 843,
#  'B0B4TWRDGW_DE': 844,
#  'B07CNR57LL_DE': 845,
#  'B09NM7R9H1_DE': 846,
#  'B09MNXJJ3P_DE': 847,
#  'B0B1LTDZJ5_DE': 848,
#  'B082J4FCJP_DE': 849,
#  'B084PV5H46_DE': 850,
#  'B01HGMP9T6_DE': 851,
#  'B014PI4NZK_DE': 852,
#  'B017SA0MDY_DE': 853,
#  'B013SSGD24_DE': 854,
#  'B08Z3XBSRL_DE': 855,
#  'B09CDPCTTX_DE': 856,
#  'B09SFTDBWP_DE': 857,
#  'B00CRB0992_DE': 858,
#  '3442487455_DE': 859,
#  'B07LC44WKL_DE': 860,
#  'B07VMQHYPP_DE': 861,
#  'B000OZNJRM_DE': 862,
#  'B07SR4R8K1_DE': 863,
#  'B09P313YK9_DE': 864,
#  'B08T79X6RB_DE': 865,
#  'B0922ZDM4R_DE': 866,
#  'B09RG894VH_DE': 867,
#  'B07P7QN49X_DE': 868,
#  'B001B4WXI6_DE': 869,
#  'B01277RMNG_DE': 870,
#  'B01F1XDQ6A_DE': 871,
#  'B07N1QBZVS_DE': 872,
#  'B099DS2H5C_DE': 873,
#  'B08W1X4TM9_DE': 874,
#  'B09SG1F53R_DE': 875,
#  'B07GH3234V_DE': 876,
#  'B082G6JBB9_DE': 877,
#  'B09TNS2X24_DE': 878,
#  'B07XRSFBZ8_DE': 879,
#  'B01KFCZB2Y_DE': 880,
#  'B0883KFKVJ_DE': 881,
#  'B09FFHYQNY_DE': 882,
#  'B08GCCBV9V_DE': 883,
#  'B089HKJWBH_DE': 884,
#  'B0B2TT6JWX_DE': 885,
#  'B00A22BPFK_DE': 886,
#  'B0B5XCGHHH_DE': 887,
#  'B0B7R1DR9J_DE': 888,
#  'B0B5TGYT3F_DE': 889,
#  'B001IVVGUS_DE': 890,
#  'B06X3X8M8L_DE': 891,
#  'B017UG4HDC_DE': 892,
#  'B098JK24GC_DE': 893,
#  'B07DL1FVZM_DE': 894,
#  'B00JEXZ6NA_DE': 895,
#  'B00EVA5EII_DE': 896,
#  'B0BDMLKLPP_DE': 897,
#  'B09PTJNRYL_DE': 898,
#  'B07DRBSCGN_DE': 899,
#  'B092D7Y3DJ_DE': 900,
#  'B08DSHB9C1_DE': 901,
#  'B09Y8WJGQ7_DE': 902,
#  'B002TLLKW0_DE': 903,
#  'B09QCS1TS5_DE': 904,
#  'B01FJX6P5Q_DE': 905,
#  'B07ZRBCPN1_DE': 906,
#  'B075GQB7BK_DE': 907,
#  'B00EC6IFRI_DE': 908,
#  'B00TRYTE70_DE': 909,
#  'B00NBW3S1C_DE': 910,
#  'B08QVFBVR8_DE': 911,
#  'B0BB3K91GH_DE': 912,
#  'B07HH6ML2B_DE': 913,
#  'B08L6RVZB9_DE': 914,
#  'B071DZSCM3_DE': 915,
#  'B08DR8H4VK_DE': 916,
#  'B09P7KDMWB_DE': 917,
#  'B07PLGT1QL_DE': 918,
#  'B01KXUY5SY_DE': 919,
#  'B097H5C21W_DE': 920,
#  'B01IOE8P6O_DE': 921,
#  'B09DKZNJGT_DE': 922,
#  '3849929051_DE': 923,
#  'B09YRZZ1MD_DE': 924,
#  'B073ZJQLNR_DE': 925,
#  'B0B8F4485Z_DE': 926,
#  'B09ZWMS62L_DE': 927,
#  'B00YMPU5CC_DE': 928,
#  'B01N1V19KZ_DE': 929,
#  'B09TF5TDVB_DE': 930,
#  'B092S4W9HL_DE': 931,
#  'B08YNHB1SJ_DE': 932,
#  'B09S1FHXMS_DE': 933,
#  'B0B4347ZJC_DE': 934,
#  'B0B6ZTTFFP_DE': 935,
#  'B08NK6WP6L_DE': 936,
#  'B09LHC5SJC_DE': 937,
#  'B076J1KRVV_DE': 938,
#  'B000S5HZ0K_DE': 939,
#  'B0B87XSQNN_DE': 940,
#  'B07CJWLP3S_DE': 941,
#  'B06XG5Q7HY_DE': 942,
#  'B09FPLJNCS_DE': 943,
#  'B01KGW2B1W_DE': 944,
#  'B08RMQQZWT_DE': 945,
#  'B01L95ABR6_DE': 946,
#  'B06Y2W26ZK_DE': 947,
#  'B089QHFG3B_DE': 948,
#  'B01MG9GT3S_DE': 949,
#  'B074KGYJRD_DE': 950,
#  'B074N55XW2_DE': 951,
#  'B09LJ25V9Z_DE': 952,
#  'B096JK4V6L_DE': 953,
#  'B08T7J9GZC_DE': 954,
#  'B0BGPRR6L6_DE': 955,
#  '3838423224_DE': 956,
#  'B06XB273QX_DE': 957,
#  'B0925KGVV7_DE': 958,
#  'B081NNTF1P_DE': 959,
#  'B079Q423XK_DE': 960,
#  'B09JKZSZMT_DE': 961,
#  'B07SC1JS15_DE': 962,
#  'B0B3DX8SPY_DE': 963,
#  'B09H2QZHFC_DE': 964,
#  'B01N10ILNX_DE': 965,
#  '0786965622_DE': 966,
#  'B0B93F371V_DE': 967,
#  'B00WUAKR2E_DE': 968,
#  'B07CYWKZND_DE': 969,
#  'B007IDVRP4_DE': 970,
#  'B07B51YNGN_DE': 971,
#  'B07HRT94RH_DE': 972,
#  'B089GHDK49_DE': 973,
#  'B0012D4FZK_DE': 974,
#  'B08QRC78L7_DE': 975,
#  'B08KTP6517_DE': 976,
#  'B07M9WWRK7_DE': 977,
#  'B09QS66ZXG_DE': 978,
#  'B00H39W23Y_DE': 979,
#  'B07MR5MHX5_DE': 980,
#  'B098WTTW7G_DE': 981,
#  'B07NBX4KTX_DE': 982,
#  'B075V63YQ5_DE': 983,
#  'B00N340LMW_DE': 984,
#  'B00LKHSHIE_DE': 985,
#  'B08TC654B6_DE': 986,
#  'B01G062AD2_DE': 987,
#  'B00IG145L0_DE': 988,
#  'B01KHEYLP8_DE': 989,
#  'B01LW7Q1F6_DE': 990,
#  'B08RMTJTQM_DE': 991,
#  'B07X3FLB5C_DE': 992,
#  'B0B1J4D56Z_DE': 993,
#  'B07NGX4J48_DE': 994,
#  'B00G23Q1UW_DE': 995,
#  'B09B2JB5B4_DE': 996,
#  'B07XQK116Y_DE': 997,
#  'B01CHRFL8O_DE': 998,
#  'B07NNTSKZP_DE': 999,
#  ...}

# %%
# save as json 
# id_locale as new index
def save_corpus_as_json(corpus_path, map_id_path):
    with open(corpus_path, 'w', encoding='utf-8') as f, open(map_id_path, 'w', encoding='utf-8') as fid:
        for i in tqdm(range(len(product_data))):
            product = product_data.iloc[i]
            if pd.isna(product['title']):
                data = {'id' : f"{product['id']}_{product['locale']}", 'title' : " "}
            else:
                data = {'id' : f"{product['id']}_{product['locale']}", 'title' : product['title']}
            f.write(json.dumps(data) + '\n')
            fid.write(f"{product['id']}_{product['locale']}" + "\t" + str(i) + "\n")

def save_dev_corpus_as_json(corpus_path, map_id_path):
    with open(corpus_path, 'w', encoding='utf-8') as f, open(map_id_path, 'w', encoding='utf-8') as fid:
        for i in tqdm(range(500000, 1000000)):
            product = product_data.iloc[i]
            if pd.isna(product['title']):
                data = {'id' : f"{product['id']}_{product['locale']}", 'title' : " "}
            else:
                data = {'id' : f"{product['id']}_{product['locale']}", 'title' : product['title']}
            f.write(json.dumps(data) + '\n')
            fid.write(f"{product['id']}_{product['locale']}" + "\t" + str(i) + "\n")

# %%
# save query as json
def save_query_as_json(train_query_path, map_id_path, train_qrels_path, sess_len=5):
    with open(train_query_path, 'w', encoding='utf-8') as f, open(map_id_path, 'w', encoding='utf-8') as fid, \
        open(train_qrels_path, 'w', encoding='utf-8') as f_qrel:
        for i in tqdm(range(len(train_sessions))):
            sess = train_sessions.iloc[i]
            sess_locale = sess['locale']
            prev_items = sess['prev_items']
            next_item = sess['next_item']

            prev_items = eval(prev_items.replace(" ", ","))
            prev_items = prev_items[-sess_len:]
            prev_items = list(map(lambda x : x + "_"+ sess_locale, prev_items))
            # prev_items = list(map(lambda x : product_map_id[x], prev_items))
            prev_items_titles = reindex_product_data.loc[prev_items]['title'].to_list()

            # train query
            data = {'id' : str(i), 'title_list' : prev_items_titles}
            f.write(json.dumps(data) + '\n')
            fid.write(str(i) + "\t" + str(i) + "\n")

            # train qrel
            f_qrel.write(str(i) + "\t" + next_item + '_' + sess_locale + "\n")

def save_dev_query_as_json(train_query_path, map_id_path, train_qrels_path, sess_len=5):
    with open(train_query_path, 'w', encoding='utf-8') as f, open(map_id_path, 'w', encoding='utf-8') as fid, \
        open(train_qrels_path, 'w', encoding='utf-8') as f_qrel:
        for i in tqdm(range(50000)):
            sess = train_sessions.iloc[i]
            sess_locale = sess['locale']
            prev_items = sess['prev_items']
            next_item = sess['next_item']
            prev_items = eval(prev_items.replace(" ", ","))
            prev_items = prev_items[-sess_len:]
            prev_items = list(map(lambda x : x + "_"+ sess_locale, prev_items))
            prev_items_titles = reindex_product_data.loc[prev_items]['title'].to_list()

            # train query
            data = {'id' : str(i), 'title_list' : prev_items_titles}
            f.write(json.dumps(data) + '\n')
            fid.write(str(i) + "\t" + str(i) + "\n")

            # train qrel
            f_qrel.write(str(i) + "\t" + next_item + '_' + sess_locale + "\n")

# %%
if not os.path.exists('./data/corpus/'):
        os.makedirs('./data/corpus/')
save_corpus_as_json('./data/corpus.json', './data/corpus/mapping_id.txt')
# Out:
# 100%|██████████| 1551057/1551057 [02:21<00:00, 10968.55it/s]

# %%
if not os.path.exists('./data/corpus/'):
        os.makedirs('./data/corpus/')
save_dev_corpus_as_json('./data/dev_corpus.json', './data/corpus/dev_mapping_id.txt')
# Out:
# 100%|██████████| 500000/500000 [00:47<00:00, 10564.90it/s]

# %%
train_sessions.iloc[:10]
# Out:
#                                           prev_items   next_item locale
# 0           ['B005ZJTUXE' 'B005ZJTUXE' 'B00P8VIBBG']  B07TVSL9TW     FR
# 1  ['B09M8HSN22' 'B09MTKZNB2' 'B07XWK3G8K' 'B09H7...  B01J5EEEQW     DE
# 2  ['B088ZH3JF1' 'B003YCIEWC' 'B008U4NBE0' 'B073V...  B00TDNLSBU     DE
# 3           ['B01B4S990I' 'B07QJQCHRJ' 'B0723H7YMT']  B09T77G4B5     DE
# 4           ['B079D9HDHP' 'B01E0KS6JC' 'B079D9HDHP']  B079DDND7C     DE
# 5  ['B08456GQ8R' 'B08455SX6C' 'B084562Z83' 'B0845...  B08456DP3R     JP
# 6                        ['B07DRPH58X' 'B098TF21JM']  B098TG1D3C     UK
# 7                        ['B07Q9ZTSJD' 'B00D8CXYXC']  B00D8CXXTC     UK
# 8  ['B09JFRT3KK' 'B09Q5KG4G7' 'B09QRZQ9DQ' 'B0BG2...  B09FQFM117     UK
# 9  ['B085ZGTQMQ' 'B00KL44ROA' 'B00KL44ROA' 'B06WD...  B009GX10XI     JP

# %%
if not os.path.exists('./data/BertTokenizer_data/train_query/'):
        os.makedirs('./data/BertTokenizer_data/train_query/')
save_query_as_json('./data/train_query.json', './data/BertTokenizer_data/train_query/mapping_id.txt', './data/BertTokenizer_data/train_qrel.txt')
# Out:
#  10%|▉         | 345393/3557898 [03:38<33:55, 1577.92it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[79], line 3
#       1 if not os.path.exists('./data/BertTokenizer_data/train_query/'):
#       2         os.makedirs('./data/BertTokenizer_data/train_query/')
# ----> 3 save_query_as_json('./data/train_query.json', './data/BertTokenizer_data/train_query/mapping_id.txt', './data/BertTokenizer_data/train_qrel.txt')
#
# Cell In[77], line 15, in save_query_as_json(train_query_path, map_id_path, train_qrels_path, sess_len)
#      13 prev_items = list(map(lambda x : x + "_"+ sess_locale, prev_items))
#      14 # prev_items = list(map(lambda x : product_map_id[x], prev_items))
# ---> 15 prev_items_titles = reindex_product_data.loc[prev_items]['title'].to_list()
#      17 # train query
#      18 data = {'id' : str(i), 'title_list' : prev_items_titles}
#
# File ~/.conda/envs/torch12/lib/python3.9/site-packages/pandas/core/indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/.conda/envs/torch12/lib/python3.9/site-packages/pandas/core/indexing.py:1301, in _LocIndexer._getitem_axis(self, key, axis)
#    1298     if hasattr(key, "ndim") and key.ndim > 1:
#    1299         raise ValueError("Cannot index with multidimensional key")
# -> 1301     return self._getitem_iterable(key, axis=axis)
#    1303 # nested tuple slicing
#    1304 if is_nested_tuple(key, labels):
#
# File ~/.conda/envs/torch12/lib/python3.9/site-packages/pandas/core/indexing.py:1239, in _LocIndexer._getitem_iterable(self, key, axis)
#    1236 self._validate_key(key, axis)
#    1238 # A collection of keys
# -> 1239 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1240 return self.obj._reindex_with_indexers(
#    1241     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1242 )
#
# File ~/.conda/envs/torch12/lib/python3.9/site-packages/pandas/core/indexing.py:1432, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1429 ax = self.obj._get_axis(axis)
#    1430 axis_name = self.obj._get_axis_name(axis)
# -> 1432 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1434 return keyarr, indexer
#
# File ~/.conda/envs/torch12/lib/python3.9/site-packages/pandas/core/indexes/base.py:6066, in Index._get_indexer_strict(self, key, axis_name)
#    6064 if self._index_as_unique:
#    6065     indexer = self.get_indexer_for(keyarr)
# -> 6066     keyarr = self.reindex(keyarr)[0]
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#
# File ~/.conda/envs/torch12/lib/python3.9/site-packages/pandas/core/indexes/base.py:4412, in Index.reindex(self, target, method, level, limit, tolerance)
#    4410 else:
#    4411     if self._index_as_unique:
# -> 4412         indexer = self.get_indexer(
#    4413             target, method=method, limit=limit, tolerance=tolerance
#    4414         )
#    4415     elif self._is_multi:
#    4416         raise ValueError("cannot handle a non-unique multi-index!")
#
# File ~/.conda/envs/torch12/lib/python3.9/site-packages/pandas/core/indexes/base.py:3906, in Index.get_indexer(self, target, method, limit, tolerance)
#    3903 if not self._index_as_unique:
#    3904     raise InvalidIndexError(self._requires_unique_msg)
# -> 3906 if len(target) == 0:
#    3907     return np.array([], dtype=np.intp)
#    3909 if not self._should_compare(target) and not self._should_partial_index(target):
#    3910     # IntervalIndex get special treatment bc numeric scalars can be
#    3911     #  matched to Interval scalars
#
# KeyboardInterrupt:

# %%
if not os.path.exists('./data/BertTokenizer_data/dev_query/'):
        os.makedirs('./data/BertTokenizer_data/dev_query/')
save_dev_query_as_json('./data/dev_query.json', './data/BertTokenizer_data/dev_query/dev_mapping_id.txt', './data/BertTokenizer_data/dev_qrel.txt')
# Out:
# 100%|██████████| 50000/50000 [02:24<00:00, 344.89it/s]

# %%
product_data.iloc[0]['title']
# Out:
# 'RED DRAGON Amberjack 3 - Steel Tip 22 Gramm Wolfram Profi Dartpfeile Set mit Flights und Schäfte'

# %%
valid_sessions = read_valid_data()

# %%
valid_sessions.head(5)
# Out:
#                                           prev_items   next_item locale
# 0  ['B09VSN9GLS' 'B09VSG9DCG' 'B0BJ5L1ZPH' 'B09VS...  B06XG1LZ6Z     UK
# 1           ['B00390YWXE' 'B00390YWXE' 'B09WM9W6WQ']  B01MSUI4FE     JP
# 2           ['B01BM9V6H8' 'B01MG55XDR' 'B07VYSSRL7']  B01M6625ME     UK
# 3  ['B092ZG24S7' 'B09BNHWWZM' 'B08CB1WG5M' '17880...  0241558573     UK
# 4                        ['B0B6NY5RM8' 'B09BJGBBBR']  B09BJF6N8K     JP

# %%
product_data = read_product_data()

# %%
product_data.head(5)
# Out:
#            id locale                                              title  \
# 0  B005ZSSN10     DE  RED DRAGON Amberjack 3 - Steel Tip 22 Gramm Wo...
# 1  B08PRYN6LD     DE  Simply Keto Lower Carb* Schokodrops ohne Zucke...
# 2  B09MBZJ48V     DE  Sennheiser 508377 PC 5.2 Chat, Stilvolles Mult...
# 3  B08ZN6F26S     DE  AmyBenton Auto ab 1 2 3 ahre - Baby Aufziehbar...
# 4  B094DGRV7D     DE      PLAYMOBIL - 70522 - Cavaliere mit grauem Pony
#
#    price         brand              color              size    model  \
# 0  30.95    RED DRAGON                NaN               NaN  RDD0089
# 1  17.90   Simply Keto                NaN  750 g (1er Pack)      NaN
# 2  68.89    Sennheiser       Multi-Colour          One size   508377
# 3  18.99  Amy & Benton         Animal Car               NaN    2008B
# 4   7.17     PLAYMOBIL  Nicht Zutreffend.           OneSize    70522
#
#              material author  \
# 0                 NaN    NaN
# 1                 NaN    NaN
# 2          Kunstleder    NaN
# 3  aufziehauto 1 jahr    NaN
# 4        Polypropylen    NaN
#
#                                                 desc
# 0  Amberjacks Steel Dartpfeile sind verfügbar in ...
# 1  🌱 NATÜRLICHE SÜSSE DURCH ERYTHRIT - Wir stelle...
# 2  3.5 MM BUCHSE - Kann problemlos an Geräte mit ...
# 3  【Auto aufziehbar】: Drücken Sie einfach leicht ...
# 4                                    Inhalt: 1 Stück

# %%
product_data = read_product_data()

# %%
product_data.query("id == 'B00IVLANGG'")['title']
# Out:
# 500010    wolfcraft Türfutter-Montageset PRO 3676000 / 8...
# Name: title, dtype: object

# %%
reindex_product_data = product_data.set_index(product_data['id'] + '_' + product_data['locale'])

# %%
train_sessions = read_train_data()

# %%
train_UK_sessions = train_sessions.query('locale == "UK"')

# %%
train_UK_sessions.iloc[20]
# Out:
# prev_items    ['B09BP1G2TR' 'B0BK54QNZP']
# next_item                      B09PD2727K
# locale                                 UK
# Name: 63, dtype: object

# %%
reindex_product_data.loc['B09BP1G2TR_UK']['title']
# Out:
# 'Rainbow High 578314EUC Jewel Richie-Emerald Green Fashion Doll with Vitiligo Includes 2 Mix & Match Designer Outfits with Accessories-for Kids 6-12 Years Old and Collectors'
