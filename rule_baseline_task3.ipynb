# %%
import warnings
warnings.simplefilter('ignore')

import gc
import re
from collections import defaultdict, Counter

import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
from tqdm.auto import tqdm

# %%
df_sess = pd.read_csv('./raw_data/sessions_train.csv')
df_sess
# Out:
#                                                 prev_items   next_item locale
# 0                              ['B09W9FND7K' 'B09JSPLN1M']  B09M7GY217     DE
# 1        ['B076THCGSG' 'B007MO8IME' 'B08MF65MLV' 'B001B...  B001B4THSA     DE
# 2        ['B0B1LGXWDS' 'B00AZYORS2' 'B0B1LGXWDS' 'B00AZ...  B0767DTG2Q     DE
# 3        ['B09XMTWDVT' 'B0B4MZZ8MB' 'B0B7HZ2GWX' 'B09XM...  B0B4R9NN4B     DE
# 4                 ['B09Y5CSL3T' 'B09Y5DPTXN' 'B09FKD61R8']  B0BGVBKWGZ     DE
# ...                                                    ...         ...    ...
# 3606244           ['B086CYFSKW' 'B0874F9859' 'B086CYFSKW']  B07B5TYD76     IT
# 3606245                        ['B09NRZKZ7V' 'B08WJTPV93']  B08L1P4C3D     IT
# 3606246                        ['B085JFX7MP' 'B085JGHW8R']  B01MPWVD44     IT
# 3606247                        ['B00B0UING2' 'B00B0UING2']  B00D3HYEZ4     IT
# 3606248  ['B092S9D1SD' 'B09XQQ1S72' 'B0852MS7QC' 'B0B1V...  B0B7RX65YP     IT
#
# [3606249 rows x 3 columns]

# %%
df_test = pd.read_csv('./raw_data/sessions_test_task3.csv')
df_test
# Out:
#                                               prev_items locale
# 0                            ['B082DLM3NZ' 'B089X86H73']     ES
# 1               ['B071WPLND2' 'B08TMJ9SDZ' 'B07XRCLVYG']     ES
# 2                            ['B094V8G54H' 'B094V97YV8']     ES
# 3                            ['B0B3DQXY57' 'B0B6W3GGTM']     ES
# 4               ['B0765BPD7T' 'B00V4PQY3C' 'B09HWV4MBK']     ES
# ...                                                  ...    ...
# 56416                        ['B08GNG5FMW' 'B08Q7MJW8W']     UK
# 56417                        ['B09YH16XH1' 'B09YGY96ZM']     UK
# 56418  ['B00EXKSNNE' 'B005DBORH8' 'B005DBORCS' 'B005D...     UK
# 56419           ['B007CJVZ1A' 'B07GCSPHNK' 'B07GCVF3N3']     UK
# 56420                        ['B07NBPTPD9' 'B01H2SPJGC']     UK
#
# [56421 rows x 2 columns]

# %%
def str2list(x):
    x = x.replace('[', '').replace(']', '').replace("'", '').replace('\n', ' ').replace('\r', ' ')
    l = [i for i in x.split() if i]
    return l

# %%
next_item_dict = defaultdict(list)

for _, row in tqdm(df_sess.iterrows(), total=len(df_sess)):
    prev_items = str2list(row['prev_items'])
    next_item = row['next_item']
    prev_items_length = len(prev_items)
    if prev_items_length <= 1:
        next_item_dict[prev_items[0]].append(next_item)
    else:
        for i, item in enumerate(prev_items[:-1]):
            next_item_dict[item].append(prev_items[i+1])
        next_item_dict[prev_items[-1]].append(next_item)
# Out:
# 100%|██████████| 3606249/3606249 [02:43<00:00, 22087.37it/s]

# %%
next_item_map = {}

for item in tqdm(next_item_dict):
    counter = Counter(next_item_dict[item])
    top1_list = counter.most_common(1)
    if len(top1_list) == 0:
        next_item_map[item] = ''
    else:
        next_item_map[item] = top1_list[0][0]
# Out:
# 100%|██████████| 1323630/1323630 [00:09<00:00, 136106.64it/s]

# %%
next_item_map
# Out:
# {'B09W9FND7K': 'B09JSPLN1M',
#  'B09JSPLN1M': 'B09W9FND7K',
#  'B076THCGSG': 'B007MO8IME',
#  'B007MO8IME': 'B007MO8IME',
#  'B08MF65MLV': 'B0798N5C1L',
#  'B001B4TKA0': 'B001B4THSA',
#  'B0B1LGXWDS': 'B00AZYORS2',
#  'B00AZYORS2': 'B0B1LGXWDS',
#  'B09XMTWDVT': 'B0B4MZZ8MB',
#  'B0B4MZZ8MB': 'B0B7HZ2GWX',
#  'B0B7HZ2GWX': 'B09XMTWDVT',
#  'B0B71CHT1L': 'B0B71GSJ2R',
#  'B09Y5CSL3T': 'B09Y5DPTXN',
#  'B09Y5DPTXN': 'B09Y5CSL3T',
#  'B09FKD61R8': 'B0BGVBKWGZ',
#  'B0749V8TC7': 'B0749V17QP',
#  'B0749W93VC': 'B0749V8TC7',
#  'B0749TX4YP': 'B0749VF4LM',
#  'B09SMK3R8H': 'B01N4ND0F9',
#  'B01N4ND0F9': 'B09SMK3R8H',
#  'B09B2W5S9R': 'B09B2YFY6M',
#  'B09B2YFY6M': 'B09B2W5S9R',
#  'B09B2WGPRB': 'B097CX2V3L',
#  'B01MQOR80Q': 'B095HS8R62',
#  'B095HS8R62': 'B07HY9KBMZ',
#  'B09B31WTVY': 'B09B32SSDT',
#  '3649625660': '3649625660',
#  'B07N3SNQW5': 'B099JZ9L9Y',
#  'B099JZ9L9Y': 'B07Q2CFPGH',
#  'B07Q2CFPGH': 'B099KCMQ92',
#  'B099KCMQ92': 'B07Q2CFPGH',
#  '3848520974': '3848520974',
#  'B07H1GQB36': 'B08DTZ3PTY',
#  'B08DTZ3PTY': 'B08G4DFMNN',
#  'B0927GXJPB': 'B003AO3LS6',
#  'B003AO3LS6': 'B07XHB9N43',
#  'B07YPSZ566': 'B07YPSZ566',
#  'B08G91WFQR': 'B08G97TPH8',
#  'B08G97TPH8': 'B08G91WFQR',
#  'B08G96F4ZF': 'B08G91WFQR',
#  'B01H6JS4IC': 'B01H6JS4IC',
#  'B0B42R2GKP': 'B0B42R2GKP',
#  'B0B5344X16': 'B07PFP21W9',
#  'B09ZTSZV49': 'B09B6W4C15',
#  'B09HXP3R6T': 'B09B6V94NG',
#  'B0B5QR5DJC': 'B0B7RD1HQQ',
#  'B09SFTDW9W': 'B0B5QR5DJC',
#  'B0B7RD1HQQ': 'B09SFTDW9W',
#  'B07LFQPX5L': 'B07LFPJTVF',
#  'B07LFPJTVF': 'B07LFQPX5L',
#  'B085QWM3KB': 'B001BAAV5W',
#  'B001BAAV5W': 'B00PEMBKZI',
#  'B002GHKPQY': 'B010VC4AG6',
#  'B010VC4AG6': 'B002GHKPQY',
#  'B00B2IOQHM': 'B0773V43RV',
#  'B0773V43RV': 'B000VVMY48',
#  'B000VVMY48': 'B0773V43RV',
#  'B01IKAEFJS': 'B08NSNYMQ5',
#  'B09LS7L75M': 'B09LS7L75M',
#  'B08D1XKQLP': 'B08CY964WX',
#  'B07W3L29CS': 'B07VY9P2GR',
#  'B07VY9P2GR': 'B07W3L29CS',
#  'B0B34LHBTF': 'B0B34PFRC3',
#  'B0B34PFRC3': 'B0B34LHBTF',
#  'B08F7XKPLD': 'B0BF9JD3YY',
#  'B0BF9JD3YY': 'B08F7XKPLD',
#  'B098S9TZG6': 'B0BF9JD3YY',
#  'B098FCPRY4': 'B098FFYX3B',
#  'B098FFYX3B': 'B098FCPRY4',
#  'B09Q3N3WT5': 'B09Q3LPC7G',
#  'B096JXN4QF': 'B08Y7RHM66',
#  'B0BL9H6ZGQ': 'B0BLBRRJD1',
#  'B0BLBRRJD1': 'B096K9KV9K',
#  'B08Y7RHM66': 'B096KB1JSK',
#  'B096K9KV9K': 'B096K7VKCF',
#  'B00CS3IXLA': 'B0751FNR26',
#  'B0751FNR26': 'B00CS3IXLA',
#  'B000OXME9S': 'B000OXME9I',
#  'B07FK6DYP9': 'B07CRLVXC5',
#  'B07CRLVXC5': 'B07FK6DYP9',
#  'B07FJX5YNS': 'B07FK6DYP9',
#  'B08S3C6LCB': 'B08S3C6LCB',
#  'B0BK551XH1': 'B08S3C6LCB',
#  'B09J8ZY18N': 'B09J8ZBGYV',
#  'B0B9GFPLZJ': 'B09J8ZBGYV',
#  'B09VS7CX7V': 'B09VS7CX7V',
#  'B0B3T4K2VR': 'B07Q43HJVW',
#  'B07P5G5FVS': 'B07R9PZ9VC',
#  'B07R9PZ9VC': 'B07P5G5FVS',
#  'B014W4I5PG': 'B014W4I5PG',
#  'B00DIVPEGS': 'B00E67BJOE',
#  'B00E67BJOE': 'B00DIVPEGS',
#  'B00E4ZS2M0': 'B07JQ87Z1T',
#  'B07Z3X7RXC': 'B071RNDGZP',
#  'B071RNDGZP': 'B07Z3X7RXC',
#  'B09DR42FJG': 'B0955TX876',
#  'B09JDGGFR3': '3596706955',
#  '3596708273': '3596706955',
#  'B01NAQR0Y2': 'B08XBZL5CM',
#  'B08XBZL5CM': 'B08XBNRD25',
#  'B0B881CKN8': 'B088887DTC',
#  'B0B5ZBZZJR': 'B0B5ZBZZJR',
#  'B07K9K5QTN': 'B07K9K5QTN',
#  'B0931QNJWL': 'B08639TB7N',
#  'B07L6B7D4M': 'B07L6LHZ7W',
#  'B07L6LHZ7W': 'B07L6B7D4M',
#  'B095K51ZSD': 'B095K2N6T5',
#  'B08QYYBTMC': 'B0B3DKVCC6',
#  'B0BGL7KC2D': 'B0BGL7KC2D',
#  'B08V12CT4C': 'B08V1KXBQD',
#  'B08V1KXBQD': 'B08V12CT4C',
#  'B01H84XN8G': 'B000EWC0NY',
#  'B08RN1WJBG': 'B09DS2Y73L',
#  'B08S6LKMCM': 'B09QM7RXBN',
#  'B09KRCKVBY': 'B0BD77ZCR9',
#  'B073FGSC7T': 'B003OOFZIQ',
#  'B097Y4ZJXB': 'B097Y42GWC',
#  'B097Y4V621': 'B097Y4ZJXB',
#  'B097Y4B9N8': 'B097Y4ZJXB',
#  'B01EG3LBO0': 'B00V8CQEYA',
#  'B07VL9YHC9': 'B07VCS1895',
#  'B07VCS1895': 'B07VL9YHC9',
#  'B09M7ZNQSB': 'B07W4DGZ54',
#  'B07W4DGZ54': 'B07W7K29YM',
#  'B07W7K29YM': 'B07W4DGZ54',
#  'B09L7Q9425': 'B09QVFQCDP',
#  '3881172351': '3845837756',
#  '3845837756': '3742318926',
#  'B07GB9MMB1': 'B08777PNL5',
#  'B074P87WH6': 'B00NPYH80I',
#  'B01E5IS66M': 'B08NP5GN8R',
#  'B08NP5GN8R': 'B01E5IS66M',
#  'B003KHJO6G': 'B0B88LMTRB',
#  'B0B88LMTRB': 'B003KHJO6G',
#  'B084HZCLNQ': 'B00FZWPO5Y',
#  'B00FZWPO5Y': 'B084HZCLNQ',
#  'B00K69H85U': 'B084HZG4F3',
#  'B084HZG4F3': 'B00K69H85U',
#  'B09SHWGFJC': 'B09SHWFZNR',
#  'B09STY5C7R': 'B09SHWGFJC',
#  'B09QH4J3XS': 'B09QH5NGB7',
#  'B09QH5NGB7': 'B09QH4ZDSM',
#  'B0B2WT9JHP': 'B0B2WT9JHP',
#  'B09Y5WT9TJ': 'B09Y5WT9TJ',
#  'B09PHB6TSP': 'B09Y5XL9FB',
#  'B09Y5XL9FB': 'B09Y5XL9FB',
#  'B09QH9NVFG': 'B09QHD2FBD',
#  'B0B8KPSY7B': 'B09QH9NVFG',
#  'B01CO5PIWS': 'B01CO5PSSM',
#  'B09WD4GYNJ': 'B09WD5QYH4',
#  'B094QKV6S8': 'B094QJNYY2',
#  'B079MC4MS1': 'B079M9DNGB',
#  'B079M9DNGB': 'B079MC4MS1',
#  'B08SMPSMZB': 'B084D6GJSD',
#  'B084D6GJSD': 'B08SMPSMZB',
#  'B0B8SQHFMC': 'B0B8SNYFPZ',
#  'B0B8SNYFPZ': 'B09Z7NJVHK',
#  'B001F8MRFM': 'B00M7ADB0C',
#  'B00M7ADB0C': 'B01LX8CFQV',
#  'B09GLKSJFR': 'B09GLN6HJ6',
#  'B0B6J9CTWP': 'B09Y5KJ3F7',
#  'B09Y5KJ3F7': 'B09ZV2WWH8',
#  'B09ZV2WWH8': 'B09GLKSJFR',
#  'B0B6C9PJJG': 'B0B6CC75LQ',
#  'B01LX16TPB': 'B09JLPLXCB',
#  'B07XYCQZ7V': 'B07XYBZ31G',
#  'B00AS966B0': 'B07S9GHYND',
#  'B09JNNK8L2': 'B09DPN2PLW',
#  'B0B1WPFNC7': 'B09DPN2PLW',
#  'B09DPN2PLW': 'B09JNNK8L2',
#  'B07SS57787': 'B07SS3B5ZX',
#  'B07SQ3BZN5': 'B07SS57787',
#  'B07SS3B5ZX': 'B07SQ3BZN5',
#  'B07SS57FV1': 'B07XBPC5VW',
#  'B07V6QYW9W': 'B094FXN763',
#  'B07V6VGYXW': 'B07V6QYW9W',
#  'B094FXN763': 'B07V6VGYXW',
#  'B07V5R8BSY': 'B094FX9LRJ',
#  'B0B5CBRJNN': 'B07GB4NQ2F',
#  'B000VBPEQS': 'B000VBPEQS',
#  'B086LTRGMZ': 'B08T8ZMTS8',
#  'B098F6919C': 'B006D51HKI',
#  'B085FXHR38': 'B085FXGP5W',
#  'B085FXGP5W': 'B09G3WQQG6',
#  'B085HK4KL5': 'B09G3W3NQC',
#  'B0967LSY4Z': 'B0967LSY4Z',
#  'B08XZH4X1N': 'B095T4X6Z3',
#  'B06XGNM7R2': 'B06XGNM7R2',
#  'B00491XPVW': 'B00JP8DXDE',
#  'B00JP8DXDE': 'B01KXHHTZS',
#  'B09KLKMW6R': 'B08X1G2WWD',
#  'B08X1G2WWD': 'B09ZQNSQZ1',
#  'B09ZQNSQZ1': 'B08X1G2WWD',
#  'B08RNBLKYW': 'B08DJ41QBS',
#  'B08DJ41QBS': 'B08RNBLKYW',
#  'B09BYJ9F44': 'B01M59PNKH',
#  'B01M59PNKH': 'B09BYJ9F44',
#  'B005VNOFWA': 'B0777QYWHM',
#  'B0777QYWHM': 'B07JQMVY4H',
#  'B08HPDTKWL': 'B0BCH4RR13',
#  'B0BCH4RR13': 'B08HPDTKWL',
#  'B011RACHN4': 'B0873T3387',
#  'B0873T3387': 'B011RACHN4',
#  'B086N2RT37': 'B08WHN1KTN',
#  'B08WHN1KTN': 'B086N2RT37',
#  'B09YDK2RNG': 'B09YDL8V77',
#  'B09YDL8V77': 'B09YDK49Z3',
#  'B09YDK49Z3': 'B071Z7CCBK',
#  'B08TZ2RWF6': 'B08TZ2RWF6',
#  'B08M46CWM6': 'B08M46CWM6',
#  'B08HP7J77F': 'B08HP5GW4F',
#  'B08HP5GW4F': 'B08HP7J77F',
#  'B08TLYX1FP': 'B09FM39HJX',
#  'B09FM39HJX': 'B01I52640O',
#  'B07SSS6FR2': 'B08CV5XY4F',
#  'B08CV5XY4F': 'B07SSS6FR2',
#  'B08VBH3NCF': 'B0BB11BWVT',
#  'B09P8XWBKF': 'B082VP752X',
#  'B082VP752X': 'B09P8XWBKF',
#  'B09P8Z2QZX': 'B09NQP6PP1',
#  'B07H5VTB9H': 'B013P2UMUW',
#  'B013P2UMUW': 'B07H5VTB9H',
#  'B00006J6IW': 'B071XM6C67',
#  'B09C3PGRRK': 'B09C3NSC46',
#  'B08F62G2NJ': 'B08F63JZNQ',
#  'B094DZNFMH': 'B08F63JZNQ',
#  'B0B6G3BBNM': 'B09FPV7NF8',
#  'B0BF5SCYDZ': 'B0BF5SCYDZ',
#  '3625171562': '3625171562',
#  'B00CRF8382': 'B00QH0LSSA',
#  'B000W34ZB0': 'B07KFNN86J',
#  'B07KFNN86J': 'B07KFNN7X3',
#  'B0728LV4GY': 'B0728LV4GY',
#  'B0028H6MWI': 'B0028H6MWI',
#  'B07B29FSCP': 'B00C9DAZ38',
#  'B00C9DAZ38': 'B00C9DAZ38',
#  'B07ZTHMRG4': 'B07ZTGVKWN',
#  'B09T3K4KJV': 'B018IV0F2U',
#  'B089MWFMV9': 'B011KRABFK',
#  'B077K49T9J': 'B016TFSECA',
#  'B016TFSECA': 'B089MXHF4L',
#  'B01939I24O': 'B013DY5I7Y',
#  'B01BMCZ0T0': 'B011KRAGH8',
#  'B07KWMHCS1': 'B094DHP6WB',
#  'B09NQG2P4V': 'B071DPWR5S',
#  'B07P5QL45S': 'B07P5QL45S',
#  'B07MLDJF3B': 'B07MLFBJG3',
#  'B07MLFBJG3': 'B07MLDJF3B',
#  'B00LN803K0': 'B00LN803K0',
#  'B00LH3DMUO': 'B01B8R6PF2',
#  'B00MNV8E0C': 'B01B8R6PF2',
#  'B08CF24SS1': 'B08CF4MVPP',
#  'B015CCR1FW': 'B09PZ6J5YZ',
#  'B09PZ6J5YZ': 'B015CCR1FW',
#  'B08HV9RHHF': 'B089M4757V',
#  'B089M4757V': 'B089M4757V',
#  'B09699CSC7': 'B09697J6XZ',
#  'B09697J6XZ': 'B09699CSC7',
#  'B09696TVXV': 'B096925RRC',
#  'B096925RRC': 'B09696TVXV',
#  'B0B7RCPQRN': 'B0B7RML8JF',
#  'B01F13SC5U': 'B01F13SC5K',
#  'B01F13SC5K': 'B01F13SC5U',
#  'B00PKJUI5S': 'B00PKJUI5S',
#  'B08R7NNWLL': 'B08XY8FMR2',
#  'B08XY8FMR2': 'B083MN4SW1',
#  'B07DN6V52X': 'B077RXM292',
#  'B077RXM292': 'B07DN6V52X',
#  'B08JD1SW74': 'B098DFBLGJ',
#  'B098DFBLGJ': 'B098DDVSYX',
#  'B001QOGSG4': 'B001QOGSG4',
#  'B09B9YYVYF': 'B09B9YM9NR',
#  'B08NVZQ8NW': 'B08NVYHCYP',
#  'B0B7BFQXW8': 'B0B7BK2BGC',
#  'B0BFRLFFPR': 'B0BCQLVFBM',
#  'B0BCQLVFBM': 'B0BFRLFFPR',
#  'B00I06U2B8': 'B00I06U48E',
#  'B00I06U48E': 'B00I06U2B8',
#  'B01MRN6N5M': 'B00GO4N698',
#  'B00GO4N698': 'B01MRN6N5M',
#  'B09LYMZ4N3': 'B09LYS9KLQ',
#  'B09LYS9KLQ': 'B09LYMZ4N3',
#  'B09LYQT125': 'B09LYQZFHW',
#  'B09LYQZFHW': 'B09LYQT125',
#  'B0B4VXRJX3': 'B09R1R82P5',
#  'B09NB8232J': 'B09BTKNGN5',
#  'B09BTKNGN5': 'B09NB989Z4',
#  'B09NB989Z4': 'B09BTKNGN5',
#  'B09PTJW2PF': 'B09NKLP6B4',
#  'B09F3N3QXP': 'B09BZRM3RV',
#  'B01CWALGEY': 'B00DK7Z15Y',
#  'B00DK7Z15Y': 'B00DK7Z15Y',
#  'B081BL1VDW': 'B081BL1VDW',
#  'B092RY2435': 'B09DYDLWMH',
#  'B09DYDLWMH': 'B092RY2435',
#  'B09NXCXY21': 'B09DPJ9R9P',
#  'B09DPJ9R9P': 'B09NXCXY21',
#  'B07LFYK3RY': 'B08BNRYXWS',
#  'B08BNRYXWS': 'B07LFYK3RY',
#  'B0B56WFL4S': 'B0B51H9QHY',
#  'B0B51H9QHY': 'B0B51J8BY9',
#  'B08DFGWDZR': 'B08DFPV5Y2',
#  'B08DFPV5Y2': 'B08DFGWDZR',
#  'B08BC7HNYJ': 'B08TQVCGN6',
#  'B08TQVCGN6': 'B09CPTKG6H',
#  'B086K6S5L4': 'B09QQ5QSW2',
#  'B08SMB849P': 'B086K6S5L4',
#  'B09QQ5QSW2': 'B08SMB849P',
#  'B000YWH2LO': 'B07QVNLDWR',
#  'B08P4YPB8Q': 'B0B2WZZBY3',
#  'B0B2WZZBY3': 'B08P4YPB8Q',
#  'B0B7MG776F': 'B096DSPY7H',
#  'B08GSQW542': 'B084T4DZFC',
#  'B084T4DZFC': 'B08GSQW542',
#  'B09Z6R6C7C': 'B09Z6RHG3F',
#  'B09Z6RXHJB': 'B09Z6R6C7C',
#  'B09Z6QLHVL': 'B09Z6RXHJB',
#  'B0B4X579FP': 'B09Z6RXHJB',
#  '3788638672': '378864026X',
#  '378864026X': '3845119128',
#  'B086XCB1QP': 'B083BY3B2T',
#  'B083BY3B2T': 'B086XCB1QP',
#  'B09YRBPFZ1': 'B09YRBR692',
#  'B07BGSW6BT': 'B07BGSW6BT',
#  'B0B6RGBDLG': 'B0B6RF4MPS',
#  'B0B2NZVHWL': 'B0B6RGBDLG',
#  'B09BCT5VBQ': 'B09C8TVPGY',
#  'B08V1398T5': 'B09C8TVPGY',
#  'B09C8TH8V2': 'B08V1398T5',
#  'B09C8TVPGY': 'B09C8TH8V2',
#  'B06X3VQRC7': 'B08C2K6TLH',
#  'B0BJQ86L6G': 'B08R8Q6PH1',
#  'B08R8Q6PH1': 'B08PV44VGL',
#  'B08HD9KWHT': 'B09MT2STFG',
#  'B09MT2STFG': 'B08HD9KWHT',
#  'B07F28HT4C': 'B07L9M477R',
#  'B07L9M477R': 'B07F28HT4C',
#  'B099RMG3TY': 'B09JJX2PXP',
#  'B09JJX2PXP': 'B099RMG3TY',
#  'B07KS9CNHY': 'B07KS9CNHY',
#  'B09BRB6TYS': 'B09BRB6TYS',
#  'B097343VMY': 'B017TYRDIG',
#  'B017TYRDIG': 'B097343VMY',
#  'B00PHDQRWA': 'B07657CPDH',
#  'B09QXBK3S8': 'B09KPKFM3W',
#  'B08CXMB5FS': 'B09CK8JX97',
#  'B0B5DF8GJW': 'B0B688G3RF',
#  'B0B9GKRSFJ': 'B09ZVM62P7',
#  'B09ZVM62P7': 'B0B9GKRSFJ',
#  'B09XF8DTD7': 'B09XF8DTD7',
#  'B0B7N2YKPC': 'B0B7MZXLML',
#  'B0B7MZXLML': 'B0B7N19Y8B',
#  'B0B2ZBZTDX': 'B083YMH99L',
#  'B083YMH99L': 'B07MGJ6WN6',
#  'B07JNPJN78': 'B099BC6KRY',
#  'B09J4TJP82': 'B07M85NKR5',
#  'B07M85NKR5': 'B07M85NKR5',
#  'B0863RK1KX': 'B0863SN8S1',
#  'B07TJL4F21': 'B09MJ5Q644',
#  'B09MJ5Q644': 'B07TJL4F21',
#  'B09CPN3JWG': 'B09CPN7V5M',
#  'B09CPN7V5M': 'B09CPN3JWG',
#  'B0B11VSF58': 'B0B11SMZQQ',
#  'B0B11SMZQQ': 'B09Y183XHR',
#  'B0B2RJGWBQ': 'B086916TZ7',
#  'B086916TZ7': 'B0B2RJGWBQ',
#  'B0BBRHDYSJ': 'B0B2RJGWBQ',
#  'B087VM7HT2': 'B087VL2Z21',
#  'B087VL2Z21': 'B087VL2Z21',
#  'B07NGVRYWX': 'B07NGVRYWX',
#  'B09ZLB29B6': 'B09ZP2CFNL',
#  'B09ZP2CFNL': 'B09ZLB29B6',
#  'B09ZL8H9TH': 'B09ZP5XKY5',
#  'B09ZP5XKY5': 'B09ZLB1JVY',
#  'B093GGVB89': 'B093GGNRZM',
#  'B093GGNRZM': 'B093GGVB89',
#  'B093GFBD2M': 'B093GHXQB9',
#  'B093GHXQB9': 'B093GFJ74C',
#  'B093GFJ74C': 'B093GH41F1',
#  'B093GH41F1': 'B09FWY5QCJ',
#  'B09FWY5QCJ': 'B09FXB4QTL',
#  'B09FXB4QTL': 'B09FWY5QCJ',
#  'B09FTDXG5L': 'B09FTD94J8',
#  'B093GGBM61': 'B09FTFK4FT',
#  'B09FTFK4FT': 'B09FTBNCQ6',
#  'B08GFLBXSZ': 'B08H87VZJ9',
#  'B08H87VZJ9': 'B08GFLBXSZ',
#  'B08GFPYTGL': 'B08H83C89C',
#  'B08H83C89C': 'B08GFPYTGL',
#  'B09BQVR5N8': 'B09BQWNPHN',
#  'B08GFQSDCN': 'B08H89QD4H',
#  'B0B34QYWDK': 'B09TTZZWW6',
#  'B09TTZZWW6': 'B0B34QYWDK',
#  'B09KS35B7S': 'B09MVLCRJG',
#  'B08C2YRV3L': 'B08C2Y19F1',
#  'B095PDRHS4': 'B0B5615TM9',
#  'B08G4HRMMG': 'B08DHV1NCT',
#  'B0B5615TM9': 'B088WD6PXX',
#  'B09XN14VC5': 'B09XN22FZR',
#  'B09SFRH8R4': 'B07RP5LBC1',
#  'B07RQ53V4P': 'B07MJJ4MW6',
#  'B09J4V8RYF': 'B0B2K4JVBK',
#  'B07WS5H5ZY': 'B07WYD67T5',
#  'B07WS5JMZP': 'B07WYD67T5',
#  'B0766JX13M': 'B0766GSF17',
#  'B0766GSF17': 'B0766JX13M',
#  'B09JC2QLCN': 'B09JC37QRJ',
#  'B09JC37QRJ': 'B09JC2QLCN',
#  'B07RWVM79Z': 'B07RWTLN1Y',
#  'B07RWTLN1Y': 'B07RWVM79Z',
#  'B08PH9D4V6': 'B07WWVVQZL',
#  'B08P98BPLZ': 'B09F9Z7P7R',
#  'B07DK7YXQ5': 'B07DK72X4K',
#  'B0BGYJD6Z1': 'B07NPGPDNY',
#  'B0143EQYE4': 'B0144PKU8I',
#  'B09C5RF4VN': 'B09C5QXMQY',
#  'B0B375ZY12': 'B0B375ZY12',
#  'B096V2N136': 'B098NZ7GR3',
#  'B082YN8F54': 'B07NR1TMZC',
#  'B082YMTVB6': 'B07NR1TMZC',
#  'B01DDE7GHE': 'B087QG19CD',
#  'B087QG19CD': 'B0B2P6JN2H',
#  'B0B2P6JN2H': 'B072PS8ZKG',
#  'B003PAIRWK': 'B00VUSH63K',
#  'B00VUSH63K': 'B003PAIRWK',
#  'B07C9W7CCH': 'B07C9W7CCH',
#  'B094VLX6HH': 'B094VLX6HH',
#  'B0984MVD1C': 'B0984QX3QQ',
#  'B0984QX3QQ': 'B0984S4CGC',
#  'B09NH1RRCG': 'B09NH1RRCG',
#  'B006XE8DEC': 'B007FD62FW',
#  'B0B8N9L6QC': 'B0B8NF77YG',
#  'B09ML7GP5M': 'B09V3LCVYQ',
#  'B0BFQB9VFH': 'B0BFQD5GJ8',
#  'B0BFQD5GJ8': 'B09QPFK3C3',
#  'B0922JX27X': 'B09NQGVSPD',
#  'B09NQGVSPD': 'B0922JX27X',
#  'B09SDT5Z2S': 'B094WRT8PD',
#  'B094WRT8PD': 'B08H99BPJN',
#  'B09SDVMKLY': 'B094WLFGD3',
#  'B094WLFGD3': 'B08H99BPJN',
#  'B094YTVHPF': 'B09WSBKTKY',
#  'B09WSBKTKY': 'B09NLH8PMY',
#  'B09NLH8PMY': 'B08H99BPJN',
#  'B08GR6H7PR': 'B0B9C4FQXB',
#  'B0B9C4FQXB': 'B08GRZXL46',
#  'B08GRZXL46': 'B0B9C4FQXB',
#  'B07F8P8GM9': 'B0118W7D58',
#  'B08BX396DL': 'B07F8P8GM9',
#  'B08R9T375R': 'B09F5L7VX9',
#  'B09F5L7VX9': 'B08R9T375R',
#  'B07Y1YMXFY': 'B07Y1X4T12',
#  'B00MH4QKP6': 'B00MH4QI26',
#  'B093C9FN7W': 'B093C9FN7W',
#  'B003BU3XRS': 'B003BU3XRS',
#  'B08HNCPZLY': 'B08HNCPZLY',
#  'B07JM21QHM': 'B07DRKMWYX',
#  'B07GH48Q2G': 'B07DRKMWYX',
#  'B07DRKMWYX': 'B07JM21QHM',
#  'B07F16BD5N': 'B07DRKMWYX',
#  'B07JMFH2Q2': 'B07KCLQ2V1',
#  'B07S9YZGSX': 'B07F16BD5N',
#  'B07GH1W53G': 'B07JMFH2Q2',
#  'B07HGB48D4': 'B07JM21QHM',
#  'B07MZ9QLDQ': 'B07GH48Q2G',
#  'B07N2WY5WJ': 'B07KCHLSZX',
#  'B07KCHLSZX': 'B07JLQCTC5',
#  'B07JLQCTC5': 'B07GGYJS65',
#  'B0BH8FDQ8J': 'B07GH48Q2G',
#  'B08M3D8FTX': 'B08J43PR1G',
#  'B08B5Y27TB': 'B08B5Y27TB',
#  'B09H5P3WNQ': 'B09H5P3WNQ',
#  'B09XGP6STD': 'B09XGV6DXQ',
#  'B09XGV6DXQ': 'B0B7X587WQ',
#  'B0B7X587WQ': 'B09XGV6DXQ',
#  'B07BPGYZ6C': 'B07BPGYZ6C',
#  'B0094FQZOC': 'B0B466H784',
#  'B0BDZYBQ93': 'B0BDZYBQ93',
#  'B099RWZHV4': 'B085TJ49MZ',
#  'B085TJ49MZ': 'B099RWZHV4',
#  'B08R86M2B7': 'B08R85L118',
#  'B071P98VTG': 'B074RGW2VQ',
#  'B0BF5NRF8H': 'B071P98VTG',
#  'B09YHZ8ZZ7': 'B00LDSP20Q',
#  'B09YHZPGVF': 'B00LDSP20Q',
#  'B00LDSP20Q': 'B09YHZPGVF',
#  'B00JRD78F6': 'B00S9N6446',
#  'B007VDR77I': 'B00JOL0LZK',
#  'B00JOL0LZK': 'B007VDR77I',
#  'B08FXBHV29': 'B08FXBHV29',
#  'B09TW5XGD5': 'B09QD99DCP',
#  'B07VH6VX47': 'B07GJHGKK9',
#  'B09V83BGSX': 'B08XWLHWF9',
#  'B08XWLHWF9': 'B09V83BGSX',
#  'B0B1Q4Q84F': 'B08XWQHBCR',
#  'B07D8XYDQL': 'B089SVM61B',
#  'B07C51CV3H': 'B09P8H24TZ',
#  'B09P8H24TZ': 'B09S9PMN5T',
#  'B000VDAISK': 'B07PBBWBRT',
#  'B07PBBWBRT': 'B000VDAISK',
#  'B001F6ZJ9K': 'B00C4QQZK2',
#  'B089MBVQJW': 'B089MBYQ6T',
#  'B0B4SHJPMY': 'B07DGH9V7S',
#  'B07PM3QZPR': 'B0BFS6991Q',
#  'B07PJMFBKF': 'B0BFS6991Q',
#  'B0BFS6991Q': 'B07PM3QZPR',
#  'B08TR7F9MP': 'B07NXMQPP2',
#  'B0BFRGMYQN': 'B0BFRGSM11',
#  'B0BFRGSM11': 'B0BFRGMYQN',
#  'B0BFRFC4LV': 'B0BFS6991Q',
#  'B08TQ7PXH9': 'B07NXMQPP2',
#  'B000KJR5S6': 'B000L115WU',
#  'B09NDGR3TP': 'B09NDF4L7R',
#  'B00LQZB9F8': 'B071L9HVB9',
#  'B071L9HVB9': 'B00LQZB9F8',
#  'B073QVBN72': 'B073QV7823',
#  'B0BFBTWJDX': 'B0BFBRF9PT',
#  'B0BFBRF9PT': 'B0BFBTWJDX',
#  'B09YH18CWF': 'B0BGGRS2V4',
#  'B09WYVNB8P': 'B09WYV2SW3',
#  'B09WYV2SW3': 'B09WYVNB8P',
#  'B09BPV9YY2': 'B095J8MGHQ',
#  'B095J8MGHQ': 'B08PT4XZFQ',
#  'B09CZGDG1C': 'B097RCR61S',
#  'B097RCR61S': 'B09CZGDG1C',
#  'B0BCHS168T': 'B0BCHS168T',
#  'B09LQK9854': 'B09LQK9854',
#  'B0B96QTHRM': 'B0B5WCVK65',
#  'B0BB9RVHSJ': 'B0BB9RVHSJ',
#  'B0033Q5KU8': 'B0033Q5KU8',
#  'B0979V752C': 'B0979S75KG',
#  'B0979S75KG': 'B0979RLKV4',
#  'B0979RLKV4': 'B0979V752C',
#  'B095CQWBWY': 'B0979V752C',
#  'B09YDBWSC1': 'B09YDD5H1H',
#  'B094X9LTZM': 'B09G29R8C8',
#  'B004XH7TNM': 'B0837FC2TV',
#  'B0837FC2TV': 'B0837FC2TV',
#  'B07RC26ZJW': '3830342381',
#  'B09P7ZYMY2': 'B09P7ZYMY2',
#  'B06XDYJNSR': 'B01N193MHD',
#  'B0169SORDW': 'B07L5529KZ',
#  'B07L5529KZ': 'B0169SORDW',
#  'B09JPGHB2J': 'B09JPFBNGB',
#  'B09JPFBNGB': 'B09JPG5M2L',
#  'B088S1C3K9': 'B088RX9CSZ',
#  'B088RX9CSZ': 'B088S1C3K9',
#  'B0B2PSDNV1': 'B0B2PQLWD9',
#  'B0B2PQLWD9': 'B0B2PSDNV1',
#  'B09C63P5KQ': 'B09C62L43D',
#  'B08YR261VK': 'B07VCG5G7H',
#  'B099NNRP72': 'B099NP74Q7',
#  'B099NSDH7K': 'B099NQTD4G',
#  'B09JC21TK4': 'B0BD855V1J',
#  'B0BD855V1J': 'B0BD8PWNC8',
#  'B07H5QQG82': 'B09778FJV4',
#  'B0B1DR8FJM': 'B0B1Z6NFQB',
#  'B094MX3ZCD': 'B081ZG7BCK',
#  'B081ZG7BCK': 'B081ZFQBQB',
#  'B081ZFQBQB': 'B081ZG7BCK',
#  'B083M7W174': 'B0B3JFYX4D',
#  'B0B3JFYX4D': 'B0B3JGFKRF',
#  'B0B3JGFKRF': 'B0B3JFYX4D',
#  'B09MYXZ2TL': 'B00XCW5H9C',
#  'B00XCW5H9C': 'B01DCH5BMY',
#  'B08LQ44FRC': 'B08LQ44FRC',
#  'B07Z3XVSC3': 'B07Z3YD833',
#  'B07Z3YD833': 'B07Z3XVSC3',
#  'B08X3HCW5Q': 'B09H6DC9Z5',
#  'B09H6DC9Z5': 'B08X3HCW5Q',
#  'B0BHQRVG3D': 'B09M8MQFV4',
#  'B09M8MQFV4': 'B0BHQRVG3D',
#  'B09G386KLZ': 'B09G386KLZ',
#  'B08GCV1BK9': 'B08PPQVQLW',
#  'B08PPQVQLW': 'B08GCV1BK9',
#  'B09KLW8D9C': 'B0B6PWXWM8',
#  'B08T1VJ2L5': 'B08T19F29G',
#  'B08T19F29G': 'B08T1VJ2L5',
#  'B08T1XQM1X': 'B08T19F29G',
#  'B09QSY8XMT': 'B07NDF5HR4',
#  'B07NDF5HR4': 'B07NDF5HR4',
#  'B0043W42ZU': 'B09ZDNXQTP',
#  'B09ZDNXQTP': 'B0BGMVVDC3',
#  'B01BY9RTO0': 'B094NW9YS2',
#  'B094NZB19R': 'B094NW9YS2',
#  'B094NW9YS2': 'B01BY9RTNQ',
#  'B01BY9RTNQ': 'B094NW9YS2',
#  'B09ND17G4W': 'B09ND17G4W',
#  'B006JKIW7I': 'B075ZVKXJP',
#  'B075ZVKXJP': 'B075ZVPGLZ',
#  'B0041MSQX6': 'B0041MSQX6',
#  'B084GPY76H': 'B087234F73',
#  'B087234F73': 'B084GPY76H',
#  'B07BG9GN7C': 'B07BGCGJDH',
#  'B07BGCGJDH': 'B07BG9GN7C',
#  'B017A1N6L6': 'B08WLPXR9S',
#  'B0B3DH33VJ': 'B08GPKTN2B',
#  'B08GPKTN2B': 'B0B3DH33VJ',
#  'B08W5FV9GN': 'B01J41D4IU',
#  'B09C94CZ1K': 'B07WLMV14S',
#  'B07WLMV14S': 'B07W4KVGJM',
#  'B094VWMXRX': 'B000CSQ71G',
#  'B07NV5BC5W': 'B09MZKWB6D',
#  'B09MZK63ZJ': 'B07NV5BC5W',
#  'B0BBSNCTXL': 'B079KHH4WP',
#  'B003U7QW6G': 'B0B1N9V7G9',
#  'B08FWRQ6Z4': 'B08C8VSSRB',
#  'B08C8VSSRB': 'B08FWRQ6Z4',
#  'B09G1CT22S': 'B09G1BH6W4',
#  'B098LCY76J': 'B08JCH2F3L',
#  'B08JCH2F3L': 'B08JCH2F3L',
#  'B09DNQ9K4P': 'B0B8SBNBVC',
#  'B0B8SBNBVC': 'B09DNQ9K4P',
#  'B09DSWJZ1L': 'B09DNQ9K4P',
#  'B0BF12Y3G8': 'B0BF12Y3G8',
#  'B075QCRKNT': 'B0BF129MRX',
#  'B0BF129MRX': 'B0BF129MRX',
#  'B096T15N7S': 'B01MRA69NQ',
#  'B008KWO3TY': 'B0B218QT9M',
#  'B07FQSMFRN': 'B07FQRT5QH',
#  'B07FQRT5QH': 'B07FQSMFRN',
#  'B07MSGTTL8': 'B07MM45BXV',
#  'B07MM45BXV': 'B07MSGTTL8',
#  'B09WXN689V': 'B09WXN689V',
#  'B091MVJSN4': 'B091MWG3KP',
#  'B091MWG3KP': 'B091MVJSN4',
#  'B07P5H4M8N': 'B07P5H4M8N',
#  'B09JTNZR1Z': 'B07PV4X5CM',
#  'B082VP8LYF': 'B082VP8LYF',
#  'B001JMTPMM': 'B00EK99VN4',
#  'B00EK99VN4': 'B001JMTPMM',
#  'B07QYV7PB6': 'B07QYTWH36',
#  'B07QYTWH36': 'B07QYVZGZ1',
#  'B07QYVZGZ1': 'B07QYVBDMD',
#  'B07QYVBDMD': 'B07QYVFSD7',
#  'B07QYVFSD7': 'B07QYTR3R1',
#  'B07QYTR3R1': 'B07QZXDKPZ',
#  'B07QYVX3LQ': 'B07QXSGRDJ',
#  '3772442684': '3772443893',
#  '3772443893': '3772443893',
#  'B08PVGTM4S': 'B00VF9BJBE',
#  'B0001E3VE2': 'B0788C2HZR',
#  'B0788C2HZR': 'B07885BY9Z',
#  'B09L842S5V': 'B072BBQ3M5',
#  'B072BBQ3M5': 'B072BBQ3M5',
#  'B098D33F41': 'B082HXJXFQ',
#  'B082HXJXFQ': 'B07LDZWTJG',
#  'B085Y2RM5Q': 'B09L7VQYHY',
#  'B09L7VQYHY': 'B07YKBM7PV',
#  'B07YKBM7PV': 'B088GWGX3Y',
#  'B09QQHPS9L': 'B09VF1LS8J',
#  'B09VF1LS8J': 'B09VLBLZQQ',
#  'B09VLBLZQQ': 'B09VF1LS8J',
#  'B07QMV95WQ': 'B08552FMQP',
#  'B08552FMQP': 'B07QMV95WQ',
#  'B085YWWHW3': 'B08VWGD4RW',
#  'B08VWGD4RW': 'B085YVVHNR',
#  'B09HQ5S83P': 'B085YVK5C7',
#  'B07WNS7CF4': 'B09NMS1FPJ',
#  'B09NMS1FPJ': 'B09NMS1FPJ',
#  'B09NMRC7WS': 'B09NMRC7WS',
#  'B08BQXS2TX': 'B09VL1YNK3',
#  'B097SYBKSB': 'B097SYBKSB',
#  'B082PJ6X9K': 'B09QRM3VPG',
#  'B0842RSW58': 'B07GL3JX73',
#  'B07BLYRLZ4': 'B084DH6CRC',
#  'B07MB7PFZG': 'B07MHFFVRS',
#  'B09M7GY217': 'B0B6FJJGKB',
#  'B09BM4DYJT': 'B084ZQVV8T',
#  'B084ZQVV8T': 'B09BM4DYJT',
#  'B07GTTH1TC': 'B08M4RBQLM',
#  'B08M4RBQLM': 'B07GTTH1TC',
#  'B08HHB551N': 'B09NNFN2H8',
#  'B09NNFN2H8': 'B09NNDXNHW',
#  'B09FXMGQP7': 'B09FXPLZ3C',
#  'B09FXPLZ3C': 'B09FXMGQP7',
#  'B09FXJX5VM': 'B09FXMGQP7',
#  'B0B8J5NDGR': 'B0B8J4PHLZ',
#  'B0B8J4PHLZ': 'B0B8J5NDGR',
#  'B0B1MVR1F3': 'B0B1MVR1F3',
#  'B0B9B2TNL3': 'B0B7LR4ZHS',
#  'B093L3G5Y5': 'B093L3G5Y5',
#  'B00851JOXK': 'B016BYZX8M',
#  'B016BYZX8M': 'B00GEKV9KK',
#  'B00GEKV9KK': 'B0971PCY86',
#  'B01485UTS0': 'B0B5RRBFGL',
#  'B0B5RRBFGL': 'B0B8ZCSC8C',
#  'B0B8ZC7HLF': 'B0B8ZCSC8C',
#  'B0B8ZCSC8C': 'B0B8ZC7HLF',
#  'B0B9YMF7DC': 'B0B9YW21B6',
#  'B0B9YN2LMR': 'B0B9YMF7DC',
#  'B094VR7WZP': 'B094VPWRCD',
#  'B094VPWRCD': 'B094VR7WZP',
#  'B09DCL4QC1': 'B08DD7T265',
#  'B08DD7T265': 'B07NDZ3WL4',
#  'B0BJQND4NB': 'B0BJQND4NB',
#  'B00YMZBMM4': 'B00YMZBO2W',
#  'B085P1GCWJ': 'B07XQGMNNH',
#  'B015CH1JIW': 'B015CH1GTO',
#  'B07G36DF29': 'B00P8XQPY4',
#  'B00P8XQPY4': 'B00DQG9DDU',
#  'B07XDQ1PPS': 'B07XCT2Y9W',
#  'B07XCT2Y9W': 'B07XDQ1PPS',
#  'B07X2Y2NGR': 'B07X1YCC6D',
#  'B07X1YCC6D': 'B07X2Y2NGR',
#  'B07X65JZF9': 'B07X23MW7Y',
#  'B00IK95OAE': 'B01E68AVY6',
#  'B01E68AVY6': 'B01E68B1JA',
#  'B095Z2KVT7': 'B095Z2C5TJ',
#  'B095Z2C5TJ': 'B095Z2KVT7',
#  'B07GL38GJ1': 'B09LD99RMR',
#  'B09LD99RMR': 'B07GL38GJ1',
#  'B07GL39GH9': 'B0987MYHFQ',
#  'B08C566QVF': 'B0B874LX24',
#  'B0B874LX24': 'B08C566QVF',
#  'B09BF9KNXC': 'B0B9GW9S6M',
#  'B0987CWN49': 'B0932K6K4S',
#  'B0932K6K4S': 'B0931VRJT5',
#  'B0931VRJT5': 'B09324G52L',
#  'B085S3YC46': 'B09C89S7WG',
#  'B09C89S7WG': 'B085S3YC46',
#  'B09ZTZPM3R': 'B0B2JY9THB',
#  'B077HRGCYP': 'B077HRGCYP',
#  'B08GHJ3CSC': 'B08GHJ3CSC',
#  '3522306031': '352230585X',
#  'B07MZBQJHG': 'B08HN5YZS4',
#  'B08HN5YZS4': 'B07MZBQJHG',
#  'B09M3RYQLV': 'B09M3QYWP2',
#  'B09M3QYWP2': 'B08C26T2GK',
#  'B096FQMX21': 'B096FQMX21',
#  'B0B6ZS7XVS': 'B096FQMX21',
#  'B09DYP9465': 'B076CFHGNY',
#  'B0989B1R3M': 'B0989B1R3M',
#  'B08BGD1LTF': 'B08BG9J4PJ',
#  'B097Z3PZZJ': 'B08BG9J4PJ',
#  'B000WYCD5O': 'B000WYCD5O',
#  'B00I12WEYE': 'B003FSSOFC',
#  'B003FSSOFC': 'B086N92R4F',
#  'B07FLQ47DV': 'B07FLQ47DV',
#  'B06XKPB3GT': '3462002732',
#  '3462002732': 'B0BCD297DC',
#  'B07L4XJWDH': 'B09WMTRV7N',
#  'B07F8WRDKC': 'B09WMTRV7N',
#  'B08CVDP3DJ': 'B08CVDP3DJ',
#  'B004PB34SU': 'B07ZVW4P5Y',
#  'B00E5G1M0W': 'B0849T6488',
#  'B076QK2PJV': 'B076QK2PJV',
#  'B08X7BKBZK': 'B08X7BKBZK',
#  '3845849177': '3845849177',
#  '3440174883': '3440172147',
#  '3742315323': '3742315315',
#  '3742315315': '3742315323',
#  'B0B7K45YD6': 'B07CZ4DLCP',
#  'B07CZ4DLCP': 'B07CZ4DLCP',
#  'B07QLS4X84': 'B08WM2MFKF',
#  'B0BFX826K5': 'B0BFX826K5',
#  'B015Q2BCA8': 'B015Q2BCA8',
#  'B0B7K5R61Y': 'B0997J42LX',
#  'B08FXD733M': 'B08FXGNF8P',
#  'B098FD8FYD': 'B08FXD733M',
#  'B09WYW1SX9': 'B0B4HN53L8',
#  'B0BG37KXY3': 'B00OKA6PD2',
#  'B002R07IIS': 'B075LGT2TM',
#  'B0B2PVQM7Y': 'B0B2PQ6MPX',
#  'B0B2PQ6MPX': 'B0B2PSJ1NT',
#  'B08WHW73P5': 'B0B64YXCDQ',
#  'B0B64YXCDQ': 'B08WHW73P5',
#  'B09ZNFFMZF': 'B084J6SFYZ',
#  'B07R4PN3MV': 'B0B2Q2VVGP',
#  'B07XHY38PS': 'B07XHY38PS',
#  'B07CN16KSD': 'B07CN16KSD',
#  'B09QFPYX34': 'B09QFPZ9B7',
#  '3830320477': 'B093SYL61B',
#  'B0B79GTVJV': 'B0B79GTVJV',
#  '1439783462': '1439783748',
#  '1439783748': '1439783462',
#  'B09B2MQZ42': 'B0B4WPZ1KC',
#  'B0B4WPZ1KC': 'B09B2MQZ42',
#  'B09SBJTD4X': '1439783462',
#  '1439785384': '1439785279',
#  'B083NTYGGQ': 'B083NMZ9M8',
#  'B08WWYPHX9': 'B08WX3FR5L',
#  'B08WX3FR5L': 'B08WWYPHX9',
#  'B084KSHVBQ': 'B084KSHVBQ',
#  'B07MKN1XLZ': 'B08VD24FXM',
#  'B08VD24FXM': 'B093CY3PB4',
#  'B01LWUIXNM': 'B07J1XTMYB',
#  'B09GKNVHJ2': 'B01LWUIXNM',
#  'B0012F43PU': 'B00AHW312K',
#  'B00AHW312K': 'B0012F44L8',
#  'B09BK21W5R': 'B09BK21W5R',
#  'B093CGR49J': 'B08CRYFHDV',
#  'B08CRYFHDV': 'B084HG9TT6',
#  'B09C48G8NX': 'B09C493MTH',
#  'B09JCBY3FP': 'B09JCBY3FP',
#  'B09D3YLBFC': 'B09R44SLDV',
#  'B09R44SLDV': 'B09D3YLBFC',
#  'B09ZBF85J1': 'B09ZBFJB83',
#  'B09ZBFJB83': 'B09JPC7MNF',
#  'B09JPC7MNF': 'B08L51PHYG',
#  'B08L51PHYG': 'B08L529R4D',
#  'B08VDFSDK1': 'B08VDHCPCH',
#  'B0B31KQHPF': 'B0B8Z6R3H4',
#  'B0B8Z6R3H4': 'B0B8Z6R3H4',
#  'B0B4DQ5SFW': 'B09F6H1N3B',
#  'B07ZVMBMZY': 'B07ZVMBMZY',
#  'B07GWC67PW': 'B085Z8V116',
#  'B081NRCTHD': 'B075L9TD9W',
#  'B01N0IVMJA': 'B07S9PTLNZ',
#  'B07QS6ZPC6': 'B07QR1RNWP',
#  'B07QR1RNWP': 'B0B63BS78M',
#  'B01MZZGF44': 'B01J0R077O',
#  'B01J0R077O': 'B01MZZGF44',
#  'B07HGTXF95': 'B07J2R8LNL',
#  'B0B6ZX27CZ': 'B09WTX3VC2',
#  'B084Z6147W': 'B084Z6147W',
#  'B0BCWQ27W3': 'B0BCWQ27W3',
#  'B09KRSHMNX': 'B0987C5L9J',
#  'B000GB7G3C': 'B000IH31B0',
#  'B000IH31B0': 'B000IH31B0',
#  'B07DZPKCDM': 'B07DZPK6YQ',
#  'B07DZPK6YQ': 'B07DZPKCDM',
#  'B091KZ3G1Z': 'B0B2K3B61V',
#  'B0B3RV1NDX': 'B0B3RZLC9N',
#  'B00I5ABIFI': 'B00I5ABIFI',
#  'B09P2S9HLX': 'B08HCRQTKD',
#  'B00X9ZYV3U': 'B01MR8EONS',
#  'B01MR8EONS': 'B07PW3BYTF',
#  'B07HJ3HNNX': 'B072N24YXM',
#  'B08SQ8979M': 'B0BBWBP7WD',
#  'B08H8FSFFF': 'B0BBM6GX65',
#  'B0966P7KM6': 'B0966P7KM6',
#  'B08JQLKQF5': 'B08JQLKQF5',
#  '3849929043': '3845119128',
#  '3845119128': '1503742946',
#  'B084VC95CB': 'B083MT7HBW',
#  'B083MT7HBW': 'B084VC95CB',
#  'B094D3QSDP': 'B08DKT57FF',
#  'B08DKRZQ9N': 'B094D3QSDP',
#  'B094D4P112': 'B08MDSL7JK',
#  'B08MDXWFNK': 'B08MDSL7JK',
#  'B095C6FDV2': 'B095C4MVBK',
#  'B00JC4W3N2': 'B0193GTENA',
#  'B0193GTENA': 'B00JC4W3N2',
#  'B07NRG1M67': 'B07NRW9NF6',
#  'B07NRW9NF6': 'B07NRG1M67',
#  'B093CC7XJQ': 'B094R69RXL',
#  'B09PVSJBRB': 'B00MZQU4KI',
#  'B00MZQU4KI': 'B0B7JPVYJ8',
#  'B01N34V79Z': 'B01N0X4RT5',
#  'B00AKUHC6A': 'B00AKUHC6A',
#  'B005I49EH8': 'B00AKUHC6A',
#  'B06XNNNVX6': 'B08J7D2T8Z',
#  'B08J7D2T8Z': 'B06XNNNVX6',
#  'B07SJR6HL3': 'B08GG2WYWN',
#  'B000KTB14U': 'B000KT8XA0',
#  'B000KT8XA0': 'B000KTB14U',
#  'B08H8XVSPM': 'B077TFT1P4',
#  'B077T6QTZG': 'B077TFT1P4',
#  'B077TFT1P4': 'B077T6QTZG',
#  'B09LH6DMGJ': 'B06X6J4W2Y',
#  'B06X6J4W2Y': 'B06X6J4W2Y',
#  'B09QQ1F9CV': 'B06X6J4W2Y',
#  'B08GJ13GNP': 'B09STPDBWC',
#  'B00AOAIRSS': 'B00AOAJAUC',
#  'B00AOAJAUC': 'B00AOAIRSS',
#  'B00AOAIO5Y': 'B07Q39BC63',
#  'B09N9S1YLV': 'B09N7WQWFP',
#  'B09N9TVP5Q': 'B09N9Q5M43',
#  'B098XR3GXY': 'B098XPP8QQ',
#  'B007E9VXJW': 'B007E9VXJW',
#  'B09Z6H4WW7': 'B07XP678P7',
#  'B07951BDM4': 'B07FKRS59F',
#  'B0BDRQC183': 'B07J3L8X4S',
#  'B08TB4BQJQ': 'B09KM8HGBN',
#  'B08W5GLRMM': 'B08TB4BQJQ',
#  'B092VQCBRV': 'B092VQCBRV',
#  'B009GPP0IM': 'B009GPP0IM',
#  'B00FL0OJ38': 'B00FL0OJ38',
#  'B0090Y7C1M': 'B0090Y7C1M',
#  'B01LVYURVW': 'B01DO0T0X0',
#  'B01DO0T0X0': 'B08B66J4DZ',
#  'B073QSLY9T': 'B073QSVDLP',
#  'B08CRS6GPC': 'B08CRS6GPC',
#  'B088P11CQB': 'B085YD96GH',
#  'B09TMF6742': 'B08N36XNTT',
#  'B08N2QK2TG': 'B09TMF6742',
#  'B09GFWWY7N': 'B077GSDLJJ',
#  'B09VD7J226': 'B09J8V9RQQ',
#  'B09J8V9RQQ': 'B09J8V18FL',
#  'B084V4VKB6': 'B084V5FZYV',
#  'B084V5FZYV': 'B084V4VKB6',
#  'B09TR4BM3Z': 'B08GR8SG56',
#  'B09FT86B1Y': 'B09FT8B5MD',
#  'B07G1BPZ9Z': 'B07G1975ZJ',
#  'B07G1975ZJ': 'B07G1BPZ9Z',
#  'B07ZTNH6FM': 'B0B9LF2YZW',
#  'B0776YDQ9R': 'B000QB4IZ6',
#  'B0B788T4L9': 'B079M9WSBR',
#  'B079M9WSBR': 'B07NP4MCKR',
#  'B07NP4MCKR': 'B079M9WSBR',
#  'B09WY8V7FT': 'B09KXXR7M7',
#  'B09W9RS4JL': 'B0B5GHMG7F',
#  'B08KDRLPPH': 'B07Y84Y6WY',
#  'B07Y84Y6WY': 'B07V29BSWM',
#  'B07V29BSWM': 'B0BDGL4VPJ',
#  'B08XVM4P4T': 'B07Y84Y6WY',
#  'B09K5DP313': 'B096VSC7XK',
#  'B07RQ57PTM': 'B07RQ57PTM',
#  '3736318057': '3736318057',
#  '3731861623': '3731862050',
#  'B08L7YKXF7': 'B08L7ZTQ13',
#  'B08L7ZTQ13': 'B07WC26SHK',
#  'B07WC26SHK': 'B08FT4XWPK',
#  'B08FT4XWPK': 'B09WMBTQTX',
#  'B07D13JWKK': 'B07D13TXQ8',
#  'B08P4M43W7': 'B08NJ9NF7R',
#  'B098X6BQ8P': 'B098X6BQ8P',
#  'B098B6YY59': 'B00PTLSH9G',
#  'B004LU19LE': 'B00XEIX16A',
#  'B00XEIX16A': 'B07L9QNRCK',
#  'B07L9R5J29': 'B00XEIX16A',
#  'B09FF4LLM8': 'B089STSW8G',
#  'B07C3QLJ5Y': 'B07L9QNRCK',
#  'B0967LF6KW': 'B09WJ1NBHQ',
#  'B09WJ1NBHQ': 'B0967LF6KW',
#  'B09NFDC3FQ': 'B09BTMCGBC',
#  'B09BTMCGBC': 'B09NFCXNPN',
#  'B096VK777Y': 'B09H66MYWS',
#  'B07X1X5ZFV': 'B085WMBTWY',
#  'B00WLI5E3M': 'B013AZCPLS',
#  'B013AZCPLS': 'B00WLI5E3M',
#  'B06XFK2H8Z': 'B01MXLEVR7',
#  'B071G5YCS6': 'B07214QNQX',
#  'B082NW8CF9': 'B01M3NB6FB',
#  'B0832JCZC6': 'B085HHKH5P',
#  'B01GN0M6NE': 'B01LNAAEJ2',
#  'B0B971KJ3F': 'B09V7TQP63',
#  'B09V7TQP63': 'B0B971KJ3F',
#  'B09YRRSN87': 'B0999CN918',
#  'B09NSWVT8L': 'B09NSWVT8L',
#  'B00N0OHEMA': 'B0B9XP5FKT',
#  'B0B9XP5FKT': 'B00N0OHEMA',
#  'B00A128S24': 'B00A128S24',
#  'B09GLL96XD': 'B09GLJKBXY',
#  'B09GLJKBXY': 'B09GLL96XD',
#  'B00WHZ6VEU': 'B00WHZ79F0',
#  'B0B87TTGP5': 'B089FBV4DQ',
#  'B081W6LM1G': 'B081W6LM1G',
#  'B00X67CBIS': 'B00X67CIC2',
#  'B00GSSGBAQ': 'B06XQMRJHT',
#  'B06XQMRJHT': 'B091D3D7D5',
#  'B08F2FM1CN': 'B07TD515P2',
#  'B07TD515P2': 'B08KWG243P',
#  'B08YN6589V': 'B09VL43W4N',
#  'B09VL43W4N': 'B086GNGLVM',
#  'B09SL43JB9': 'B08XXHZZFQ',
#  'B08XXHZZFQ': 'B0B4SFFJSR',
#  'B09VT8MK3K': 'B003CSNV2Q',
#  'B08F3QY1QG': 'B08F3QY1QG',
#  'B09D7HVSTV': 'B09JBD41KF',
#  'B07PG98DRG': 'B07PM1Q1D2',
#  '3440174581': '1077890338',
#  '1077890338': '1657681513',
#  'B00J8O9V0E': 'B01AT5KVP4',
#  'B01AT5KVP4': 'B00J8O9V0E',
#  'B0001MQQZK': 'B0001MQR5O',
#  'B09V2JR5VQ': 'B09V2K14KS',
#  'B09V2K14KS': 'B0764CKJ67',
#  'B0764CKJ67': 'B075CNPXQW',
#  'B08GCNXGRL': 'B089N24PZD',
#  'B08L9ZKCDG': 'B089N24PZD',
#  'B089N24PZD': 'B08GCNXGRL',
#  'B083BBBX7Y': 'B08GCNXGRL',
#  'B0B58DFZD7': 'B0B58G6F1N',
#  'B09CV9DBXX': 'B09CV7NGCJ',
#  'B09CV7NGCJ': 'B0B88PCDDC',
#  'B09CV86RFW': 'B0B88PK898',
#  'B01M8HVDL5': 'B0816MB9Q3',
#  'B08GY2K8H8': 'B00AI7MFQ2',
#  'B00AI7MFQ2': 'B08GY2K8H8',
#  'B09ZTVL555': 'B09KQT2L35',
#  'B079KKFGH1': 'B09N83KL8H',
#  'B09N83KL8H': 'B079KKFGH1',
#  'B09K7H7Z8P': 'B09SPRFVWT',
#  'B09SPRFVWT': 'B09K7FHRCC',
#  'B09K7FHRCC': 'B083159W5J',
#  'B08WJBVM5G': 'B08WJBVM5G',
#  'B07SLYDMZ1': 'B08XSTGL7P',
#  'B017KPKN68': 'B07QNP618D',
#  'B07QNP618D': 'B07QPS8W89',
#  'B077ZH6ZV9': 'B08SRDXQW5',
#  'B0029MCTJ2': 'B07F354L43',
#  'B09X44M2LR': 'B09X43NZQY',
#  'B09X43NZQY': 'B09X44M2LR',
#  'B09HXCLS4X': 'B08XBB25X7',
#  'B08XBB25X7': 'B08248BRN4',
#  'B08XB3J5ZP': 'B07WQRHDVZ',
#  'B0912C4V7M': 'B09HXCLS4X',
#  'B08ZMC5CHH': 'B09HXCLS4X',
#  ...}

# %%
k = []
v = []

for item in next_item_dict:
    k.append(item)
    v.append(next_item_dict[item])
    
df_next = pd.DataFrame({'item': k, 'next_item': v})
df_next = df_next.explode('next_item').reset_index(drop=True)
df_next
# Out:
#                 item   next_item
# 0         B09W9FND7K  B09JSPLN1M
# 1         B09W9FND7K  B09JSPLN1M
# 2         B09W9FND7K  B09JSPLN1M
# 3         B09W9FND7K  B09JSPLN1M
# 4         B09W9FND7K  B078WW2WN5
# ...              ...         ...
# 15306178  B09V7T4HXD  B09QHXKZXC
# 15306179  B0B14HBDHX  B092471PYL
# 15306180  B0B14HBDHX  B09X9DSQ7V
# 15306181  B07P6QPKNL  B07P6QGKTV
# 15306182  B083FKX8ZR  B09SYYH71X
#
# [15306183 rows x 2 columns]

# %%
top1 = df_next['next_item'].value_counts().index.tolist()[0]

# %%
df_test['last_item'] = df_test['prev_items'].apply(lambda x: str2list(x)[-1])
df_test['next_item_prediction'] = df_test['last_item'].map(next_item_map)
df_test
# Out:
#                                               prev_items locale   last_item  \
# 0                            ['B082DLM3NZ' 'B089X86H73']     ES  B089X86H73
# 1               ['B071WPLND2' 'B08TMJ9SDZ' 'B07XRCLVYG']     ES  B07XRCLVYG
# 2                            ['B094V8G54H' 'B094V97YV8']     ES  B094V97YV8
# 3                            ['B0B3DQXY57' 'B0B6W3GGTM']     ES  B0B6W3GGTM
# 4               ['B0765BPD7T' 'B00V4PQY3C' 'B09HWV4MBK']     ES  B09HWV4MBK
# ...                                                  ...    ...         ...
# 56416                        ['B08GNG5FMW' 'B08Q7MJW8W']     UK  B08Q7MJW8W
# 56417                        ['B09YH16XH1' 'B09YGY96ZM']     UK  B09YGY96ZM
# 56418  ['B00EXKSNNE' 'B005DBORH8' 'B005DBORCS' 'B005D...     UK  B005DBORCS
# 56419           ['B007CJVZ1A' 'B07GCSPHNK' 'B07GCVF3N3']     UK  B07GCVF3N3
# 56420                        ['B07NBPTPD9' 'B01H2SPJGC']     UK  B01H2SPJGC
#
#       next_item_prediction
# 0               B082DL9QJZ
# 1               B00KBOJ8AI
# 2               B094V2FVPV
# 3               B0B3DQXY57
# 4               B08N17D24Y
# ...                    ...
# 56416           B08GN9FP13
# 56417           B09YH16XH1
# 56418           B005DBORH8
# 56419           B07GCSPHNK
# 56420           B00H7WWMMI
#
# [56421 rows x 4 columns]

# %%
pd.isna(df_test['next_item_prediction']).sum()
# Out:
# 1275

# %%
top1
# Out:
# 'B07QPV9Z7X'

# %%
preds = []

for _, row in tqdm(df_test.iterrows(), total=len(df_test)):
    pred_orig = row['next_item_prediction']
    pred = pred_orig
    prev_items = str2list(row['prev_items'])
    if type(pred) == float:
        pred = top1
    preds.append(pred)
# Out:
# 100%|██████████| 56421/56421 [00:02<00:00, 25229.62it/s]

# %%
df_test['next_item_prediction'] = preds
df_test
# Out:
#                                               prev_items locale   last_item  \
# 0                            ['B082DLM3NZ' 'B089X86H73']     ES  B089X86H73
# 1               ['B071WPLND2' 'B08TMJ9SDZ' 'B07XRCLVYG']     ES  B07XRCLVYG
# 2                            ['B094V8G54H' 'B094V97YV8']     ES  B094V97YV8
# 3                            ['B0B3DQXY57' 'B0B6W3GGTM']     ES  B0B6W3GGTM
# 4               ['B0765BPD7T' 'B00V4PQY3C' 'B09HWV4MBK']     ES  B09HWV4MBK
# ...                                                  ...    ...         ...
# 56416                        ['B08GNG5FMW' 'B08Q7MJW8W']     UK  B08Q7MJW8W
# 56417                        ['B09YH16XH1' 'B09YGY96ZM']     UK  B09YGY96ZM
# 56418  ['B00EXKSNNE' 'B005DBORH8' 'B005DBORCS' 'B005D...     UK  B005DBORCS
# 56419           ['B007CJVZ1A' 'B07GCSPHNK' 'B07GCVF3N3']     UK  B07GCVF3N3
# 56420                        ['B07NBPTPD9' 'B01H2SPJGC']     UK  B01H2SPJGC
#
#       next_item_prediction
# 0               B082DL9QJZ
# 1               B00KBOJ8AI
# 2               B094V2FVPV
# 3               B0B3DQXY57
# 4               B08N17D24Y
# ...                    ...
# 56416           B08GN9FP13
# 56417           B09YH16XH1
# 56418           B005DBORH8
# 56419           B07GCSPHNK
# 56420           B00H7WWMMI
#
# [56421 rows x 4 columns]

# %%
df_test['next_item_prediction'].apply(len).describe()
# Out:
# count    56421.0
# mean        10.0
# std          0.0
# min         10.0
# 25%         10.0
# 50%         10.0
# 75%         10.0
# max         10.0
# Name: next_item_prediction, dtype: float64

# %%
products_train = pd.read_csv('./raw_data/products_train.csv')
products_train.head(5)
# Out:
#            id locale                                              title  \
# 0  B005ZSSN10     DE  RED DRAGON Amberjack 3 - Steel Tip 22 Gramm Wo...
# 1  B08PRYN6LD     DE  Simply Keto Lower Carb* Schokodrops ohne Zucke...
# 2  B09MBZJ48V     DE  Sennheiser 508377 PC 5.2 Chat, Stilvolles Mult...
# 3  B08ZN6F26S     DE  AmyBenton Auto ab 1 2 3 ahre - Baby Aufziehbar...
# 4  B094DGRV7D     DE      PLAYMOBIL - 70522 - Cavaliere mit grauem Pony
#
#    price         brand              color              size    model  \
# 0  30.95    RED DRAGON                NaN               NaN  RDD0089
# 1  17.90   Simply Keto                NaN  750 g (1er Pack)      NaN
# 2  68.89    Sennheiser       Multi-Colour          One size   508377
# 3  18.99  Amy & Benton         Animal Car               NaN    2008B
# 4   7.17     PLAYMOBIL  Nicht Zutreffend.           OneSize    70522
#
#              material author  \
# 0                 NaN    NaN
# 1                 NaN    NaN
# 2          Kunstleder    NaN
# 3  aufziehauto 1 jahr    NaN
# 4        Polypropylen    NaN
#
#                                                 desc
# 0  Amberjacks Steel Dartpfeile sind verfügbar in ...
# 1  🌱 NATÜRLICHE SÜSSE DURCH ERYTHRIT - Wir stelle...
# 2  3.5 MM BUCHSE - Kann problemlos an Geräte mit ...
# 3  【Auto aufziehbar】: Drücken Sie einfach leicht ...
# 4                                    Inhalt: 1 Stück

# %%
id2title_dict = defaultdict(str)
for i, product in tqdm(products_train.iterrows(), total=len(products_train)):
    k = f"{product['id']}_{product['locale']}"
    if type(product['title']) != str:
        v = ''
    else:
        v = product['title']
    id2title_dict[k] = v
id2title_dict
# Out:
# 100%|██████████| 1551057/1551057 [01:09<00:00, 22315.86it/s]
# defaultdict(str,
#             {'B005ZSSN10_DE': 'RED DRAGON Amberjack 3 - Steel Tip 22 Gramm Wolfram Profi Dartpfeile Set mit Flights und Schäfte',
#              'B08PRYN6LD_DE': 'Simply Keto Lower Carb* Schokodrops ohne Zuckerzusatz (750g) - Vollmilch Schoko Drops zum Naschen oder Backen - Gesüßt mit Erythrit statt Zucker - Ideal für Low-Carb & Ketogene Ernährung',
#              'B09MBZJ48V_DE': 'Sennheiser 508377 PC 5.2 Chat, Stilvolles Multi-Plattform On-Ear Headset PC, Kopfhörer mit Kabel & Unterricht, für Laptop, Telefon & PC & EPOS I Sennheiser PC 8 USB Headset, Schwarz',
#              'B08ZN6F26S_DE': 'AmyBenton Auto ab 1 2 3 ahre - Baby Aufziehbares Auto ab 1 Jahr - 4pcs Spielzeugautos Set für Mädchen',
#              'B094DGRV7D_DE': 'PLAYMOBIL - 70522 - Cavaliere mit grauem Pony',
#              'B09JNNBDH5_DE': 'URBZUE Handwärmer, 10000mAh USB aufladbar und Digitalanzeige, elektrischer Taschenwärmer mit Mehreren Heizstufen von 40-60 ° C, tragbares warmes Wintereschenk für Frau, Mann, Kinder,rosagold',
#              'B08R62WZ1Y_DE': 'Kinderkopfhörer Bluetooth, Mädchen Katzenohr Kopfhörer Over-Ear mit LED-licht Faltbare Stereo Kopfhörer Kabellose, Kopfhörer Kinder mit Mikrofon, Micro SD/TF, für Handy/Tablet/PC (Lila)',
#              'B09WK4YNX8_DE': '8 Stück Herd Schalter Schutz, Küche Gasherd Knob Abdeckungen, backofen kindersicherung, Herdschutz kinder, Home Backofen Gasherd Transparente Schutzhülle Kindersicherung, geeignet für Kochgeschirr',
#              'B07KTKFYYS_DE': 'AVANA Edelstahl Ausstechformen 12 Stück Ringe Keksformen Cutter Set Speiseringe Keks Cookie Rund Plätzchen Ausstecher mit Aufbewahrungsbox',
#              'B0B9MPKYJK_DE': 'Amstory Stirnlampe LED Wiederaufladbar Joggen Kopflampe, Camping Stirnlampe COB Headlamp mit Rotlicht Sensor 7 Modi USB Aufladbar Leicht Wasserdicht Taschenlampe für Laufen Wandern Angeln - 2 Stücke',
#              'B0B5RMZ9FQ_DE': 'Halloween deko gruselig gartendekoration Hexe, Hängende Geister Party Dekoration Skelett Hängedeko Knochenmann Dekoskelett Gruselig Wanddeko Hängedekorationen für Hof Party Bar (kriechender Geist)',
#              'B000LXWTUU_DE': 'Canina 74161 8 Petvital Verminex, 50 ml (1er Pack)',
#              'B06XKPB3GT_DE': 'Kreise (Standard Edition)',
#              'B07Q3471S2_DE': 'LED Ringlicht mit Stativ & Handyhalter 10 Zoll, Dimmbare Tischringlicht für YouTube-Videoaufnahmen, Selfie, Live-Stream, Makeup/Fotografie mit 3 Beleuchtungsmodi und 10 Helligkeitsstufen',
#              'B0BG4V5PBQ_DE': 'Wecker Digital,LED Display Uhren mit Intelligentem Helligkeitssensor, Batteriebetriebene Kinder Wecker mit Uhrzeit, Datum, Temperatur, Schlummerfunktion für Zuhause,Schlafzimmer,Büro,Reisen (Rosa)',
#              'B094V3614V_DE': 'LIVACASA Bauchtasche Mode Damen Gürteltachse Metallic Hüfttasche Mädchen Wasserabweisend Schultertaschen 3 Fächer Kinder Hipbag zur Party Festival Otdoor Travel Lila+Blau',
#              'B07K27BTM8_DE': 'JewelCandle "Magical Winter Duftkerze mit Überraschungsschmuck, silberfarben',
#              'B078RFH53S_DE': 'Velinda Kinderbett Hausbett Spielbett Abenteuerbett Einzelbett mit Absturzsicherung (Farbe: weiß)',
#              'B08K8MHZ4N_DE': 'SAMMART 41L Collapsible Plastic Laundry Basket - Foldable Pop Up Storage Container/Organizer - Portable Washing Tub - Space Saving Hamper/Basket (Weiß/Seegrün)',
#              'B087JPRYFZ_DE': "L'Oréal Paris Elvital Haarserum ohne Silikone, Hitzeschutz für langes, widerspenstiges Haar, Ohne Ausspülen, Haaröl mit pflanzlichen Proteinen und Kakaobutter, Dream Length No Frizz Serum, 1 x 100 ml",
#              'B00V5BR1RS_DE': 'VTech Baby Flitzer - Parkgarage – Interaktives Spielzeug mit Abschleppwagen, Aufzug, Rutsche, Tankstelle u. v. m. – Für Kinder von 1-5 Jahren',
#              'B07K15DDKQ_DE': 'NTS Nähtechnik 6mm 50m Baumwollkordel Kordel Seil in vielen Farben (dunkelgrün)',
#              'B0B3JRWV4S_DE': 'CUWELT 700 Stück Mini Holzsterne, Gemischt Kleine Holz Sterne 10/12/15/20mm, Stern Holzscheiben zum Basteln und Dekorieren, Verschönerung Holzstern für Weihnachtsbaum Anhänger Hochzeit DIY Baumschmuck',
#              'B084GYK4B9_DE': 'Bad Candy Vape Aromakonzentrat Angry Apple, Shake-and-Vape zum Mischen mit Basisliquid für e-Liquid, 0.0 mg Nikotin, 20 ml',
#              'B08BR2NLTN_DE': 'Hi-Spec 18V Bohrschrauber mit Akku und Multi-Bit-Satz 58 tlg. DIY Akkuschrauber und Bohrmaschine mit S2 Stahl-Bit-Satz für Metall, Holz & Mauerwerk (Batterie inkl.) …',
#              'B096B95D9Y_DE': 'Buddy´s Bar - Barista Edition, Reinigungspinsel Set für Kaffeemaschinen, Bürstenset, gebogener Pinsel: 13,5 cm, gerader Pinsel: 12,5 cm lang, Barista Pinsel mit Haaren aus Nylon, Walnuss-Holzgriff',
#              'B07J65G9DD_DE': 'WLAN Stick 1200 Mbit/s, Techkey USB 3.0 WLAN Adapter 802.11 AC Dualband WiFi Adapter 2,4 GHz / 300 Mbit/s 5 GHz / 866 Mbit/s 5dBi High Gain-Antenne für Windows 11-7 / XP/Vista/Mac OS 10.9-10.15',
#              'B07XPFNBHW_DE': 'JOYIN 170 Stück Mehrfarbige Murmelbahn Marble Run Set mit 120 Kunststoffteile 50 Glasmurmeln, Bausteine, Kugelbahn Lernspielzeug, Bausteinspielzeug, Konstruktionspielzeug für Kinder',
#              'B0868TBNZZ_DE': 'Audi collection Isolierbecher, 1 Stück (1er Pack)',
#              'B000S1KWPE_DE': 'Top Gun (Blu-ray)',
#              'B0916LVFGG_DE': 'BigDean 24x Marmeladengläser 125ml - Einmachgläser klein, Gläser zum Verschenken, Schraubgläser - Made in Germany - Sturzgläser mit Deckel TO 66 - Rot kariert',
#              'B087BKQ98X_DE': 'wandmotiv24 Leinwandbild 260 g/m ² - Foto-Collage mit 3 Fotos - Fotogeschenk - Geschenk für Freunde und Familie - Kunstdruck querformat 30x20cm (BxH) - M0002',
#              'B01MREMJ90_DE': 'The New York Doll Collection 11 Zoll /28cm Afroamerikaner weich Körper Puppe im eschenkkarton (Bonus Schnuller inklusive)',
#              'B09QMCVW6P_DE': 'BOSS Herren R-Neck T-Shirt, 3er Pack Classic, Assorted 962, L',
#              'B09JCC7FVK_DE': 'NIULAA 2er Set Wolle Kissenbezug 50x50 cm Weiß Samt Boho Deko Kissen Flauschig Dekokissen Fell Kissenbezüge für Sofa Schlafzimmer Modern Kissenhülle Bezug Sofakissen Zierkissen',
#              'B00IK6I6YS_DE': 'Donnie Darko [dt./OV]',
#              'B00V07XW3E_DE': 'CABLEDECONN 4-in-1 Multifunktions-Displayport auf HDMI/DVI/VGA Adapterkabel mit Micro-USB Audio-Ausgang, Stecker auf Buchse, Konverter, unterstützt 3 Monitore gleichzeitig',
#              'B07PNR4KM2_DE': 'd-c-fix Klebefolie Folie Selbstklebefolie 200x45 cm Holzdekor Holzoptik Holzdesign Holz Eiche Sheffield Umbra',
#              'B0B8YBSMJ1_DE': '250 Stk. Sterne Aufkleber Glitzer Sticker Silber Weihnachtssticker Weihnachtsaufkleber Weihnachtsdeko Selbstklebend zum Basteln DIY Geschenke Deko für Weihnachten Hochzeit Geburtstag (Silber)',
#              'B06XTTLZ1B_DE': 'KIKO Milano 3D Hydra Lipgloss 10 | Pflegender Lipgloss Mit 3D-Effekt',
#              'B0009585PI_DE': 'Trixie 2288 Dog Activity Trainings-Discs, ø 4,5 cm, 1 Stück (1er Pack)',
#              '3954531038_DE': 'Die 50 gesündesten 10-Minuten-Rezepte (Schnell und gesund kochen, Gesund-Kochbücher BJVV)',
#              'B09TV4BNB9_DE': 'Adress-Stempel Textstempel easyprint 5 - 70x25mm - 6 Zeilen - (Abdruckfarbe Rot) mit Wunschtext personalisierbarer Namensstempel oder Firmenstempel - Lieferzeit 24-48 h',
#              'B09TLCZ14D_DE': 'Topcroft ® Pommesschneider - 2 Einsätze - Rutschfester Gummifuß - Pommes Schneider Gerät - Spülmaschinengeeignet - Frische Pommes - Pommes Frites Schneider',
#              'B075TL67K8_DE': 'Coenzym Q10 hochdosiert, 200 mg pro Kapsel, vegan, 120 Kapseln für 4 Monate, 98% Ubichinon mit optimaler Bioverfügbarkeit, ohne unnötige Zusatzstoffe, Made in Germany',
#              'B07NWCJZWV_DE': 'Vicloon ELSA Set, Eisprinzessin Set，ELSA Handschuhe, Pfirsichherz Krone, Zauberstab, Halskette, Ring, Ohrring, Clip-On Toupet, Set von 9',
#              'B07DM8V3KS_DE': 'Philips Avent Natural-Sauger (Modell SCF044/27)',
#              'B09WK5NBZ1_DE': 'Legezon Kinder Regal für Tonie Box und Hörfigurens,Luftballon Passend für über 17+ Toniefiguren,Magnetisch Beliebig Fixierbar,Für Jungen und Mädchen zum Spielen und Sammeln(Wolke)',
#              'B09L85HNCT_DE': 'KETEEN Glitzer Handyhülle für Samsung Galaxy S20 FE Hülle Transparent Ultradünne Marmor 360 Grad Vollschutz Hülle Galaxy S20 FE Stoßfest TPU Robust Bumper Outdoor Schutzhülle für Samsung S20 FE, Rosa',
#              'B002RAWQ3K_DE': 'UNITEC Universal-Schnurdimmer 20-500VA, LED Dimmer für dimmbare LED Leuchtmittel, schwarz',
#              'B0BGHXC7CL_DE': 'Yogi Tea Adventskalender 2022',
#              'B07Y25MGQL_DE': 'Kelay Key Shell for Citroen C2 C3 C4 C5 C6 C8 Peugeot 107 207 307 307S 308 407 607.2 Buttons CE0536 HU83',
#              'B01L7456JW_DE': '10 Stück Wärmepflaster für Regel- und Periodenschmerzen - langanhaltende Wärme bis zu 8 Stunden, schmerzlindernd, hypoallergen - Maße: 22 x 9,5 cm',
#              'B07QBL9HYF_DE': 'MW.Shop.24 Kokos-Mulchscheibe - 28 cm/Kübelabdeckung/Winterschutz für Topfpflanzen/Pflanzenschutzmatte/Unkrautschutzmatte',
#              'B0B59DRXBT_DE': 'GOYJOY Hundekäfig für Auto, groß, tragbar, faltbar, klein und mittelgroß, Polymermaterial, Kratzfest und langlebig, Gelb',
#              'B07ZH9JTM4_DE': 'Alaskaprint 60x SK5 Cuttermesser Klingen 18mm Teppichmesser Klingen Cuttermesser Ersatzklingen Cuttermesser Abbrechklingen 18mm Cuttermesser Klingen 18mm',
#              'B08JQL5F31_DE': 'CSL - 15m CAT.8 Netzwerkkabel Outdoor 40 Gbits - LAN Kabel Patchkabel Datenkabel - CAT 8 High Speed Gigabit Ethernet Cable - 40000 Mbits Glasfaser - Abriebfest – ölbeständig – wasserfest – IP66',
#              'B08ZNQD1NL_DE': 'CaseNN Kompatibel mit Samsung Galaxy S9 Hülle Handyhülle Premium Leder Flip Case Magnetisch Klapphülle Wallet Lederhülle klappbar Schutzhülle Bumper mit Schlüsselanhänger - Wein Rot',
#              'B07QCQK6CV_DE': 'Der mit dem Wolf tanzt',
#              'B00VW4SYQ0_DE': 'Erborian BB Cream mit Ginseng. Unebenheiten kaschierende Grundierung für eine babyweiche Haut. 5-in-1 getönte koreanische Gesichtspflege mit Sonnenschutzfaktor LSF 20 – Erborian BB-Cream Clair – 15 ml',
#              'B0BD7145W7_DE': 'Auto Lufterfrischer | Autoerfrischer Aufhänger Diffusor | Berry Duft Parfüm | Auto Duft gegen Gerüche | Duftbaum Auto für Langanhaltenden Duft im Taxi, Büro, Zuhause | Geschenke für Frauen Männer',
#              'B0B5DDKVPD_DE': 'Folienschneider, Frischhaltefolie abroller, Folienspender Aus Bambus, Kitchen Organizer für Aluminiumfolie, Frischhaltefolie, Pergamentpapier, Zinnfolienspender, kompatibel mit 30 cm Rollen',
#              'B0744DTMHH_DE': 'iDiskk 128G Lightning USB-Stick für iPhone MFi-zertifizierter Foto-Stick für iPhone iPad Speicher iPhone USB-Flash-Laufwerk für iPhones Macbooks und PCs',
#              'B09LYVGMJV_DE': '2022 Upgraded Handyhülle für Samsung Galaxy S22 Hülle Leder [Mit S22 Schutzfolie] für Samsung S22 Hülle Klappbar Leder Flip Wallet 360 Grad Stoßfeste Case Schutzhülle für Samsung Galaxy S22 5G Hülle',
#              'B0953TN3KH_DE': "BAKUGAN 'Geogan Rising' Ultra Ball 1er Pack, unterschiedliche Varianten",
#              'B09J13MPFJ_DE': 'Taschenkalender A7 Folie 2022',
#              'B08VGQG3VP_DE': 'Iberiagifts - Hundemarke Pfote mit Gravur für kleine bis mittelgroße Hunde oder Katzen - Plakette graviert personalisiert (Grün)',
#              'B07CKPD4RP_DE': 'com-four® 3X Brotdose für unterwegs - Lunch-Box mit Trennwänden - Vorratsdose',
#              'B099RB4X99_DE': 'Hezbjiti Lichtervorhang mit 400 LEDs, 10m, LED-Lichterkette, 8 wasserdichte Lichterkette mit 75 Tropfen, Dekoration für Party, Hochzeit, Balkon, Fenster, Wand, Hof, Schaufenster, Garten, Weihnachten',
#              'B08JVGH7RN_DE': 'MERISH Boxershorts Herren 8er Pack S-5XL Unterwäsche Unterhosen Männer Men (XXL, 216i 8er Set Mehrfarbig)',
#              'B08BPH1WMD_DE': 'SET MIT 6 STÜCK einfachen Aufbewahrungsboxen aus FSC-Zertifiziertem papier - BLUMEN, mehrfarbig',
#              'B09D89LNLV_DE': 'DeTec. 7 kW Benzin Stromgenerator DT-LB7500E-3, 230V AVR 400V, 25 L Tankvolumen, Starkstrom',
#              'B08DKHWNVH_DE': 'WAVVE Bettwäsche 155x220 3teilig Weiß - Winter Bettbezüge 155 x 220 Sets mit 80x80 cm Kissenbezug, Winterbettwäsche Weiss für Einzelbett, Weich Bettbezug mit Reißverschluss',
#              'B07ZHZPXZ7_DE': 'Bakugan Ultra, Pyrus Vicerox, 7,6 cm große Sammelfigur und Sammelkarte, für Kinder ab 6 Jahren',
#              'B09YRG6FPR_DE': 'LETTAS Baby Kindersitz 360 Grad drehbar Isofix und Top Tether SIPS Gruppe 0+/1/2/3, 0-12 Jahre, 0-36kg, ECE R44/04, ADAC (Schwarz mit Anti-Aufgeben)',
#              'B07SJ6SMXH_DE': 'MIULEE 2er Set Streifen Kissenbezüge Kissenhülle Leinenoptik Sofakissen Dekorative Kissenbezug Dekokissen Deko Couchkissen Bezug für Sofa Büro Couch Schlafzimmer Wohnzimmer 50x50 cm Kaffee',
#              'B0B2KKWHKF_DE': 'CCnutri Elastisches Nylon Armband Kompatibel mit Apple Watch 38mm 40mm 41mm 42mm 44mm 45mm 49mm, Stoff Geflochtenes Sport Band Damen Herren für iWatch Ultra SE Series 8 7 6 5 4 3 2 1, 4 Stück',
#              'B01MXIDQOS_DE': 'LEDGLE 8er Stück LED Lichterkette Batterie Kupfer Drahtlichterkette Warmweiß 1.2M&24LEDs Lichterketten Weihnachten Batteriebetrieben wasserdichte Lichter Flasche Dekoration',
#              'B0B772VMPH_DE': 'Tayknyco Warm Decke Sofa Kuscheldecke Flauschig Winter Dicke Couchdecke Grün 150x200 cm XL',
#              'B0B8VXQFRL_DE': 'bubbacare Nasensauger Baby, Nasenreiniger&Ohrenschmalz-Entferner 4 Silikon-Rotzsaugerdüsen, Nasensauger Baby Staubsauger für Kleinkind, Neugeborene, Kleinkinder Sichere Hygienische, Blau-02',
#              'B07RF96S2K_DE': 'Run out sports Elastische Schnürsenkel ohne binden Schnellverschluss | Gummi Schuhsenkel | Schnellschnürsystem für Kinder, Senioren, Damen, Herren reflektierend - 12 Farben (schwarz)',
#              'B01NBLDOJN_DE': 'Vitamin D3 20.000 I.E + Vitamin K2 200 mcg Menaquinon MK7 Depot - 180 Tabletten - 99,7+% All-Trans - Laborgeprüft - Vegetarisch - Hochdosiert - Premium Qualität',
#              'B08PW1VS3R_DE': 'Pizzaschieber für Pizzastein, Pizzaschaufel Holz, Schneidebrett aus Holz, Pizza Schaufel für Backofen und Grill, Pizza Peel für Pizzawender, Zubehör für Küche, Schneidebrett (2)',
#              'B08H21WG6P_DE': 'GIM Wireless Charger, 3 in 1 Qi-Zertifiziert Induktive Ladestation, max. 10W kabelloses Ladegerät, kompatibel für iPhone 12/11/SE/XR/XS/X/8, iWatch 1/2/3/4/5/6 und Airpods, Samsung, Huawei usw, weiß',
#              'B0B4QQTGTR_DE': 'Musselintücher für Babys 5 Stück,100% Baumwolle Weiche Baby Handtuch,Weiche Absorbierende Musselin Spucktuch Mehrzweck Baby Gesichtstüche für Jungen und Mädchen,22x23cm Zufällige Farbe',
#              'B0881P6YFK_DE': 'iHealth thermometer für erwachsene von ihealth, infrarot-stirn-thermometer für erwachsene und kinder, touchless digital baby thermometer mit fieber-indikatoren, nichtkontaktthermometer (pt2l)',
#              'B00IK6JWZK_DE': 'Idiocracy',
#              'B0834WLBBF_DE': 'HyFanStr Handtaschen Organizer Nylon, Taschenorganizer Tasche in Tasche Organizer Innentaschen für Handtaschen mit Schlüsselkette,Schwarz,Mittel',
#              'B0B3LS7QJQ_DE': 'Kimimara LED Brille Cyberpunk - Party Leuchtbrille Leuchtende Visor Glasses Rave Brille - Donner',
#              'B005IQ2ARM_DE': 'Versace Red Jeans Woman Edt Spray 75ml',
#              'B0B6VGP3X9_DE': 'Schutzfolie für Huawei P30 Pro Glas folie,9H Härte Schutzglas, Kratzschutz, Blasenfrei, HD Klar, 3D Vollständige Abdeckung, Gehärtetem Glas Displayschutz für Huawei P30 Pro [2 Stück]',
#              'B08B85T2J4_DE': 'FURTALK Damen Kaschmir Schal Warmes Halstuch Großer Feinstrick Winter Schlauchschal',
#              'B0B4X29L7T_DE': 'Buchstabensalat Rätselbuch für Kinder: 55 Wortsuch Rätsel für Jungen und Mädchen ab 8 Jahren: toller Rätselspaß | Wörter suchen mit Lösungen | Wortgitter mit spannenden Kategorien',
#              'B076G629HF_DE': 'COSCO Shifter 135kg Multi Funktion Klappbar Handwagen und Sackkarre (Blau), 42.3*34.9*125.1 cm',
#              'B093GH3HK6_DE': 'LinStyle Kinder Holzspielzeug Angelspiel, Spielzeug ab 2 Jahre, Montessori Lernspielzeug Frosch Fische Angeln Spiel, Weihnachts Spielzeug Geschenk Mädchen Junge 2 3 4 5 Jahre',
#              'B07668GJP6_DE': 'fischer FIXtainer - Dübelbox mit DUOPOWER Universaldübel Sortiment - Für zahlreiche Baustoffe und vielfältige Anwendungen - DUOPOWER 6 x 30, 8 x 40, 10 x 50 - 210 Teile - Art.-Nr. 535968',
#              'B08B3GX3ZJ_DE': 'SONGMICS Mülleimer für die Küche, 3 x 8 Liter, Abfalleimer aus Metall, 3-in-1 Treteimer, Mülltrennung, Mülltrennsystem, mit 15 Müllsäcken, einfach zu reinigen, Stahl, weiß-grau LTB24WT',
#              'B07XG8JP9L_DE': 'LaLe Living orientalisches Tablett - Tepsi - rund aus Eisen in Gold, Ø37cm zur Verwendung als Serviertablett oder Dekotablett für Kerzen, Vasen oder Adventskranz',
#              'B079QB6LCR_DE': 'Magnetarmband Handwerker Geschenke [2022] Männer Geschenke für Handwerker Gadget - Geschenk Mann Geschenk für Männer Geschenk - Herren Geschenke für Männer Gadgets für Männer Männergeschenke',
#              'B0BHWPR939_DE': 'T22 LED Glühbirne Bernstein Glas Vintage Edison Röhrenbirnen E14 220V Glühbirne,10 Watt äquivalent 2200K Ultra Warm White Birnen,100 Lumen nicht dimmbar,100er-Pack',
#              'B0BG2WKWWV_DE': 'Source of Nature® | NMN | 30g | Uthever® NMN | Nicotinamid-Mononukleotid über 99,9% | Echtheit zertifiziert | Premium Qualität | NAD-Booster',
#              'B09V1G76T1_DE': 'Bullet Journal dotted A5 mit Gummiband [Travel the World] 156 Seiten | Notizbuch gepunktet, Tagebuch von Trendstuff by Häfft | nachhaltig & klimaneutral',
#              'B0971M2F8R_DE': 'HappyDoo - Kindergeschirr Set Mit Saugnapf - Babyteller Mit Saugnapf + Anti-Rutsch Schüssel + Löffel und Läzchen Aus Silikon - BPA Frei - Rosa - Baby Teller Mit Saugnapf - Kinderteller',
#              'B09G2HSPY9_DE': 'Granbest Shaggy Teppich Hochflor Langflor Teppiche für Wohnzimmer Moderner Flauschiger Kurzflor Teppich Rutschfester Teppich für Altere und Kinder（120cm*170cm，Grau）',
#              'B08944LJHT_DE': 'Addams Family',
#              'B09YR3MWCK_DE': 'soosable Schwarz Geschenkbox Set, [1 Set] Faltbare Magnetische Geschenkbox mit Schleife + Einkaufstasche + 20g Raffia Hamper Shreds + Karte, Dekorative Box für Geburtstag, Neujahrsgeschenkverpackung',
#              'B08ND18XT6_DE': 'Airpods Schutzhülle Hülle Kompatibel mit AirPods 2 & 1, KOKOKA Silikon AirPods Schutzhülle hülle LED an der Frontseite Sichtbar Stoßfeste Schutzhülle, Deep Green',
#              'B09NZBDB7Y_DE': '312 Stück Münzalbum Münzsammlung, Coins Aufbewahrung Sammelalbum für 20 25 27 30 38 46mm Euro Münzen. Sammelhüllen Organizer Box für Münzsammlung Zubehör, Geldwährung, Pfennige, Viertel -Schwarz',
#              'B08L56S5BF_DE': 'Dripex Weinregal Bambus Weinflaschenregal 7 Ebenen Flaschenregal für Keller Küche 27 Flaschen 0,75 und 1 Liter 94 x 29 x 47CM',
#              'B09T76TBS7_DE': 'Mars Gaming MCPU33, Dual FRGB CPU Kühlkörper, 3 Heatpipes HCT, TDP 140W, Ultra-quiet PWM 11cm Lüfter',
#              'B08M63GCY5_DE': 'Travelite Handgepäck Rucksack / Tasche erfüllt IATA Bordgepäck Maß, Gepäck Serie KICK OFF: Praktischer Rucksack für Urlaub und Sport, 006912-22, 50 cm, 35 Liter, Petrol, 37 x 50 x 20 cm',
#              'B08ML31GMS_DE': 'ekavale - Kleine Schultertasche aus Wasserabweisendes Nylon – Handtasche für Damen & Mädchen - Crossbody Bag - Leichte Umhängetasche (Grau)',
#              'B09WKCHZ31_DE': 'SURFOU 3 in 1 Wireless Charger, Magnetische Kabelloses ladestation, Induktive Ladegerät Kompatibel für iPhone 14/ pro/max/13/ pro/Mini, AirPods 3/2/pro, iWatch 7/6/5/4/3, More Qi Phones',
#              'B07YZF6Z33_DE': 'Entlüftungsroller Set: 50 cm Entlüftungswalze + Nylon-Nagelsohlen [35 mm] (fertig montiert) + Stehrakel Großflächenrakel 560 mm - Betonentlüfterrolle mit Spritzschutz Stachellänge: 11 mm',
#              'B093V64P7V_DE': 'ZENGVEE 3er Pack Sport Tshirts Herren Laufshirt Kurzarm Schnelltrocknend Atmungsaktiv Sport Shirt Männer Sportshirt Herren Kurzarm Trainingsshirt Herren(520-Black Gray Green-M)',
#              'B08LK197RM_DE': 'Iris & Lilly Damen Hipster-Unterwäsche Baumwolle und Spitze, 5er-Pack, Hellbeige, 38',
#              'B06X6MZ3KP_DE': 'Alnatura Bio Haferdrink, ungesüßt, laktosefrei, vegan, 8er Pack (8 x 1 l)',
#              'B09NY742DK_DE': 'Pearl Angeli Weiches Echtes Leder Handy Umhängetasche - Handytasche Geldbörse Damen RFID Schutz kleine Crossbody Tasche (A-Schwarz)',
#              'B097P1HRPW_DE': 'künstliche Blumen kunstblumen deko Blumen künstlich Pflanzen seidenblumen Rosen deko kunstblumen wie echt plastikblumen DIY Scrapbooking Girlande Rosen Blume Dekoration 30stücke 3,5cm (Mehrfarbig)',
#              'B08QS4TNDR_DE': 'Sennheiser EPOS Impact SC 60 USB ML beidseitiges UC-Headset mit In-Line Call Control Zertifiziert für Skype for Business, 9734329000',
#              'B07G19G4GL_DE': 'Everanimals rutschfeste Napfunterlage Hund Katzen - Silikonmatte Fressnapf-Unterlage, 50x30cm',
#              'B07MH5T4NK_DE': 'Amoui Kochschürze Grillschürze Männer Damen Schürze Küchenschürze Baumwolle + Polyester Lange Latzschürze mit Zwei Taschen',
#              'B07WWJ4J3L_DE': 'deAO 13-teiliges Spielzeugeisenbahn-Set für Kinder mit Scheinwerfer, Rauch, realistischen Klängen, 3 Wagen und 11 Fuß-Spur - Tolles Accessoire für Kinder und Weihnachtsdekoration (ROT oder GRÜN)',
#              'B0B5CY5T87_DE': 'KVM Switch, eppfun 4K HDMI & USB KVM Switches for 2 PCs, für Monitor, Mouse, Keyboard, Printer - Unterstützt USB Audio Adapter',
#              'B08L2DHYPH_DE': 'IronMaxx Protein Chips 40 High Protein Low Carb, Geschmack Hot Chili, 50 g Beutel (1er Pack)',
#              'B09BF18ZBT_DE': 'CJBIN Venezianische Maske Damen, 12 Stück Augenmaske Sexy, Sexy Maske Masquerade Maske Damen Sexy Flexible Lace Masks für Halloween, Fancy, Dress Maskenball Kostüm, Karneval Party, Schwarz',
#              '3840189624_DE': 'Helme Heine Familienplaner Buch A5 2023 - Kalenderbuch - Taschenkalender mit 5 Namensspalten, Einstecktasche, Lineal, Schulferien - 160 Seiten - 15,2 x 23,2 cm',
#              'B09FG6W73L_DE': 'LANDICI 13 13,3 Zoll Laptoptasche Laptophülle,Laptop Schultertasche Wasserdicht Notebook Tasche Notebooktasche für 13,3" Macbook Air|Dell XPS,13"/14" Macbook Pro,13,5" Surface Book 3|Laptop 4,Grau',
#              'B0B3D7FKZY_DE': 'JETech Hülle für iPad 10,2 Zoll (9./8./7. Generation, 2021/2020/2019), Schützende Harte Rückenschale Weiche Berührung Tablet Ständerabdeckung, Auto Wachen/Schlafen (Blau)',
#              'B0015ZCGL0_DE': 'WMF Diadem Plus Topfset Induktion 4-teilig, Kochtopf Set mit Glasdeckel, Cromargan Edelstahl poliert, Induktions Töpfe Set unbeschichtet',
#              'B0BJW49PK8_DE': 'Himmelsflüsterer - Duftkerze im Glas - Muttertagsgeschenk | Mittelgroß | rot | Bratapfel Duft | Handgemacht | 100% Sojawachs | 200 g Wachs | 50h lange Brenndauer | Geschenke zum Muttertag',
#              'B08KY3VZ3J_DE': 'Vicco Couchtisch Guillermo Wohnzimmertisch Beistelltisch Holztisch Kaffeetisch 90 x 50 cm (Weiß-anthrazit)',
#              'B07Q8QZ1ZF_DE': 'Philips - Snow Edition - 128 GB USB 2.0 - Sonnenaufgangsorange',
#              'B08R8HX27D_DE': 'HENNEZ Toilettenpapierhalter Schwarz Matt - SCHRAUBENMONTAGE - Vintage Klopapierhalter - Klorollenhalter Toilettenpapierhalter Vintage - WC Papier Halterung WC Rollenhalter',
#              'B0B587ZBKT_DE': 'WOLTU Kinder Bücherregal Wandregal, Bücher-Organizer mit 3 Ablagen, Kinderregal für Buchaufbewahrung, aus Kiefernholz E1 MDF, für Kinderzimmer Spielzimmer, Grau',
#              'B000FNIOG4_DE': 'WMF Clever&More Schraubdeckelöffner 6 cm, Drehverschlussöffner, Kunststoff, Cromargan Edelstahl',
#              'B07HX679CQ_DE': 'Wicked Chili DVBT2 Antenne kompatibel mit HD TV Receiver Samsung, Xoro, Dyon, TechniSat, Digitalbox, Freenet, Magnetfuß für innen und außen (starker DVB-T2 HD Empfang, Magnetfuß, 3m Koaxialkabel)',
#              'B01N5RES79_DE': 'Powerplus Starthilfe Set POWE80090 für Autobatterie - Powerstation als Pannenhilfe Set für Kfz Batterie - Schnellstartsystem und Starthilfe für Ihr Auto mit 12 V und 4 in 1 Funktion',
#              'B082YNW3WH_DE': 'Bosch Professional 18V System Akku-Bohrschrauber GSR 18-2-LI (Drehmoment, max. (max. Drehmoment (hart/weich): 63/24 Nm, inkl. 2x2,0 Ah Akku, Ladegerät GAL 18 V-20, L-Case)',
#              '3840191963_DE': 'Gabi Kohwagner: Mein persönlicher Kalender 2023 - Monatsplaner mit viel Platz für Termine und Notizen - 30 x 24,3 cm (geöffnet 30 x 48,6 cm)',
#              'B01MZ6FPV0_DE': 'Glückwunschkarte zum 50. Geburtstag ~ Noch lange kein Grund, älter zu werden',
#              'B082BHJGZM_DE': 'Jacobs 2in1 Instant Coffee Sticks, 10 Portionen pro Portion (6 Stück)',
#              'B09YVCLL1G_DE': 'ISOLATECH e27 Lampenfassung in Weiß mit Schalter 3,5m Kabel Schraubring 1Stk.',
#              'B08P7S7SF8_DE': 'ORIGINAL Arnica Globuli in Potenz C30 | Höchste Qualität aus Deutschland',
#              'B07JYQ23M1_DE': '1m Battery Powered RGB LED Strip Lights Flexible Rope Lighting with Battery Power Supply Box and 24 Keys RF Remote Controller',
#              'B012I6GBX8_DE': 'Milupa Milumil Pre Babynahrung, Anfangsmilch von Geburt an, Baby-Milchpulver, (1 x 800 g)',
#              'B09BTSDSJ5_DE': 'Kukuje Churpi - Das Stück Himalaya für deinen Hund - Kauknochen aus Hartkäse Käseknochen Kauspielzeug Kaustange Hundekäse',
#              'B08K79CSJB_DE': '100 Stück prospekt-hüllen,premium klarsichtfolien,klarsichtfolien a4,Prospekthüllen Stärke 0,07mm,für Post-Karten, Fotos, Dokumente',
#              'B0BC12J8YG_DE': 'AMIAMO Tablet Kinder 7 Zoll, Kinder Tablet Android 11, 1024 * 600 HD-Display, 3500 mAh Akku, 32GB, Quad Core, KIDOZ Vorinstalliert, WiFi, Bluetooth, Doppelkamera Tablet PC, Tablet für Kinder, Rosa',
#              'B08NX1XTJF_DE': 'Moderne LED Deckenleuchte, 22W Modern Kreative Minimalistische Deckenlampe für Schlafzimmer Flur Wohnzimmer Korridor Aluminium-Deckenleuchten Küchenlampe Flurlampe, Weißem Licht',
#              'B0BGJ7PJC4_DE': '100 LED Lichterkette Innen und Außen Strombetrieben für Weihnachtsbaum Weihnachten Garten Hochzeit Party Fenster Weihnachtsdeko',
#              'B08ZFT5TGN_DE': "CD Dusche 'Totes Meer Mineralien', 250 ml, Duschgel mit echtem Salz aus dem Toten Meer, Showergel mit Aloe-vera-Extrakt für empfindliche Haut, ohne Mikroplastik, vegan",
#              'B002SA4QPU_DE': 'plasteo 20 Liter Getränke- Wasserkanister Natur mit Hahn und Schraubdeckel (DIN 61) | Lebensmittelecht | Tragbar | Indoor und Outdoor | BPA Frei | Made in Germany',
#              'B07XY7PRJM_DE': 'Kinderplay Puppenwagen ab 1 2 3 Jahre Kinderwagen Spielzeug - Grau Kombi, 3 in 1, Spielzeug Draussen, Puppenwagen mit Herausnehmbarer Tragetasche und Umhängetasche, Höhenverstellbar bis 62 cm, KP0200S',
#              'B007HM2728_DE': 'Collonil Waterstop Colours Schuhcreme jeans, 75 ml',
#              'B07MW4W18M_DE': 'BOOMJOY Toilettenbürste, WC-Bürsten Halter Silikon Borsten Klobürste mit Halter Pinzette - Weiß',
#              'B07JM13T83_DE': 'VASAGLE Wandregal, Wandboard für Bücher, Bilder, Deko, Schweberegal, 80 x 20 x 3,8 cm, Büroregal, MDF, für Wohnzimmer, Küche, Flur, Schlafzimmer, Badezimmer, weiß LWS28WT',
#              'B000BC7QMM_DE': 'D-Link DGS-105 5-Port Layer2 Gigabit Switch (bis zu 2000 Mbit/s Datenübertragung pro Port, einfache Plug & Play-Installation, energiesparende Funktionen, lüfterlos, Metallgehäuse) schwarz',
#              'B099QY8MS8_DE': 'MUSUNFE Sensory Fidget Toys Pack, Stressabbau & Angstlinderung Tools Bundle Fidget Toys Set für Kinder Erwachsene, Autistic ADHS Spielzeug, Spielzeug für 3–12 Jahre alte Mädchen Jungen (24er Pack)',
#              'B08F2PGZ3B_DE': 'ZNAP® Slim Wallet Kreditkartenetui | Geldbörse Herren klein | Kartenhalter Geldbeutel Herren | Kartenetui Herren Geldbeutel | Herren Portemonnaie mit RFID Schutz | 8 Karten | Leder Creme genarbt',
#              'B006H1MO2I_DE': 'ARTDECO Magic Fix Lippenstiftfixierung - Transparente Versiegelung für kussechte, wasserfeste und langanhaltende Lippenstifte - 1 x 5 ml',
#              'B08GCTL9ZK_DE': 'Unick LED Einbaustrahler 230V flach [6er Set 5W IP44 ∅70mm] - stromsparend & langlebig - Exklusiver LED Spot [warmweiß 3000K] - Deckenspots für eine harmonische Ausleuchtung ihrer Wohnräume',
#              'B00XCAF69A_DE': 'berydale Damen Langarmshirt mit V-Ausschnitt aus 100 % Baumwolle, Weiß (3er Pack), S',
#              'B08LV76DP8_DE': 'Tischhalterung für Echo Dot 3. Generation Echo Dot Ständer Tischhalter für Echo Dot 3. Generation – Schwarz',
#              'B009TLAQ3M_DE': 'Hama Fotoalbum 28x24 cm (Spiral-Album mit 50 schwarzen Seiten, Fotobuch mit Pergamin-Trennblättern, Album zum Einkleben und Selbstgestalten) azur-blau',
#              'B0BGXNCNNK_DE': 'AiQInu Zugluftstopper für Türen, Einseitige Tür Zugluftstopper, Schalldicht, hält Zugluft und Gegen Insekt,Türdichtung hält Warm und Kalt, 96cm x 8cm, Braun',
#              'B0BB2G1NPL_DE': 'LALAGO Teelichtgläser 12er Set, Gefleckt Teelichthalter Glas, Kerzenhalter Teelichthalter,Kerzengläser für Teelicht Deko Weihnachten Tischdeko Hochzeit（Rosegold）',
#              'B08ZHNNDLB_DE': 'VASAGLE | Wand-Garderobe im Industrial Design, Vintage mit 3 Haken, Stange und Ablage 40 x 60 x 21,5 cm | Holz/Schwarz',
#              'B09VXVFTHG_DE': 'KSIBNW 230V Neon LED Streifen Aussenbereich Neutralweiß 4000K, Led Strip 2m Mit Netzteil Und Led Controller,Flexibler Wasserdichter IP65 Neonlichtstreifen für Schlafzimmer, Innen Heim Küche Deko',
#              'B09X1WGLYL_DE': 'HUND IST KÖNIG® Hundetasche Katzentasche bis 7kg - robust & formstabil | Hochwertige Hundetragetasche / Transporttasche Katze - faltbar & leicht zu verstauen | Hundebox Auto Transportbox Katze',
#              'B01LTHZ8IG_DE': 'NIVEA BABY Nasen frei (24 Ampullen à 5 ml), Nasenpflege mit Kochsalzlösung reinigt Nase und Augenlider, befeuchtet die Nase und erleichtert das Atmen',
#              'B008UQ8JWC_DE': 'Nobafix Fixierbinden 4m x 10cm elastisch 50 Stück',
#              'B081D9G31W_DE': 'SIKORA P34 Klassische Holz Weihnachtspyramide mit 3 Etagen',
#              'B09X48GLFM_DE': 'Anime Maske -Miotlsy 3 PCS Japanische Anime Anbu Maske, Halloween Maske Halloween Christams Party Cosplay Maske',
#              'B000PHCQEG_DE': 'Da Vinci 5235 Serie Synthetik-Pinsel-Set, Borsten, lila/grün/schwarz/weiß, 30 x 30 x 30 cm',
#              'B07DKCRMNF_DE': 'Uten Digitale Küchenwaage, ultradünn, multifunktional, Edelstahl, Lebensmittelwaage, 5 kg, mit LCD-Display mit Hintergrundbeleuchtung (2 Batterien im Lieferumfang enthalten) 9.25 x 6.50 x 1.06 inches',
#              'B07SSLZJY4_DE': '8X4 Men Deo Spray N°8 Wild Oak (150 ml), Herren Deodorant mit erdig-holzigem Duft, 48h zuverlässiger Anti-Transpirant-Schutz für sensible Haut',
#              'B09WPB1BJG_DE': 'Acta Berg Kurbelradio | Notfallradio mit Kurbel & 5000 mAh Akku | Solar Radio mit Weltempfänger | Handkurbel Blackout Notfallausrüstung | Als Taschenlampe & Ladegerät',
#              'B08ZMY5X2Y_DE': 'Funkklingel Batteriebetrieben, SURNICE Türklingel Funk Set, 8 LED-Lichtfarben, 300M Reichweite, 16 Melodien & 4 Lautstärken, Nicht stören-Modus, Weiß',
#              'B00LW3FEAK_DE': 'Ansmann CR123A Lithium Batterie 3V 6 Stück - ideal für Garagentoröffner, Alarmanlage, Miniradio, Funkauslöser für Kamera, Messgeräte, Klingel gold',
#              'B07HXMXHCV_DE': 'Lindt Schokolade zu Weihnachten | Mini-Teddys aus Vollmilchschokolade | 700 g Packung | Schokoladen-Geschenk zu Weihnachten',
#              'B09MD6BLQ5_DE': 'casavetro OPI HGK 10 Leere Glasflaschen 250 ml kleine Flaschen mit Griffkorken Verschluss 0,25 Liter l Likörflaschen Schnapsflaschen Essigflaschen Ölflaschen (10 x 250 ml)',
#              'B0BFDHR9NS_DE': '580 581 XXL Kompatibel Patronen für Canon tr8550 Druckerpatronen PGI-580XXL-PGBK CLI-581XXL Multipack für Pixma TR8550 TS6150 TS6350 TS705 TR7550 TS6250 TR8500 TS9550 TS8150 TS8251 TS8250 (5 Pack)',
#              'B0B1TC5SYZ_DE': 'Spermidin-Weizenkeimextrakt-Kapseln - Spermidin-Ergänzung 1300 mg Fortgeschrittene Formel mit Zink zur Rettung der Mitochondrien, des Immunsystems und der Zellerneuerung (Pack of 1)',
#              'B09XQ2CX1L_DE': 'Belle',
#              'B08YS3ZX9C_DE': 'INDIGOS UG® Namensaufkleber für Wäscheetiketten & feste Dinge - 35-105 Stück - 35x10mm - Fliegen - blau - Kleidung - Kinder, Schule und Kindergarten - KITA für Stifte, Federmappen, T-Shirts',
#              'B0B9G8SX77_DE': 'LEGO Classic Bausteine und Funktionen, Box mit LEGO Steinen für Hubschrauber und andere Konstruktionsspielzeuge & Classic Kreativ-Bauset mit durchsichtigen Steinen, mit Löwe, Vogel und Schildkröte',
#              'B076KQ1693_DE': '3 Stück PE7-F2 Sammelklemme, Schutzleiterklemme, grün/gelb, 7x 16mm²',
#              'B072LB3XHK_DE': 'AQUADE Ablaufgarnitur Überlaufgarnitur mit Zulauf Badewanne Ab-Überlaufgarnitur Abgang ø 40/50mm Edelstahl Ablaufdeckel: 70 mm Qualität: made in Germany',
#              'B09D3YGGGT_DE': 'REFYLL ME Trinkflasche mit Zeitmarkierung aus Tritan “hydroFyll” I Wasserflasche 1l I mit Trageschlaufe I für Kohlensäure geeignet I BPA-Frei I stylische Trinkflasche 1 Liter',
#              'B087QHQF2Q_DE': 'Vivibel Bandana Kopftuch Baumwolle,12er Paisley Bandana Halstuch 55 x 55 cm Kopftuch Armtuch Mischfarben Haar, Hals, Kopf Schal Nickituch Vierecktuch',
#              'B09VBWMKPV_DE': '2-Pack Ladegerät mit Ladekabel Kompatibel mit Samsung Galaxy S8, S8 Plus, S9, S9 Plus, S10, S10 Plus, S10e 5G, A50, A51, A40, A30, A20, A20e, Z Flip3, Fold2, Ersatz-Original Schnellladegerät (Weiß)',
#              'B07XDXMPNC_DE': 'RHINOSHIELD Case kompatibel mit [iPhone 11 Pro] | SolidSuit - Stoßdämpfende & schlanke Schutzhülle mit Premium Finish - 3.5 Meter Fallschutz - Karbonfaser Textur',
#              'B07G31T52J_DE': 'Medrull 100% Wasserfestes Pflaster 15 x 9 cm ULTRA PORE Wundpflaster Steril, Transparent, Starker Halt - Schützt bei Schnittwunden & Kratzer - Ideal zum Duschen, Sport, Baden 25 Stück',
#              'B09G3F43GB_DE': 'Koala Wiederaufbereitet Druckerpatronen Ersatz für HP 302XL 302 Patronen Multipack für HP DeskJet 1110 2130 3630 3633 3636 Envy 4520 4524 4525 4527 OfficeJet 3830 3831 4650 5230 (1*Schwarz, 1*Farbe)',
#              'B07WQ2144X_DE': 'ERYONE TPU Filament 1.75mm, 3D Drucker Filament TPU 0.5kg 1 Spool, +/-0.05mm, Grau',
#              'B0792HD8W3_DE': 'AEG L7WB65684 Waschtrockner / DualSense - schonende Pflege / 8,0 kg Waschen / 4,0 kg Trocknen / Energiesparend / Mengenautomatik / ProSteam - Auffrischfunktion / Kindersicherung',
#              'B09VYNZS1G_DE': 'PONY DANCE Vorhang Grau Blickdicht Verdunklungsvorhänge mit Ösen Extra Breite Gardienen 2-Set H 210 x B 200 cm Ösen Gardinen Blickdicht Schlafzimmer Gardinen und Vorhänge',
#              'B004C2MWVW_DE': '20 One+Step höchstempfindliche Schwangerschaftstests 10miu/ml',
#              'B01DQ9AAL0_DE': 'AVERY Zweckform 56740 Tattoo Kinder 9 Stück (Temporäre Tattoos Fußball, Kinder Tattoo wasserfest, Klebetattoos, Kindergeburtstag, Mitgebsel, Partyspiele Preise, Kinder zum Spielen, Tattoo Jungen)',
#              'B07XJQZKL2_DE': 'Metall Rasierer Plastikfrei Silber| Rasierhobel Zero Waste | Eco Rasierer Herren und Damen | Shaving Razor | Einklingen Rasierer Umweltfreundlich | Hobel Rasierer Nass | Safety Razor | Bambaw',
#              'B0B5H4LVZH_DE': 'Opa Oma Geschenk Enkel,2 Stück Bastelset Opa Oma Holznamen Bemalen & Fotos Ankleben,Opa Oma Geburtstagsgeschenk,Muttertagsgeschenk Oma,Weihnachtsgeschenke,DIY Bilderrahmen mit Standhilfe,Farben,Pinsel',
#              'B08GM3X7W4_DE': 'Bad Geschenkset, SPA LUXETIQUE Beauty Set für Frauen 8-teiliges Geburtstagsgeschenk, Gänseblümchen Weihnachtsgeschenke für mama, Wellness Set für Frauen, Bad Geschenke für Geburtstage und Feste',
#              'B07YDMD24H_DE': 'ORIGINAL BMW Motorrad Batterieladegerät Plus 77022470950',
#              'B09F18QWQT_DE': 'Schlüsselanhänger Set Personalisiert mit Buchstabe Herz - Name Partnergeschenk Handmade - Geschenk Paare Freund Freundin Familie Mutter Vater (2er Set)',
#              'B07RZTNTD5_DE': 'FABACH Trolley Master Einkaufswagenlöser für ALLE Einkaufswagen - Öffnet Frontlader- und Seitenschubfachsysteme - Abziehbarer Einkaufswagenchip Einkaufs-Chip Schlüsselanhänger aus Metall',
#              'B0B4BJD816_DE': 'Asge Rucksack Damen Schulrucksack Mädchen Teenager Backpack Women Casual Daypack Herren Reiserucksack Handgepäck Schultasche Jungen Wasserdichte Reißverschlüsse Cityrucksack mit Laptopfach',
#              'B084KX6QCJ_DE': "PUMA Herren Puma Swim Classic Men's Swimming Trunks Badehose, Schwarz, M EU",
#              'B095YVT53M_DE': 'GoToners XXL Druckerpatronen Kompatibel für Canon PGI-580 CLI-581 Patronen für Pixma TS8150 TS8151 TS8152 TS8250 TS8251 TS8252 TS8350 TS8351 TS8352 TS9150 TS9155 (6er Pack inklusive CLI-581XXL PB)',
#              'B081B3N476_DE': 'Klarstein DryFy Connect Luftentfeuchter Dehumidifier Kompressionsluftentfeuchter, WiFi-Schnittstelle, 230 m³ Luftumwälzung pro Stunde, Entfeuchtungsleistung 40 l pro Tag, weißes Designgehäuse',
#              'B09HZDBR6F_DE': 'Solarleuchten Garten, GOLUMUP 36 LEDs Solar Gartenleuchte Solarstrahler mit IP67, 2 Helligkeitsstufe, Solarlampe für Außen, Hof, Garage usw. 2 Stück, Warmweiß',
#              'B07JK2NJD8_DE': 'LILENO HOME 4er Set Kissenfüllung 30x50 cm - waschbares Innenkissen geeignet für Allergiker - Polyester Kisseninlet als Couchkissen, Sofa Kissen, Cocktailkissen und Kopfkissen',
#              'B07MBWCZ2K_DE': 'amitamin Ovarifert Inositol Formel bei PCO Syndrom, hochdosiert - 120 Kapseln Myo Inositol bei Kinderwunsch und Schwangerschaft, mit Vitamin C, Vitamin D, Vitamin B12, Vegan',
#              'B09C3RQKS5_DE': 'Philips Hue White Amb. Enrave Deckenleuchte M weiß 2400lm inkl. Dimmschalter, 915005996601',
#              'B092D6P7XM_DE': 'Lithium AA Akkus Wiederaufladbare batterien 1,5V 2600mWh mit 4-in-1 USB Typ-C Kabel Schnellladung in 2 Stunden,1200 Zyklen recycelbar-4 Stück',
#              'B01M10T4BK_DE': 'Mack Universal Messerblock im schlichten Holzdesign schwarz lackiert, mit herausnehmbarem Kunststoffeinsatz (Schwarz)',
#              'B08JPCYM1C_DE': 'Mepal Lunchpot Ellipse Mini 2-er Set Lunchbox Essensbehälter (Nordic Denim + Nordic Green)',
#              'B01N26SQ87_DE': 'Porsche 911 Carrera - Holzkiste - Schokoladenauto in Holzkästchen | Auto aus Vollmilchschokolade | Geschenk für Autoliebhaber | Kinder | Erwachsene | lustige Geschenkidee | Mann | Frau | Vatertag',
#              'B01MU6O42P_DE': 'The Illusionist Dry Gin - 500ml',
#              'B005HIMQPW_DE': '12 x Glühlampe Glühbirne Kerze 40W E14 klar 40 Watt Glühlampen Glühbirnen',
#              'B09QD42ZX7_DE': 'nip Stay Green Schnullerband aus 100% Bio-Baumwolle, Made in Germany, für Schnuller mit Ring, stufenweise verstellbar,schützt Kleidung, Colour:Braun',
#              'B07GNMV7GP_DE': 'Rico Wolle Creativ Wool Dégradé 200g 4-fädig Aqua',
#              'B08QW5S6N6_DE': 'biped 2 Paar Kinder Einlegesohlen mit echter Schafswolle und Natur Kork - warm und isolierend - natürliche Thermo Schuheinlagen aus Wolle für Winterschuhe und Stiefel z2765(34)',
#              'B0BLD48MMS_DE': 'PhotoFancy – Foto Adventskalender mit hochwertiger Lindt HELLO-Schokolade in 4 Sorten – mit eigenem Bild bedruckt - Design Schneefall',
#              'B01N5TKXP3_DE': 'United Entertainment – LED Wort Uhr / Wörter Uhr / Uhr mit Worten / Word Clock Deutsch - Schwartz - 17x16.5 cm',
#              'B00BFS9MQO_DE': 'Dior Fahrenheit, Eau de Toilette für Herren, 100ml',
#              'B0B6C8GK7X_DE': 'CICIBER Hülle für Samsung Galaxy A13 4G, Weiche Schlanke Transparent Handyhülle (Extrem Dünn, Leicht) Schutzhülle für Samsung Galaxy A13 4G 6,6 Zoll Case Cover mit Pfirsichblüte Blumen Motiv',
#              'B00IM1EGNG_DE': 'Trolli All in One Display Trolli, 1000 g',
#              'B09W16PSQL_DE': 'SanGlory Reflektorlampe R50 E14 LED Lampen, 5W ersatz für 40W Glühlampe, Kaltweiß 6000K, 510LM, E14 LED Reflektor R50 LED Strahler, 120° Abstrahlwinkel, Nicht Dimmbar, 6er Pack',
#              'B08Z897L2Q_DE': 'WENKO Zahnputzbecher Davos, puristischer Zahnbürstenhalter, Badaccessoire in angesagtem All-Black Design für den trendigen Einrichtungsstil in Bad & Gäste WC, BPA-frei, Ø 7,7 x 10,5 cm, Schwarz matt',
#              'B00KYLFMK8_DE': 'TOX Metall-Hakendübel Pirat Skippi M6 x 65 mm verzinkt, für Befestigungen in Gipskartonplatten, 25 Stück, 035101691',
#              'B097XKW2ST_DE': '360 Stück T-Abzweig-Kabelverbinder, Sopoby Kabelverbinder Kit ，T Tap Elektrische Wire Connectors für Schnelle Verbindungskabel(Rot/Blau/Gelb)',
#              'B086Q2PLW6_DE': 'Wärmflasche mit Bezug – Weicher Premium Flauschig Bezug – 1,8l groß Wärmeflasche für Erwachsene für Kuschelige Nächte, Schmerzlinderung, Rücken, Bauch, Schulter und Nacken - Grün',
#              'B01MDQ8FBZ_DE': 'aidB Eurobox NextGen Portable, 600x400x185mm, 1 St.',
#              'B07H2BKYQV_DE': 'Play-Doh Ciastolina Afera beim Friseur Set 5 Farben',
#              'B09879W97H_DE': 'TORRAS Hülle für iPhone 13 pro Hülle mit 3-Wege-Ständer (Befreie Deine Hände) Transparent Vergilbungsfrei iPhone 13 pro Case Military Grade Drop Protection Klar Handyhülle iPhone 13 pro Kratzfest',
#              'B085TGD13G_DE': 'Ösen Set, Queta 500 Stück Ösenzange Metallösen 5mm Grommet Werkzeug Kit mit Locheisen Planenösen Installation Werkzeuge für Schuhe Leder Taschen Kleidung DIY Handwerk',
#              'B01N3V832S_DE': 'GarPet Aquarium aus Glas - Glasbecken für Süß- und Seewasser - hochwertiges Glas-Aquarium - Premium Fisch-Aquarium - Fisch-Becken 50 x 30 x 30 cm',
#              'B096Y3NT67_DE': 'Luxari LED Einbaustrahler 230V flach − Strahlende LED Einbauleuchten [6er Set 9W] − Bad LED Spot [3000K warmweiß] − Deckenstrahler − IP54',
#              'B07XR9N7QD_DE': 'Vicloon Schneidebrett, 6-er Set Farbe Kunststoff-Schneidebrett mit Lebensmittel-Icons & Easy-Grip-Griffe, Antibakteriell, rutschfest, Spülmaschinenfestes, für Fisch/Gemüse/Obst/Fleisch/Brot',
#              'B09C1QT67D_DE': 'GESTAND 24er Adventskalender zum Befüllen Set,Stoffsäckchen Selbst Befüllen Bastelset Aufkleber mit Beuteln Zahlen für Kinder (Adventskalender 1)',
#              'B09B2ZGL8K_DE': '8 Stück Elastische Sport Stirnbänder, rutschfeste Haarband Dünnes Stirnband für Herren, Damen e Kinder(Schwarz)',
#              'B09NKJFPFZ_DE': 'JETech Hülle Kompatibel mit iPhone 13 Pro Max 6,7 Zoll, Stoßfeste Stoßstange handyhülle, Anti-Kratzt Transparent Rückseite (Schwarz)',
#              'B0B6PH962S_DE': '3 Stück Wäschenetz Groß für Waschmaschine, XXL Wäschesack Schmutzwäsche Wäschebeutel mit Reißverschluss, Laundry Bag Mäntel, Pullover, Steppdecken, Decken, Kissen, Plüschtiere usw (60*60CM)',
#              'B09DKMWK68_DE': 'Reolink 4K PoE Kamera Outdoor mit 5X optischem Zoom, IK10 Vandalismusgeschützt Überwachungskamera für Aussen, Personen-/Autoerkennung und Zeitraffer, microSD unterstützt für 24/7-Aufnahme, RLC-842A',
#              'B01EQFHYEY_DE': 'DDOXX Hundeleine Nylon, 3fach verstellbar, 2m | für kleine & große Hunde | Doppel-Leine Zwei Hund Katze Welpe | Schlepp-Leine groß | Führ-Leine klein | Lauf-Leine Welpen-Leine | M, Gelb',
#              'B0895QDL2H_DE': 'SCHÜTTE WC Sitz FAMILY WHITE Duroplast, Toilettensitz mit Absenkautomatik und Schnellverschluss, Klobrille mit abnehmbarem Kindersitz, maximale Belastung 150 kg Weiß 82940',
#              'B096ZVBH6B_DE': 'Abdeckplane | Gewebeplane | Schutzplane | Bootsplane | Zeltunterlage für Camping & Outdoor | Garten | wasserdichte Plane mit Ösen | Viele Größen & Farben (3x5 m (80 g/m² ), Grün)',
#              'B09Z664FNS_DE': 'WUWEOT 40 Pack Papier-Geschenk-Taschen, 21 x 15 x 8 cm Schwarz-Gold-Geschenk-Taschen Bronzing Sterne & Herz-Geschenk-Taschen Bulk Kraft Party Favor Taschen mit Griff für Geburtstag Parteien Jubiläum',
#              'B07YK8R1D1_DE': 'BIOMED Citrus Fresh pflegende Mundspülung gegen Mundgeruch - fluoridfreies und 98% natürliches Mundwasser in einer 500ml Packung',
#              'B09N6JFPRB_DE': 'Digital Fleischthermometer Küchenthermometer Grillthermometer, sofort lesbar mit Langer Sonde, großer LCD-Bildschirm für Küche, Backen, Braten, Grillen, Grillen (Batterie im Lieferumfang enthalten)',
#              'B09B2JQSQM_DE': 'Pollmann Hauptleitungs-Abzweigklemme HLAK 25-1/4 M2 grau',
#              'B08XM8R3DG_DE': 'BABY Born Unisex Badjas BABY born Bath Deluxe Bademantel 43 cm, Mehrfarbig, 25 x 9 28 cm EU',
#              'B00CL8F8D8_DE': 'KabelDirekt – 4K Antennenkabel, TV Kabel 90° gewinkelt – Fernsehkabel mit bruchfestem Metallstecker für digitales & analoges Fernsehen – 5 m (Winkel-Stecker auf Winkel-Buchse für DVB-C/DVB-T/DVB-S)',
#              'B00KKGDJ4S_DE': 'Sovita Med Weissdorn-Dragees, Weißdorn Kapseln, Herz-Kreislauf-Tabletten, 240 Kapseln',
#              'B0BKGQ7SHZ_DE': 'Frühstücksbrettchen Kinder - tolles Frühstücksbrettchen Holz mit Tiermotiven zum Personalisieren - personalisierte Geschenke Kinder - Schneidebrett mit Gravur - Geschenk zur Taufe / Einschulung',
#              'B07XJPW75V_DE': 'Govee LED Strip 20m, RGB LED Streifen, Farbwechsel LED Band mit IR Fernbedienung, für die Beleuchtung von Haus, Party, Küche , 2 Rollen von 10m',
#              'B08DJ325B1_DE': 'omitium Handykette für iPhone 12/12 Pro, Transparent Hülle mit Band iPhone 12 Pro Stoßfest Silikon Schutzhülle Durchsichtige Handyhülle iPhone 12 Halskette Cover mit Kordel zum Umhängen Case, Schwarz',
#              'B082WGLJ6F_DE': 'KHG Knoblauch Aufbewahrung aus Keramik/Steingut poliert in Anthrazit Grau mit Holz-Deckel für 250g Knoblauchknollen, Knoblauch Dose rund & mit Aufdruck, Knoblauch Behälter Höhe 13,5cm & 13,5cm ??',
#              'B0776F41F9_DE': 'KTX7 Messer Klappmesser Taschenmesser M2, Schwarz',
#              'B0002HVOVK_DE': 'SIGIKID 41181 Greifling Schmetterling Red Stars Mädchen und Jungen Babyspielzeug empfohlen ab Geburt orange',
#              'B089K7V3CF_DE': 'Furlinic Duschvorhang 120x180 Textil Badvorhang aus Polyester Stoff Schimmelresistent Wasserabweisend Waschbar Beige mit 8 Duschvorhangringen.',
#              'B085VSBVKW_DE': 'KoRo - Schokobrezel ohne Zuckerzusatz 1 kg',
#              'B003MVH17Y_DE': 'Epson 235M274 Original T1292 Apfel Tinte (SX420W BX320FWSX620FWBX/SX525WDBX625FWDBX305FWB42WDBX925FWDBX635FWDBX535WDSX435/440WBX630FWSX235WWF701575157525301035203540)cyan',
#              'B0B9TPF8D4_DE': 'Wunsch Kalender - personalisierter Wandkalender - wählbar 3 bis 5 Namen - wiederverwendbarer Kalender aus Acrylglas - Familienplaner abwischbar als Hingucker für jeden Raum',
#              'B09PDH7LLC_DE': 'MATEPROX Klar Handyhülle Kompatibel mit Samsung Galaxy S22 Hülle Hartschale Rückseite Klare Starre Stoßfeste Schutzhülle für Galaxy S22 2022-Blau',
#              'B0BKD671BZ_DE': "Opa's Kreuzworträtsel Adventskalender: Senioren Adventskalender für Opa mit 72 Kreuzworträtseln in großer Schrift",
#              'B07P9JWBBH_DE': 'IKEA Fishbo Bilderrahmen, 30 x 40 cm, Schwarz, 2 Stück, Pappe, Faserplatte, Folie, Polystyrol-Kunststoff, Farbe, Schwarz , 30x40cm',
#              'B0B5LHW9TD_DE': '21 Stück Halloween Kuchenaufsätze, Halloween Cupcake Toppers, Halloween Party Cupcake Dekorationen, Halloween Kuchendekoration Kuchenhut, Ghost Pumpkin Decor for Halloween, Lustige Emoji-Dekoration',
#              'B07JN12LFD_DE': 'Weihnachtsbaumschmuck Set - 45 teilig in Champagnertönen (Weiß, Silber, Champagner etc.) - 36 Kugeln, Weihnachtsbumspitze, Dekosterne und Kette',
#              'B002ORJHZ6_DE': 'Hellum Lichterkette Made-in-Germany Weihnachtsbaum, Kerzen Lichterkette außen mit Clip, 20 warm-weiße LED, beleuchtete Länge 1900cm, Kabel grün Schaft weiß, für Außen mit Stecker 842043',
#              'B09QPKS6B1_DE': 'Noris 606101975 Escape Your Home, Familien und Gesellschaftsspiel für 3 bis 6 Spieler-mit Timer inkl. Batterien-für alle Escape Room Fans, ab 8 Jahren',
#              'B0B7N11N8L_DE': 'Connemara Original getorfter Single Malt Irish Whiskey, mit Geschenkverpackung, mit rauchigen Aromen, 40% Vol, 1 x 0,7l & Auchentoshan 12 Jahre Single Malt Scotch Whisky, 40% Vol, 1x 0,7l',
# ...
#              'B09Y8WJGQ7_DE': 'kwmobile Hülle kompatibel mit Thermomix TM5 / TM6 - Küchenmaschine Abdeckhaube - in Violett Weiß Schwarz Pinsel Herzen',
#              'B002TLLKW0_DE': 'netproshop Fußboden Kabelkanal PVC (Halbrund, Selbstklebend, 70x17mm) (1 Meter), Farbe:Hellbraun Meliert',
#              'B09QCS1TS5_DE': 'KLUIZ CAT - XXXL 100 Gramm Katzenminze getrocknet mit nachfüllbarem Säckchen I Catnip Katzenminze aus Frankreich',
#              'B01FJX6P5Q_DE': 'Forever Speed Hundefön Pet Dryer für Hundepflege Tierfön mit Einstellbarer Windgeschwindigkeit, 2400W Hundetrockner mit 3 Düsen',
#              'B07ZRBCPN1_DE': 'Klighten LED Spiegelleuchte Bad 80cm, 16W Spiegellampe IP44 Wandleuchte Bad, Badezimmer Badlampe für Spiegel Badspiegel Lampe, 1360 Lumen, Kaltes Weiß 5500K',
#              'B075GQB7BK_DE': 'Gardigo Spinnenabwehr Ultraschall Stecker - 2er Set I Ultraschall Schädlingsbekämpfer für das Haus gegen Spinnen | 25m² | 27 kHz | Anti Spinnen Stecker | Insektenabwehr Insektenstecker',
#              'B00EC6IFRI_DE': 'WEICON Oberflächen-Reiniger / 400 ml / Reiniger / Entfetter / Spezialreiniger / farblos',
#              'B00TRYTE70_DE': 'VBS Schatztruhe ohne Gravur 10 Stück Truhe Kästchen Schatzkiste Holztruhe Piraten-Schatztruhe Aufbewahrungsbox Schmuckkasten Spardose Bauernkasse',
#              'B00NBW3S1C_DE': 'Patisse 2963 Springform mit hohem Rand "Profi" 22 cm',
#              'B08QVFBVR8_DE': 'Schreibtisch Organizer Bambus, Schreibtisch Schreibwaren Aufbewahrungsbox Stiftehalter Stifteköcher Aufbewahrungsbox Schreibtisch Zubehör Organisation Ordnungsbox',
#              'B0BB3K91GH_DE': 'Harris-Brüder-Reihe',
#              'B07HH6ML2B_DE': 'Realistische Vibratoren für sie Klitoris und G-Punkt Stimulator, Dildo Silikon Massagestab für Frauen Sex-Spielzeug Wasserdicht, AV-Vibrator mit 7 Vibrationsmodi, USB wiederaufladbar, Schwarz',
#              'B08L6RVZB9_DE': 'HABA Glitzerbecher Pferde',
#              'B071DZSCM3_DE': 'Fahrzeugteile Hoffmann DC Grundierung 400ml freie Farbauswahl (grundierung schwarz)',
#              'B08DR8H4VK_DE': 'A5 Papier Karierte Nachfüllpapier Set, FANDAMEI 6 Löcher A5 Nachfüllbare Notizpapier 90 Blätter, 5 Stücke Farbige Trennblätter A5, 320 Stücke Haftnotizen Bunt, 2 Stücke Umschlägbeutel, 20CM Lineal',
#              'B09P7KDMWB_DE': 'Reulin Ultra-Flexibles 2M Cat.8 Flach Ethernet Kabel, RJ45 Netzwerk LAN Draht Hochgeschwindigkeits Internet Datenkabel Schneller als Cat5/Cat6/Cat7 Patchkabel Gigabit Breitband Ethernet-Cable 2 M',
#              'B07PLGT1QL_DE': 'Multivitamin-Kapseln 29 Essentielle Nährstoffe Vegan | Vitamine A, B, C, D, E, K, Biotin, L-Cystein, Coenzym Q10 und 9 Mineralstoffe | Multivitamin-Komplex 60 Kapseln | Nutralie',
#              'B01KXUY5SY_DE': 'Ursus 18700043 - Laternenbastelset Engel',
#              'B097H5C21W_DE': 'Alles Gute Zum Ruhestand Girlande Bunt Endlich Ruhestand Girlande Filz Rente Deko Banner mit Sterne Hänge Deko für Party Ruhestand Rente Abschiedsfeier Pensionionär Senior Privatmann und Frauen',
#              'B01IOE8P6O_DE': 'Pure Highway 400 In-Car-Audioadapter (DAB/DAB+ Digitalradio mit Bluetooth, Go Button, Siri und Google Assitant, Spotify und 20 Senderspeicherplätze) Schwarz',
#              'B09DKZNJGT_DE': 'Dzsomt Holzreifen Zum Basteln 12 Stück Holz Bambus Blumenkranz Holzring Traumfänger Ringe Set Kranz Ringe DIY Makramee Craft Hoop Ringe Holz Bambus Floral Hoop Set Holz Bambus Blumenkranz',
#              '3849929051_DE': 'PAW Patrol',
#              'B09YRZZ1MD_DE': 'Bilderrahmen 50x70 Schwarz | London | Bilderrahmen Groß | Bilderrahmen Holz mit bruchsicherem Plexi-Glas | Rahmen 50x70 | Holzrahmen Schwarz (1Stk.)',
#              'B073ZJQLNR_DE': 'Fussboden TV Kabelkanal Kabelbrücke selbstklebend 1 m weiss 50 x 12 mm Wand Boden Fußboden halbrund rund ARLI 1 Stück',
#              'B0B8F4485Z_DE': 'BigDean Wasserbad- & Simmertopf 1,2 Liter - Milchtopf doppelwandig/aus Edelstahl - zum Milch erwärmen - Milchkochtopf, Wasserbad Topf, Schmelztopf, Edelstahltopf klein',
#              'B09ZWMS62L_DE': 'Reisefressnapf Edelstahl, 3 Napf Set, 1500 ml (3 x 500 ml), Hundenapf für Unterwegs, tragbarer Futternapf, praktischer Reisenapf für Outdoor und Alltag',
#              'B00YMPU5CC_DE': 'KarnevalsTeufel Luxus Hexenhut mit Schleier und Federbesatz Hexe (schwarz)',
#              'B01N1V19KZ_DE': 'Kärcher Akkubesen KB 5 (Akkulaufzeit: bis zu 30 min auf Hartböden, ergonomische Reinigung ohne Bücken, randnahes Kehren, platzsparende Aufbewahrung, Parkposition, automatische An-/ Ausschaltung)',
#              'B09TF5TDVB_DE': "Jack´s Bierflasche''MÄNNER HABEN AUCH GEFÜHLE-DURST ZUM BEISPIEL'' mit Geschenkverpackung 0,33 l/Männergeschenk/Zum Geburtstag/Party",
#              'B092S4W9HL_DE': 'Rauch und CO Melder, Rauchmelder, CO Melder, Geringer Stromverbrauch und Hochpräzise LCD-Digitalanzeige, 2-in-1 homematic Rauchmelder',
#              'B08YNHB1SJ_DE': 'Stricknadeln Set, ARPDJK 35 Stücke 2mm - 5mm Metall Doppelspitz Stricknadeln, 20cm lang Stricknadeln für Anfänger Erwachsene - 2mm 2,5mm 3mm 3,5mm 4mm 4,5mm 5mm',
#              'B09S1FHXMS_DE': 'tesa MOON BLACK WC-Garnitur, Set mit Halter & WC-Bürste, matt schwarz, satiniertes Glas - für Bäder im Industrial Style - bohrfrei, inklusiv Klebelösung - 379 mm x 112 mm x 145 mm',
#              'B0B4347ZJC_DE': 'OtterBox Defender Hülle für iPhone 14 Pro, stoßfest, sturzsicher, ultra-robust, schützende Hülle, 4x getestet nach Militärstandard, Schwarz,Keine Einzelhandelsverpackung',
#              'B0B6ZTTFFP_DE': 'happypie campingtoilette faltbar,Mobile Camping wc, komposttoilette Klo für Draußen, tragbare Toilette für,Notfall, Camping, Staus, Angeln, Festivals,Schwarz',
#              'B08NK6WP6L_DE': 'Reisenthel Flaschentasche-ZJ7052 Silver 25 x 28 x 24 cm',
#              'B09LHC5SJC_DE': 'Blatt Hochzeit Tiara Krone, Strass Kristall Braut Tiara Haar Pin Tiaras Stirnband, Strass Kopfband der Frau Blumen und Blätter Krone Haarband für Braut Brautjungfern (Silber)',
#              'B076J1KRVV_DE': 'r-up Beste Spannbettlaken 180x200-200x220 bis 35cm Höhe viele Farben 95% Baumwolle / 5% Elastan 230g/m² Oeko-Tex stressfrei auch für Boxspringbetten (Natur)',
#              'B000S5HZ0K_DE': 'Herlitz Briefumschlag DIN Lang Selbstklebend mit Fenster, 25 Stück mit Innendruck in Folienpackung, eingeschweißt, weiß',
#              'B0B87XSQNN_DE': '100 Stück marvel aufkleber Graffiti Decals, Wasserdicht Stickers, Cartoon Aufkleber, für Wasserflaschen, Laptop, Autos, Motorrad, Fahrrad, Skateboard, Gepäck, Kühlschrank, (Marvel-Helden)',
#              'B07CJWLP3S_DE': '24x Biere der Welt + Deutschland / Geburtstag Geschenk / Mann Geschenkset',
#              'B06XG5Q7HY_DE': 'Eine Königin Zu Weihnachten [dt./OV]',
#              'B09FPLJNCS_DE': 'Personalisierte Decke Fotodecke mit Eigenem Foto und Text,Personalisierte Geschenke Für Geburtstage, Jubiläen Geschenk Für Vater, Mutter, Kinder, Hunde, Freunde Oder Liebhaber',
#              'B01KGW2B1W_DE': 'SP Connect Universal-Mount | Fahrradhalterung | Handyhalterung fürs Motorrad | Fahrradhandyhalterungen für alle Smartphone Handys wie iPhone Samsung | Mountainbike Rennrad Handy Halterung Gadget',
#              'B08RMQQZWT_DE': 'DOC 10 Stück-FFP3 maske-luftdicht einzeln verpackt-zertifiziert EN149:2001+A1:2009-Staubmaske Schutzmaske Höchste Filterklasse 99% Filter, white, 10x Ffp3',
#              'B01L95ABR6_DE': 'LED Geschenkboxen mit Timer 3er Set - ROT - Weihnachts Dekoboxen warm weiß beleuchtet - Weihnachten Advent Winter Christbaum Deko Beleuchtung Batterie betrieben',
#              'B06Y2W26ZK_DE': 'tetesept Muskel & Gelenk Set: Duschbad & Lotion, 500 ml',
#              'B089QHFG3B_DE': 'GUTTER GAMES Saufkoffer - Die 8 Besten Trinkspiele (Bier Pong, Noch Nie Habe Ich, Ring of Fire Und Mehr) | Partyspiel Für Erwachsene - Ideal Für Das Vorglühen Und Den Spieleabend',
#              'B01MG9GT3S_DE': 'Mellerud Grill & BBQ Reiniger – Ergiebiges Spray zur Reinigung von Eingebranntem, Fett und Verkrustungen – 1 x 0,46 l',
#              'B074KGYJRD_DE': 'Staedler 8304 17 LZ "Fimo Space" Form- und Spielset',
#              'B074N55XW2_DE': 'Frau WUNDERVoll® DIY Adventskalender zum Befüllen Weihnachtszeit, Blockbodenbeutel 12(L) x7(B) x24(H) cm grau Sterne und Streifen, Ziffern grau/Weihnachten, Papiertüten, Kinder, Aufkleber',
#              'B09LJ25V9Z_DE': 'Hausnummer Anthrazit mit Gravur Straßenname und Nummer personalisiert Hausnummernschild RAL 7016 - Acrylglas wetterfest und UV-beständig - 150 x 100 mm',
#              'B096JK4V6L_DE': '120 Led Lichterkette Außen Solar, NLNEY 15M Solarlichterkette Sterne Lichtervorhang Aussen 8 Modi Weihnachtsbeleuchtung für Innen Outdoor Weihnachtsdeko, Garten, Balkon, Terrasse Deko (Bunt)',
#              'B08T7J9GZC_DE': 'CHAOREN Gürtel Herren, Ledergürtel Ratsche Automatikschließe für Herren Business Anzug, 35mm Breit Gürtel, Größe Angepasst (07 Gekreuzte Schnalle - Schwarz, 115cm/32-38" Taille verstellbar)',
#              'B0BGPRR6L6_DE': 'SMOK RPM 25W Kit, Pod System, 900 mAh, 2 ml, black leather, ohne Nikotin',
#              '3838423224_DE': 'Wald Kalender 2023, Wandkalender im Querformat (54x48 cm) - Landschaftskalender / Naturkalender',
#              'B06XB273QX_DE': 'Spetebo Schmutzfangmatte schwarz - 60 cm x 90 cm - Fußmatte Fußabtreter Türmatte Außen',
#              'B0925KGVV7_DE': '2 Pcs Ich liebe dich Morsecode Armband Paare Passende Armbänder, Paar verstellbare Armbänder Freund Freundin Paar Schmuck Schmuck für Ihn / Sie / Mädchen / Frauen',
#              'B081NNTF1P_DE': 'Olaplex Set - Olaplex Bond Maintenance Shampoo No 4 (250ml) + Olaplex Bond Maintenance Conditioner No 5 (250ml) + Olaplex Bond Smoother No 6 (100ml) + Olaplex Bonding Oil No 7 (30ml)',
#              'B079Q423XK_DE': '3x AH-CDE Kompatibler Filter für DeLonghi Wasserfilter DLSC002, SER3017, 5513292811, passend für Delonghi Bohnen- und Espressokaffeemaschinen',
#              'B09JKZSZMT_DE': 'MF Angler Adventskalender 2021 - Weihnachtskalender Angel Advents Kalender - mit 24 Überraschungen + Multifunktions Tuch',
#              'B07SC1JS15_DE': 'Staedtler (1, Doppel-Spitzdose + 24er Buntstifte-Set)',
#              'B0B3DX8SPY_DE': 'NBMNN 8-teiliger Minifiguren-Adventskalender Zusammengebaute Block-Minifiguren für Kinder, kompatibel mit der Lego Ninjago-Motorradkollektion',
#              'B09H2QZHFC_DE': 'YRHome 100m 1000 LED Lichterkette LED Außen Innen Dekoration mit steckerLichterkettenvorhang Warmweiß 8 Modi für Weihnachten Party Hochzeit Ostern Wasserdicht IP44',
#              'B01N10ILNX_DE': 'WOLTU\xa0Thermovorhang\xa0Kälteschutz\xa02er\xa0Set\xa0Verdunklungsvorhänge\xa0Ösen Vorhang Blickdicht,\xa0270g/m²\xa0Schwere\xa0Wärmeisolierende\xa0Vorhänge\xa0Damast Optik Gardinen\xa0Wohnzimmer Schlafzimmer,\xa0135x225 cm Creme',
#              '0786965622_DE': 'D&D Core Rulebook',
#              'B0B93F371V_DE': 'HOUT® Badewannenkissen | Badewanne Zubehör & Badekissen mit 7 Saugnäpfen | Spa Kissen & Bad Zubehör | Luxus-Badaccessoires für Whirlpool, Badewannen und Spa (Blau)',
#              'B00WUAKR2E_DE': 'Morella Damen Halskette Silber mit Buchstabe M Anhänger 925 Silber rhodiniert mit Zirkoniasteinen weiß 45 cm',
#              'B07CYWKZND_DE': 'Bosch Professional Schlagbohrmaschine GSB 24-2 (1100 Watt, Max. Drehmoment: 40/14,5 Nm, in L-Case)',
#              'B007IDVRP4_DE': 'KREUL 28400 - Mucki leuchtkräftige Stoff - Fingerfarbe, 4 x 150 ml, gelb, rot, blau, grün, Wasserbasis, paraben-, gluten-, laktosefrei und vegan, optimal für die Anwendung mit Fingern und Händen',
#              'B07B51YNGN_DE': 'Das Bose unter der Sonne [dt./OV]',
#              'B07HRT94RH_DE': 'Hochgeschwindigkeitsstahlklingen für Multifunktionswerkzeuge für Rotationswerkzeug; 8 kleine Kreissägestahlklingen für das Schneiden von Holz, Kunststoff und Metall',
#              'B089GHDK49_DE': 'TOPDON Infrarot Wärmebildkamera - ITC629, Auflösung von 220 x 160 Pixel, Temperaturbereich –20 °C bis +450 °C, Professional Wärmebildkamera ± 2% Genauigkeit vom Messwert, eingebaute Lithium Batterie',
#              'B0012D4FZK_DE': 'Ravensburger 21402 - Was passt zusammen? - Puzzelspiel für Kinder, Bildpaare zuordnen für 1-4 Spieler ab 2 Jahren',
#              'B08QRC78L7_DE': 'TBC Fenstermalfarben für Kinder, Window Color Set 6 Farben, DIY Fensterkunst, Hallween Ostern Dekoration, Kunst & Handwerk Kit, Geschenke für Mädchen, Jungen, Kinder, Studenten',
#              'B08KTP6517_DE': 'PLAYMOBIL® 70512 Fröhlicher Ponyausflug',
#              'B07M9WWRK7_DE': '500 Eintrittsbänder, Neon Purple - Violett - Party Einlassbänder, Securebänder, Festival Armbänder, Kontrollbänder für dein Event',
#              'B09QS66ZXG_DE': 'flintronic Groß Reisetasche, Faltbare Sporttasche Overnight Weekend Handgepäck für Damen, Leichte Kliniktasche mit Nassfach, wasserfest Handtasche für Sport & Reisen (Mit 1 Gepäckanhänger)-Fuchsie',
#              'B00H39W23Y_DE': 'Merida - Legende der Highlands',
#              'B07MR5MHX5_DE': 'USB-Speicherstick für Phone und Pad - 128 GB - USB 3.0 - Externer Speicheradapter Erweiterung für iOS PC Mac und Windows PC grau grau',
#              'B098WTTW7G_DE': 'Lanqinglv 2 Set Bohemian Indisch Kissenbezug 40x80 cm Dunkelgrün Grün Mikrofaser Hochwertiges Kopfkissen Boho Kissenbezüge mit Reißverschluss',
#              'B07NBX4KTX_DE': 'Kit 2 Stück Aluminium-Fettfilter Austauschfilter Dunstabzugshaube Für ELICA mm 267 x 305 x 9',
#              'B075V63YQ5_DE': 's.Oliver Herren-Armbanduhr Analog Quarz Leder SO-15075-LQR',
#              'B00N340LMW_DE': 'LS-LebenStil Kerzenschale Eisen 59cm Gold Stumpenkerze Kerzenständer Kerzenleiste',
#              'B00LKHSHIE_DE': 'Mr Bear Family Beard Balm-Beard Wax for Men Natural Hydrating Wax for Beard Containing Argan Oil Beeswax Coconut Oil - Skin Care for Men with Citrus Fragrance Strong Hold for Medium to Long Beard Hair 60ml',
#              'B08TC654B6_DE': 'LIHAO 32 x Küchenspielzeug Zubehör Kinderküche Edelstahl Kinder Kochset Kochgeschirr Pfannenset Schürze Rollenspiele mit Box für Mädchen Jungen Geschenk',
#              'B01G062AD2_DE': 'Motul ÖL 8100 X-CLEAN + 5W30 5L',
#              'B00IG145L0_DE': 'Sex and the City - Staffel 2',
#              'B01KHEYLP8_DE': 'HG POWER GLUE Die Schweißnaht aus der Flasche 2k Sekundenkleber extra stark Starker Profi Reparatur Kleber Industriekleber für Kunststoff Gummi Stein Keramik (2+1* (2x20g + 3x40g))',
#              'B01LW7Q1F6_DE': 'Uniento Wasserdichter Matratzenschoner 90 x 200 - atmungsaktive Matratzenauflage, Matratzenschutz ohne Knistern',
#              'B08RMTJTQM_DE': 'Elviros Kulturbeutel PU-Leder für Herren große wasserdichte Reise-Kulturtasche Waschtasche im Bade Kosmetiktasche mit einem Nass-Trockenbeutel, 24 x 15 x 16 cm, Dunkel Braun',
#              'B07X3FLB5C_DE': '3D Bilder Nagelspiel Abdruck Kreative Muster Anzeige Schreibtisch Deko Interessantes Geschenk für Kinder 20 x 15 cm, Grün',
#              'B0B1J4D56Z_DE': 'Mini Tischsauger, Elektrischer Tisch-Staubsauger für Reinigung Krümel USB Wiederaufladbar Tischstaubsauger Hohe Saugleistung Staub Reiniger Tragbar Handstaubsauger für Desktop, Haushalt, Büro',
#              'B07NGX4J48_DE': 'Simba 105953390 Glibbi Badebomben Maker, rot/gelb/blau',
#              'B00G23Q1UW_DE': 'goldbuch 24895 Fotoalbum mit Fensterausschnitt, Bella Vista, Erinnerungsalbum 25 x 25 cm, Foto Album 60 weiße Seiten mit Pergamin-Trennblättern, Fotobuch aus Leinen, Blau',
#              'B09B2JB5B4_DE': 'RITUALS Autoduft Nachfüllpackung von The Ritual of Sakura, 6 ml – Mit Reismilch & Kirschblüte',
#              'B07XQK116Y_DE': 'alfi Trinkflasche 500ml, isoBottle, Thermosflasche, Edelstahl orange Isolierflasche auslaufsicher, Wasserflasche 5677.134.050, Thermoskanne 12 Stunden heiß, 24 Stunden kalt',
#              'B01CHRFL8O_DE': 'ATOPLEE Metrisch HSS Gewindebohrer M12 Rechtsgewinde Bohrer (M12x1,5)',
#              'B07NNTSKZP_DE': 'Kinderteppich DOTS l Pünktchen Gepunktet l Öko-Tex Siegel | Farbe: Beige Blau Rosa | Kinderzimmer / Jugendzimmer (Rosa, 80x150 cm)',
#              ...})

# %%
len(id2title_dict)
# Out:
# 1551057

# %%
pred_titles = []

for _, row in tqdm(df_test.iterrows(), total=len(df_test)):
    pred_titles.append(id2title_dict[f"{row['next_item_prediction']}_{row['locale']}"])
# Out:
# 100%|██████████| 56421/56421 [00:06<00:00, 8923.83it/s]

# %%
df_test['next_item_prediction'] = pred_titles

# %%
df_test.head(5)
# Out:
#                                  prev_items locale   last_item  \
# 0               ['B082DLM3NZ' 'B089X86H73']     ES  B089X86H73
# 1  ['B071WPLND2' 'B08TMJ9SDZ' 'B07XRCLVYG']     ES  B07XRCLVYG
# 2               ['B094V8G54H' 'B094V97YV8']     ES  B094V97YV8
# 3               ['B0B3DQXY57' 'B0B6W3GGTM']     ES  B0B6W3GGTM
# 4  ['B0765BPD7T' 'B00V4PQY3C' 'B09HWV4MBK']     ES  B09HWV4MBK
#
#                                 next_item_prediction  \
# 0  Denver BTS-110 Black- Altavoz Portátil. Sinton...
# 1  MAGEFESA Dynamic Olla a presión Super rápida d...
# 2
# 3  Rizador Pelo Sin Calor, Rizador de Pelo Sin Ca...
# 4  UCMDA Alfombrilla Ratón con Cojín de Muñeca Al...
#
#                                      next_item_title
# 0  Denver BTS-110 Black- Altavoz Portátil. Sinton...
# 1  MAGEFESA Dynamic Olla a presión Super rápida d...
# 2
# 3  Rizador Pelo Sin Calor, Rizador de Pelo Sin Ca...
# 4  UCMDA Alfombrilla Ratón con Cojín de Muñeca Al...

# %%
df_test[['locale', 'next_item_prediction']].to_parquet('submission_task3.parquet', engine='pyarrow')

# %%
df_test3 = pd.read_parquet('submission_task3.parquet')
df_test3.head(5)
# Out:
#   locale                               next_item_prediction
# 0     ES  Denver BTS-110 Black- Altavoz Portátil. Sinton...
# 1     ES  MAGEFESA Dynamic Olla a presión Super rápida d...
# 2     ES
# 3     ES  Rizador Pelo Sin Calor, Rizador de Pelo Sin Ca...
# 4     ES  UCMDA Alfombrilla Ratón con Cojín de Muñeca Al...
