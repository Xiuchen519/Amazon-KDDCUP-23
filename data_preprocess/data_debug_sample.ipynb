# %%
import numpy as np
import pandas as pd

# %%
inter_feat = pd.read_csv('../data_for_recstudio/inter_feat.csv')

# %%
debug_inter_feat = inter_feat.head(1000000)

# %%
debug_inter_feat.to_csv('../data_for_recstudio/debug_inter_feat.csv', index=False)

# %%
test_inter_feat = pd.read_csv('../data_for_recstudio/test_inter_feat.csv')

# %%
debug_test_inter_feat = test_inter_feat.head(10000)

# %%
debug_test_inter_feat.to_csv('../data_for_recstudio/debug_test_inter_feat.csv', index=False)

# %%
products_data = pd.read_csv('../data_for_recstudio/products_train.csv')

# %%
products_data = products_data[['id', 'locale', 'title', 'desc']]

# %%
products_data.head(10)
# Out:
#            id locale                                              title  \
# 0  B005ZSSN10     DE  RED DRAGON Amberjack 3 - Steel Tip 22 Gramm Wo...
# 1  B08PRYN6LD     DE  Simply Keto Lower Carb* Schokodrops ohne Zucke...
# 2  B09MBZJ48V     DE  Sennheiser 508377 PC 5.2 Chat, Stilvolles Mult...
# 3  B08ZN6F26S     DE  AmyBenton Auto ab 1 2 3 ahre - Baby Aufziehbar...
# 4  B094DGRV7D     DE      PLAYMOBIL - 70522 - Cavaliere mit grauem Pony
# 5  B09JNNBDH5     DE  URBZUE Handwärmer, 10000mAh USB aufladbar und ...
# 6  B08R62WZ1Y     DE  Kinderkopfhörer Bluetooth, Mädchen Katzenohr K...
# 7  B09WK4YNX8     DE  8 Stück Herd Schalter Schutz, Küche Gasherd Kn...
# 8  B07KTKFYYS     DE  AVANA Edelstahl Ausstechformen 12 Stück Ringe ...
# 9  B0B9MPKYJK     DE  Amstory Stirnlampe LED Wiederaufladbar Joggen ...
#
#    price         brand              color              size            model  \
# 0  30.95    RED DRAGON                NaN               NaN          RDD0089
# ...

# %%
debug_products_data = products_data.sample(500000)
debug_products_data.sample(5)
# Out:
#                  id locale                                              title  \
# 1496386  B094W88NM1     FR  Oral-B Pro 3900N Brosse À Dents Électrique Rec...
# 1479591  B00IRV005E     FR  LaCie Rugged Mini, 2 To, Portable 2.5", Disque...
# 507402   B0B9H24GNS     DE  URAQT Masken Kinder, 12 Stück Cosplay Masken, ...
# 523728   B097CRQPCQ     JP                                 亀田製菓 つまみ種 120g×12袋
# 1140249  B09KH9V5J9     UK  Veno Scorp desktop PC Computer Bundle Intel i7...
#
#            price       brand                             color           size  \
# 1496386    99.90      Oral-B                            Ancien            NaN
# 1479591   115.99       LaCie                            Orange           2 To
# 507402     11.99       URAQT                                 A  Einheitsgröße
# 523728   2225.00        つまみ種                               NaN  120グラム (x 12)
# 1140249   409.99  Veno Scorp  Veno Nova Gaming Case - 2 X FANS        1TB SSD
#
# ...

# %%
debug_products_data.to_csv('../data_for_recstudio/debug_products_data.csv', index=False)

# %%
id_product_data = products_data[['id', 'locale']]
id_product_data.head(3)
# Out:
#            id locale
# 0  B005ZSSN10     DE
# 1  B08PRYN6LD     DE
# 2  B09MBZJ48V     DE

# %%
id_product_data.to_csv('../data_for_recstudio/id_products_train.csv', index=False)

# %%
id_product_data = pd.read_csv('../data_for_recstudio/id_products_train.csv')
sample_id_product_data = id_product_data.sample(100000)

# %%
sample_id_product_data.to_csv('../data_for_recstudio/sample_id_products_train.csv', index=False)
