# %%
import warnings
warnings.simplefilter('ignore')

import gc
import re
from collections import defaultdict, Counter

import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
from tqdm.auto import tqdm

# %%
df_sess = pd.read_csv('./raw_data/sessions_train.csv')
df_sess
# Out:
#                                                 prev_items   next_item locale
# 0                              ['B09W9FND7K' 'B09JSPLN1M']  B09M7GY217     DE
# 1        ['B076THCGSG' 'B007MO8IME' 'B08MF65MLV' 'B001B...  B001B4THSA     DE
# 2        ['B0B1LGXWDS' 'B00AZYORS2' 'B0B1LGXWDS' 'B00AZ...  B0767DTG2Q     DE
# 3        ['B09XMTWDVT' 'B0B4MZZ8MB' 'B0B7HZ2GWX' 'B09XM...  B0B4R9NN4B     DE
# 4                 ['B09Y5CSL3T' 'B09Y5DPTXN' 'B09FKD61R8']  B0BGVBKWGZ     DE
# ...                                                    ...         ...    ...
# 3606244           ['B086CYFSKW' 'B0874F9859' 'B086CYFSKW']  B07B5TYD76     IT
# 3606245                        ['B09NRZKZ7V' 'B08WJTPV93']  B08L1P4C3D     IT
# 3606246                        ['B085JFX7MP' 'B085JGHW8R']  B01MPWVD44     IT
# 3606247                        ['B00B0UING2' 'B00B0UING2']  B00D3HYEZ4     IT
# 3606248  ['B092S9D1SD' 'B09XQQ1S72' 'B0852MS7QC' 'B0B1V...  B0B7RX65YP     IT
#
# [3606249 rows x 3 columns]

# %%
idx_permu = np.random.permutation(len(df_sess))
train_num, valid_num = int(len(df_sess) * 0.8), int(len(df_sess) * 0.1)
test_num = len(df_sess) - train_num - valid_num 
print(train_num, valid_num, test_num)
train_idx, valid_idx, test_idx = np.split(idx_permu, [train_num, train_num + valid_num])
train_idx, valid_idx, test_idx
# Out:
# 2884999 360624 360626
# (array([1070973, 2705391, 1965079, ...,  944527,  723883,  163305]),
#  array([3275574,  575404, 1544217, ..., 3279956, 1506532, 1392533]),
#  array([2170579, 2845910, 2934909, ..., 2359272, 1718538, 1953586]))

# %%
df_train_sess = df_sess.loc[train_idx]
df_valid_sess = df_sess.loc[valid_idx]
df_test_sess = df_sess.loc[test_idx]
df_train_sess = df_train_sess.reset_index(drop=True)
df_valid_sess = df_valid_sess.reset_index(drop=True)
df_test_sess = df_test_sess.reset_index(drop=True)

# %%
df_pred = pd.read_csv('./raw_data/sessions_test_task1.csv')
df_pred
# Out:
#                                                prev_items locale
# 0       ['B08V12CT4C' 'B08V1KXBQD' 'B01BVG1XJS' 'B09VC...     DE
# 1                ['B00R9R5ND6' 'B00R9RZ9ZS' 'B00R9RZ9ZS']     DE
# 2       ['B07YSRXJD3' 'B07G7Q5N6G' 'B08C9Q7QVK' 'B07G7...     DE
# 3       ['B08KQBYV43' '3955350843' '3955350843' '39553...     DE
# 4       ['B09FPTCWMC' 'B09FPTQP68' 'B08HMRY8NG' 'B08TB...     DE
# ...                                                   ...    ...
# 316966                        ['B077SZ2C3Y' 'B0B14M3VZX']     UK
# 316967  ['B08KFHDPY9' 'B0851KTSRZ' 'B08KFHDPY9' 'B0851...     UK
# 316968  ['B07PY1N81F' 'B07Q1Z8SQN' 'B07PY1N81F' 'B07Q1...     UK
# 316969                        ['B01MCQMORK' 'B09JYZ325W']     UK
# 316970           ['B0B8JX92YJ' 'B09TN4MP6V' 'B0BG2LZQSL']     UK
#
# [316971 rows x 2 columns]

# %%
def str2list(x):
    x = x.replace('[', '').replace(']', '').replace("'", '').replace('\n', ' ').replace('\r', ' ')
    l = [i for i in x.split() if i]
    return l

# %%
next_item_dict = defaultdict(list)

for _, row in tqdm(df_train_sess.iterrows(), total=len(df_train_sess)):
    prev_items = str2list(row['prev_items'])
    next_item = row['next_item']
    prev_items_length = len(prev_items)
    if prev_items_length <= 1:
        next_item_dict[prev_items[0]].append(next_item)
    else:
        for i, item in enumerate(prev_items[:-1]):
            next_item_dict[item].append(prev_items[i+1])
        next_item_dict[prev_items[-1]].append(next_item)
# Out:
# 100%|██████████| 2884999/2884999 [03:03<00:00, 15724.33it/s]

# %%
next_item_map = {}

for item in tqdm(next_item_dict):
    counter = Counter(next_item_dict[item])
    next_item_map[item] = [i[0] for i in counter.most_common(100)]
# Out:
# 100%|██████████| 1269983/1269983 [00:18<00:00, 70325.41it/s]

# %%
next_item_map
# Out:
# {'B00X81MA0Q': ['B00X81MA0Q',
#   'B093STBTW6',
#   'B00X81M4FW',
#   'B01N24HPR2',
#   'B00JWKQ9JK',
#   'B09MM529WV',
#   'B077SMRXB8',
#   'B00X81GP9I',
#   'B093SVT4FX',
#   'B00X9X4JFW',
#   'B07Y1RZMHJ',
#   'B07G77V6GG',
#   'B0035FZIBI',
#   'B012NPT51Y',
#   'B00NXXNRBU',
#   'B0B5DN36ZZ',
#   'B01ID7YJ1M',
#   'B0BDMGX45M',
#   'B07ZY6W39F',
#   'B07NYFG5DG',
#   'B08ZJ76RH2',
#   'B0BBQZLGCQ',
#   'B0B3DMNRKL',
#   'B092ZM6JQK',
#   'B00X81GTCQ',
#   'B08P71LNNY',
#   'B0B554CWZX',
#   'B07G2H9NVT',
#   'B07MMSHC4R',
#   'B0888KRK3Z',
#   'B08QR6ZXQW',
#   'B01MR866BB',
#   'B007H4B768',
#   'B09PZ4H9YM',
#   'B0963CHQ6R',
#   'B012SRRMLM',
#   'B081TRYVS4',
#   'B017DO98JY',
#   'B00JWKQ7VA'],
#  'B07Y1RZMHJ': ['B086V6B85B', 'B07PZK2JSV', 'B09Y91XW98', 'B01G93MLGC'],
#  'B086V6B85B': ['B07Y1RZMHJ', 'B07S9NV1LC', 'B091YBGGBY', 'B0B98ZN7Z3'],
#  'B07S9NV1LC': ['B0BD9DWXBY',
#   'B09D178XW4',
#   'B09JCJT88S',
#   'B08D688LHQ',
#   'B00K6O5TM4',
#   'B09CP8FHT2',
#   'B07ZNB7VY4',
#   'B09MWH1PDT'],
#  'B0BD9DWXBY': ['B0BD9DWXBY',
#   'B09SW762K6',
#   'B08ZS9WTJ7',
#   'B09SP5PMYK',
#   'B0B11WXVTY',
#   'B0B1ZVVJV7',
#   'B0BBQN58LZ',
#   'B0B91WBBM6',
#   'B095BYB1BC',
#   'B09VGG8PTC',
#   'B07Q3PVZFR'],
#  'B09SW762K6': ['B091T4NPSM',
#   'B0B7D1RQLS',
#   'B07L13XS3S',
#   'B09SW762K6',
#   'B0B5NGSLR2',
#   'B09ZYLGXV3',
#   'B095BYB1BC'],
#  'B091T4NPSM': ['B091SZYF2D',
#   'B09G2VF7QK',
#   'B091SWTM19',
#   'B0B1ZVVJV7',
#   'B0B92ZSXM6',
#   'B07WV39YJ5',
#   'B09PS3613S'],
#  'B01MXM07AH': ['B01N7604K6',
#   'B09V135YCC',
#   'B09B64X65N',
#   'B01N361OGL',
#   'B074J5YQ3G',
#   'B083MWWC6J',
#   'B07W7PL9XG',
#   'B01H2SVW4K',
#   'B075FYHN21',
#   'B00Q3VSJ12',
#   'B086JQ5GKM',
#   'B006J23MHQ',
#   'B01MXM07AH',
#   'B0126KL8PM',
#   'B00EAN8PSM',
#   'B096W9JFYD',
#   'B08NB23TBR'],
#  'B01N7604K6': ['B01MXM07AH', 'B09MCHPNWJ', 'B08D97SHH8', 'B09DGLN1YB'],
#  'B09B64X65N': ['B097KGB88G', 'B0B1PWFTTQ', 'B072XD8M1B', 'B096W3BPGW'],
#  'B097KGB88G': ['B09B64X65N', 'B096W3BPGW', 'B075SD8YZL'],
#  'B096W3BPGW': ['B00D8AT01O'],
#  'B0BBM8YMDK': ['B0BBM7HZBK',
#   'B004I8S304',
#   'B00XHNJJKE',
#   '4065299470',
#   'B0015P7W4Q'],
#  'B0BBM7HZBK': ['B0BBM7KTZT'],
#  'B07LCKCHHK': ['B07PMJBF5W',
#   'B01N7TGKYE',
#   'B06XNV931T',
#   'B01N126LWY',
#   'B0BCDJYSQW',
#   'B09HXQDWSB',
#   'B0B45P8FNV'],
#  'B01N126LWY': ['B09J2V6C9Q',
#   'B07GLG2HVC',
#   'B07VCHKRVC',
#   'B08WW6G2LD',
#   'B08L4Z893K',
#   'B08L532G95'],
#  'B0BDDX2D7C': ['B08NF2JVXK',
#   'B0B1Q84Z38',
#   'B0BDDX2D7C',
#   'B0B9BMGX4J',
#   'B08M3PL67D'],
#  'B08NF2JVXK': ['B09LDFTJH4',
#   'B0B9GX5BM6',
#   'B07XZHTV2L',
#   'B0BG85YNZ4',
#   'B08JTH4256',
#   'B08NF2JVXK',
#   'B09HR6GVLG',
#   'B087FBFJ1Z',
#   'B08MT7JLZ9',
#   'B09MMGQ1C9'],
#  'B00GX27MH8': ['B00GX27MH8', 'B00P4EJ5US'],
#  'B09GBFPQSN': ['B09GBBXXBD', 'B01LX71LQP'],
#  'B09GBBXXBD': ['B01HSPMG6A', 'B09GBFPQSN'],
#  'B00ZZOYW8C': ['B00HKWAX0S',
#   'B00ZZOYW8C',
#   'B0029ZDRSQ',
#   'B00846UAZM',
#   'B01B1FW4Q0',
#   'B00GT5E7PY',
#   'B019XKETU4',
#   'B09WMT52G2',
#   'B01MPZNQ5V',
#   'B08NK7QQYW',
#   'B00AMZSGMM',
#   'B084T2RZBC',
#   'B076KS3NKM',
#   'B00ZCEOKBE',
#   'B099KDPLLF',
#   'B08N6DTPFK',
#   'B09BQYV6N8',
#   'B06XCX7MJ4',
#   'B09ZXYZCNP',
#   'B07KPX2JF9',
#   'B07DFMGPGM'],
#  'B00HKWAX0S': ['B01B1FW4Q0',
#   'B00ZZOYW8C',
#   'B00GT5E7PY',
#   'B019XKETU4',
#   'B0029ZDRSQ',
#   'B07DFMGPGM',
#   'B07BGLLS26',
#   'B07L9W8297',
#   'B07PRKLRYW',
#   'B00F2I4KRE',
#   'B0B821WVYZ',
#   'B09XQSZ88J',
#   'B08R6FK6T5',
#   'B08BTQ8CLG',
#   'B099KDPLLF',
#   'B0795DP124',
#   'B00GJSUXF4',
#   'B09WMT52G2'],
#  'B098CPKFMP': ['B09475X2TB',
#   'B098CPKFMP',
#   'B0794NVY6D',
#   'B07142VZH4',
#   'B08697RXCT',
#   'B0844X2QXP',
#   'B00U7MK8NU',
#   'B01NCZGPOD',
#   'B0792PT8QQ',
#   'B08K76QJK2',
#   'B098P86FVV',
#   'B084HDZFNH',
#   'B00QVXNJQ2',
#   'B0144MAGQM',
#   'B09V5P39DC',
#   'B08LDD565M',
#   'B07KT7YLJW',
#   'B099DHS1V3',
#   'B09LHCWB6L',
#   'B082VP9616',
#   'B07RLMWP7X',
#   'B08158HB65',
#   'B08TZVV739',
#   'B09475148T'],
#  'B07YTZTCFP': ['B07GYRVP61',
#   'B07YTZTCFP',
#   'B07ZNJCP6N',
#   'B08BWXK1FL',
#   'B08MJQ2L8B',
#   'B08JG1L6YC',
#   'B07ZF76TS7',
#   'B07WMTF539',
#   'B07VLBZY4D',
#   'B09ZYCBWYF',
#   'B07V3F2JFG',
#   'B07FQQKJ1V',
#   'B0B4C8WY5W',
#   'B004YEI7Y4',
#   'B08ZB6C9VC',
#   'B08PFWDZNL',
#   'B000GE3JO4',
#   'B0B6FHGMHT',
#   'B0B1DKWY3Q',
#   'B0117RGXC8',
#   'B09ZVH8PQB',
#   'B00L3KO5WK',
#   'B0874XMR5J',
#   'B07D94Z3JH',
#   'B09B3F2PH9',
#   'B08DJ8P377',
#   'B0B1JLNDHP',
#   'B08CT4W3JL'],
#  'B07WMTF539': ['B09B3F2PH9',
#   'B09NYC2CDT',
#   'B08DJ8P377',
#   'B09ZVH8PQB',
#   'B08BWXK1FL'],
#  'B07YMDZZT8': ['B08756F586',
#   'B07VW3Z2T9',
#   '3780663651',
#   '3965525212',
#   'B09K1T3D83',
#   'B09YM71WV9',
#   'B0B2RY72CF',
#   '3946739954'],
#  'B08756F586': ['B09L1HDFCP',
#   'B09K6LMPG2',
#   'B08756F586',
#   'B0B94QGNLS',
#   'B09LD67YMT',
#   'B07KX4WGNZ',
#   'B09YRPKGQV',
#   'B086VXCBP1',
#   'B095CD576K',
#   'B0B4CHW5KL',
#   'B0844RSYBQ',
#   'B074VZHN29',
#   'B09SZ1R3YP',
#   'B00VPY431C',
#   '3833240466',
#   'B0B3DN6CCY',
#   'B08KF6RJ4B',
#   'B09RBCTLF2',
#   'B091JCZNPN',
#   'B09WJ6XVGM',
#   'B083JTTQ1Y',
#   'B09659MBSX',
#   'B01F5SZERU',
#   'B07MTBZ18T',
#   'B074W82BTW',
#   'B07HBBN95G',
#   'B07Y3F9Z41',
#   'B074W58C65',
#   'B01F5T9WR2',
#   'B09B45BFY3',
#   'B08X1G2WWD',
#   'B07DYQPYPR',
#   'B09L1FTGHY',
#   'B09B49JW39',
#   'B085DFMFDS',
#   'B09K6LPPLS',
#   'B00417N2A8',
#   'B01M0UZZK7',
#   'B08LSDKWRW',
#   'B09MS1F9JN',
#   'B09NRBR497',
#   'B09L1GCZGD',
#   'B001LNPDRK',
#   'B08LSD122D',
#   'B07B5FK3BN',
#   'B0B94MBXP4',
#   'B0BB9RMD1N',
#   '3480236529',
#   'B09YRQCDG6',
#   'B09CLG5WKR',
#   'B09686CZLM',
#   'B07X9LJR3H',
#   'B0922THB6D',
#   'B07Y3Z2QYT',
#   'B09K6LLD3G',
#   'B07D7S6195',
#   'B08GKV8DR3',
#   'B08HS23N2D',
#   'B08P3JZNV4',
#   'B09D9FT4NL',
#   'B08SR72H4N'],
#  'B09K6LMPG2': ['B09K6LMPG2',
#   'B08756F586',
#   'B09WJ6XVGM',
#   'B09B45BFY3',
#   'B09K6M6MQF',
#   'B07VG247RL',
#   'B0B94QGNLS',
#   'B0BCYDPP97',
#   'B09Q3GMGF4',
#   'B07VY87S1J',
#   'B00NIQLKY8',
#   'B0B84SK641',
#   'B0B3JPD2CK',
#   'B0B74C4CC9',
#   'B01F5T6Q5I',
#   'B0BL75XG28',
#   'B07X5M7JYC',
#   'B07ZYCF82M',
#   'B08TWYTPST',
#   'B08LSPNG8X',
#   'B09B49JW39',
#   'B09PYKKV8Y',
#   'B08X1ZY2J7',
#   'B079TKVV3S',
#   '3649637863',
#   'B09YRQ2Z5G',
#   'B0B3DPJQHR',
#   'B08KF6RJ4B',
#   'B0B3DL3YVM',
#   'B09L1HDFCP',
#   'B0056KARKW',
#   'B09PZ6HJL8'],
#  'B09TZ5GRY2': ['B09ZLDWCBL',
#   'B095HXQ7R9',
#   'B0B1BD7R9Q',
#   'B06XNWQRN3',
#   'B09V19KNGH',
#   'B0B2NZNBQ7',
#   'B00E8H3I5A',
#   'B002SGS2MW',
#   'B003HHZJZY',
#   'B018GJUYL6',
#   'B07BQZNXWF',
#   'B09TZ5GRY2',
#   'B07R35GKCK',
#   'B003U28F9I',
#   'B00S9RGM7Q',
#   'B08CMHF21T',
#   'B08YJ4ZZJX',
#   'B083ZGRJJ7',
#   'B00FF81L4G'],
#  'B0B2NZNBQ7': ['B0B3NBW87B',
#   'B0B9R3MYHL',
#   'B0B2NZNBQ7',
#   'B09S917JCG',
#   'B08BP7TL2Y',
#   'B07VYRSY3X',
#   'B0B9RGN1L6',
#   'B0057DWZ0S',
#   'B09PY4BPFW',
#   'B0BG1L3GY3',
#   'B0B3MJQWVG',
#   'B085P27TZN'],
#  'B0B3NBW87B': ['B0B2NZNBQ7',
#   'B09SFXTKY6',
#   'B0B9R3MYHL',
#   'B0B5GF9TVD',
#   'B09Z2G1HNR',
#   'B0B8BT6739',
#   'B08L3K3W7C',
#   'B077XG37YC',
#   'B0B9RGN1L6',
#   'B09JSKYBV2',
#   'B09QJRD127',
#   'B09BN9SSGR'],
#  'B0B5GF9TVD': ['B098DMSHCS', 'B01HNYK9HY', 'B0BDYZKM7W'],
#  'B08R79MBRQ': ['B01LN4D2EW', 'B08R79MBRQ', 'B09GK8YNGC'],
#  'B01LN4D2EW': ['B004VRM3B2', 'B09RN5K22M', 'B00YIM4UN4'],
#  'B004VRM3B2': ['B085NXJPGQ',
#   'B00N4UF3ZK',
#   'B01K9TR2QG',
#   'B09GK8B837',
#   'B094JN7ZR3',
#   'B01M0NECB3',
#   'B09GK8YNGC',
#   'B004VRM3US',
#   'B014UU8JSU',
#   'B07GBSY1G3'],
#  'B09YP3VBMZ': ['B07PYQHLMZ',
#   'B07PVHCQ64',
#   'B07WRNQQRW',
#   'B09N81TM5M',
#   'B00TIS1M4I',
#   'B008C0IAGG',
#   'B0BBTQZM27',
#   'B09YP41H2G',
#   'B0956H2D6P',
#   'B0BD7JJLZG',
#   'B00CM3BCP0'],
#  'B07PYQHLMZ': ['B07PVHCQ64',
#   'B08BJKB74G',
#   'B09YP3VBMZ',
#   'B00TIS1M0C',
#   'B00MB9LUQ6',
#   'B014KNUXA4',
#   'B09YP41H2G',
#   'B014KNV2WC',
#   'B000FP3JYE',
#   'B07PWF6KTB',
#   'B09VB173NQ',
#   'B07YYDKYCC',
#   'B0BBTRKL6G',
#   'B06XTN3PZK',
#   'B08JSH7PB4',
#   'B0016GMNO8',
#   'B0BB67VRCT',
#   'B00CM3BCP0',
#   'B0916VHFXZ',
#   'B09C22FR6K',
#   'B0B1774GJV',
#   'B075JF9XCT'],
#  'B00MB9LUQ6': ['B00MB9LUQ6',
#   'B07PVHCQ64',
#   'B00TIS1M7K',
#   'B0B57DTPR9',
#   'B00COHI6X0',
#   'B09YP41H2G',
#   'B00TIS1M0C',
#   'B014KNV2WC',
#   'B01FF9NMN2',
#   'B09YP3VBMZ'],
#  'B00TIS1M7K': ['B00TIS1M0C',
#   'B014KNUXA4',
#   'B004BIYYO0',
#   'B014KNV2WC',
#   'B09YP3VBMZ',
#   'B09C22FR6K',
#   'B000FQP7HA',
#   'B00TIS1M7K',
#   'B002TK8T6Q',
#   'B09X6HTC56',
#   'B00MB9LUQ6'],
#  'B09X2NB8PF': ['B09X2ND9KK',
#   'B09X2MK5YM',
#   'B09X2MHXWH',
#   'B09X2NG8K8',
#   'B09X2NB8PF',
#   'B09X2M4422',
#   'B079YF7232',
#   'B079Y6B1MM',
#   'B018M71UJW',
#   'B004WCQUY2',
#   'B0986T225X',
#   'B08JGXNPPH',
#   'B018M735ZO',
#   'B09FP92GW3',
#   'B08LK59425',
#   'B018M7BC4K',
#   'B07ZTRR8RP',
#   'B004WCURXM',
#   'B07574NGQM',
#   'B09DKF9Z54',
#   'B00A128S24',
#   'B08BTQNWVN',
#   'B09NGFZB5G',
#   'B01FI02YL4',
#   'B00XU1MXCE',
#   'B07ZTS47LG',
#   'B08BTMD8HR',
#   'B01IVKQ6RG',
#   'B08618R4CZ',
#   'B08GRSPMXB',
#   'B09NH339JP',
#   'B09YVGVBH1',
#   'B0BBR5XPV6',
#   'B08VNLN7KK',
#   'B07SR3JMZG',
#   'B01C7B0S8S',
#   'B07S6PM7R6',
#   'B08BNNL8JJ',
#   'B00N2VIALK',
#   'B00QV1F1C4',
#   'B00BQDLJ3C',
#   'B018M6PR10',
#   'B07L5MRD5T',
#   'B07NZMY9NT',
#   'B07S8QR93Y',
#   'B08GS2HLQM',
#   'B08X45NX43',
#   'B09PZX4B11',
#   'B07QV4W8MW',
#   'B09FNVG12M',
#   'B07L5MMQGY',
#   'B004SUOVNU',
#   'B00N2VIWPY',
#   'B018M7F3MW',
#   'B00BQDLH7K',
#   'B08GQBYH13',
#   'B08GM2H1Q2',
#   'B004WCS98W',
#   'B09GY32ZZG',
#   'B08JGS87QR',
#   'B0B21453LP'],
#  'B07574NGQM': ['B0756WGL1L',
#   'B0756WD4CZ',
#   'B079DG52Q6',
#   'B00BS8IDNE',
#   'B09GY32ZZG',
#   'B08THJSBS4'],
#  'B0756WGL1L': ['B07574NGQK', 'B075734WD8'],
#  'B081MGSHTL': ['B081MGSHTL', 'B07Z89W1JN', 'B081K2BTVG'],
#  'B07Z89W1JN': ['B09X5XLZR9', 'B0BF62Q3Z7'],
#  'B09X5XLZR9': ['B01IT3KVB2',
#   'B00AP7TU2C',
#   'B097QHLHH4',
#   'B09X5XLZR9',
#   'B09XBR5RJQ',
#   'B07DJD51B3',
#   'B0744HJQK9',
#   'B000HRS7OM',
#   'B01AWH2WL0',
#   'B016O1QOTE',
#   'B08R9BRLJV',
#   'B002E2QNM6'],
#  'B00AP7TU2C': ['B00AP7TU2C',
#   'B01CNSNSPA',
#   'B01EYKV5LO',
#   'B0BG647MF9',
#   'B01GRWA4F0',
#   'B01M6625ME',
#   'B01LQ6DV7K',
#   'B07FT1CR5P',
#   'B0B77L23T3',
#   'B01BOS3I4G',
#   'B09X5XLZR9',
#   'B00MHQZK96',
#   'B017QJ4S6E',
#   'B00FW2A7MW',
#   'B081NB2T54',
#   'B004G920OK',
#   'B097S5CR1X',
#   'B07W7V8RTV',
#   'B00HBR7PPI',
#   'B089B13YN5',
#   'B017NVI9HY',
#   'B01GJ6IH7G',
#   'B07D3ZR4LT',
#   'B01C5YK17K',
#   'B00GBW0FLU',
#   'B0856JKBWG',
#   'B07CZVJ836',
#   'B01M6YSY6I',
#   'B07Y59HSM6',
#   'B086LWSFDH',
#   'B001E5S6TM',
#   'B001D484YQ',
#   'B0051C0HOG',
#   'B07HYSJW56',
#   'B00RXGAT7I',
#   'B07G46V3NZ',
#   'B00DB5QTQ0',
#   'B000KU91C8',
#   'B08LZZ7VTZ',
#   'B07FF569PN',
#   'B07Y7F4BRL',
#   'B00HP48OCU',
#   'B071XFCCJX',
#   'B091G2KKYD',
#   'B07S2RHS3H',
#   'B01B4073LS',
#   'B004G92ELE',
#   'B07D3GG47V',
#   'B01MRYH46R',
#   'B06VT29PWP',
#   'B01N3VS1ZW',
#   'B01LPQ43S2',
#   'B077S58B9G',
#   'B089FYG6JY',
#   'B018CV43M4',
#   'B08B8YZDJ2',
#   'B08M1DXCLX',
#   'B00QK68HQ2',
#   'B01BMA83MI',
#   'B01LX21YTZ',
#   'B00187GS7S',
#   'B01J13TUSE',
#   'B09QJ24S3N',
#   'B01KZ3Y84K',
#   'B004B99GBU',
#   'B096YBLCQC',
#   'B07GJS6QNP',
#   'B00VX2AHFM',
#   'B09V87L97C',
#   'B07PFDJJ3C',
#   'B0744HJQK9',
#   'B005TJYXZK',
#   'B003RRXGL8',
#   'B01LQPOU30',
#   'B072P5YSYM',
#   'B01LPOS21I',
#   'B082XG7KX3',
#   'B00L4KT8EO',
#   'B01ETRJC5I',
#   'B001E5ML16',
#   'B00ISCR7DU',
#   'B0BC9TXFLX',
#   'B0B6CTFYX6',
#   'B0037AWS0U',
#   'B08F2STD32',
#   'B08R9F1XGN',
#   'B01CDUSQ3W',
#   'B0132FQMI8',
#   'B00LZTHOW2',
#   'B0BBRMRPYJ',
#   'B00G3JNXPG',
#   'B01N4MB9I0',
#   'B079PH834S',
#   'B091FXSR6M',
#   'B091G84567',
#   'B00WJQ6OAI',
#   'B078PLFNHH',
#   'B0B1D4665T',
#   'B08F2QFZ5C',
#   'B01LF3VROS'],
#  'B07BGHDRZH': ['B07BGHDRZH',
#   'B07BK9F7WB',
#   'B01M36DP4F',
#   'B074C4L27M',
#   'B09HCST7TL',
#   'B077BXZTRG',
#   'B09S37TD4N',
#   'B08QSHKW7V',
#   'B07C1J5WN7',
#   'B07JVP37J5',
#   'B07NNWNXC8',
#   'B08KF1YLPX',
#   'B074T65KQL',
#   'B08DRS4L4X',
#   'B07P5S6B2C',
#   'B07BFG9HT5',
#   'B00B6D02SU',
#   'B0B15FKR8T',
#   'B01M27L452',
#   'B08XRR22V1',
#   'B07NS4RX11',
#   'B09Y1FG3B5',
#   'B0714CRJPT',
#   'B07F1JQZD3',
#   'B07X262WGJ',
#   'B0B15DMR1Z',
#   'B0845V9PDL',
#   'B0B2Q2VNQD',
#   'B09JCQCCYR',
#   'B082FDFWSQ',
#   'B01CJYM9WQ',
#   'B07JBC5SXY',
#   'B09NPKM7QG',
#   'B0992KG1MY',
#   '3550201729',
#   'B08T6BQ49Y',
#   'B07NN66VXH',
#   'B07K7FG65R',
#   'B082VNTQF9',
#   'B074CL5W23',
#   'B07BK96DRK',
#   'B0881S6SP5',
#   'B08X1RQCTT',
#   'B09R4NDW3N',
#   'B01LWJMCEV',
#   'B071FNS849',
#   'B0BK97CWLV',
#   'B096MH3R8Y',
#   'B092FP57J5',
#   'B003TRJ6X8',
#   'B089C1FL52',
#   'B07RKWV54M',
#   'B084VT6VG2',
#   'B07KN9SVT8',
#   'B07D7V6WC9',
#   'B09ZJBQSX5',
#   'B00NGRAOMS',
#   'B08KSF5C34',
#   'B000NQ4XU4',
#   'B08J48DNCN',
#   'B084GWB8YC',
#   'B07D4RV4M9',
#   'B07F84K9FR',
#   'B07JDJD31T',
#   'B08VRSX49Q',
#   'B0BB72419Y',
#   '3551183260',
#   'B0B3Y7JMWR',
#   'B071G83W8D',
#   'B07TDXV71T',
#   'B085FFS5B8',
#   'B008KWOABK',
#   'B0B4P5KTQZ',
#   'B074CK9ZN9',
#   'B004HL9D7Y',
#   'B09XRF3BSH',
#   'B09XXHW3G8',
#   'B01N9ILU86',
#   'B0013EG5QK',
#   'B01H1WPOF0',
#   'B01NBL9SWO',
#   'B081QQK82P',
#   'B084G4MJPB',
#   'B01M8JZIUW',
#   'B073GSMPNW',
#   'B0041MKE2C',
#   'B01LWMD8YA',
#   'B003ODMCJ2',
#   'B01AW92AOC',
#   'B09XF5VN8B',
#   'B08DG6FLK1',
#   'B07K1D8M1N',
#   'B01M7QCEUF',
#   'B0B7XJX81D',
#   'B07X3X5ZSB',
#   '3750509662',
#   'B09D3NXCBL',
#   'B07NPNFQ7W',
#   'B08F4JGKD9',
#   'B016KMI6KW'],
#  'B08KF1YLPX': ['B0B8T19ZMS', 'B09S37TD4N', 'B08KF1YLPX', 'B09NPKM7QG'],
#  'B09MZJ8FC5': ['B09BJCCN58',
#   'B085RMZTMD',
#   'B085N4KF7Y',
#   'B07V38Z171',
#   'B07T8XZB2C',
#   'B07SL6GN46',
#   'B09YTHCC4X',
#   'B00I4VIHGQ',
#   'B0866FPL6G',
#   'B073BK5CH3',
#   'B0BC8JZXT8',
#   '3849930688'],
#  'B09BJCCN58': ['B0B4NHT4R3',
#   'B07SL6GN46',
#   'B09BJCCN58',
#   'B085RMZTMD',
#   'B09MZJ8FC5',
#   'B08CK1Q29J',
#   'B09MDSBWHN',
#   'B0058GK5Q0',
#   'B09N72FXFG',
#   'B085WZQG8P',
#   'B07WFLBX6W',
#   'B071VNZ44T',
#   'B01H2T840E',
#   'B093L2VHBC',
#   'B0B68VLKMR',
#   'B09HC2XWRG',
#   'B08HGMWMG7',
#   'B087R81N4H',
#   'B08JLPTQX2',
#   'B073BK6KNB',
#   'B09YD3B8M5',
#   'B099SFDJS8',
#   'B0939VPQNF',
#   'B07T8XZB2C',
#   'B092W1JMMJ',
#   'B09F6FK5MG',
#   'B09BKRKV38',
#   'B09D454ZN1',
#   'B09S3MM3GT',
#   'B0B2ZV6SX4',
#   'B09XBQGML5',
#   'B01L0WGJD8',
#   'B08MVS9BNT',
#   'B0BGLG5J6F',
#   'B08Y6HKXSR',
#   'B01K435KOS'],
#  'B085RMZTMD': ['B07XDQV62H',
#   'B07SL6GN46',
#   'B09HH4YBWR',
#   'B09HS7BZY1',
#   'B07BQQY7C9',
#   'B085RMZTMD',
#   'B09BJCCN58',
#   'B09W2L8KJY',
#   'B082KGSJQV',
#   'B0B6PW11HX',
#   'B0B1V4T8FR',
#   'B09XQ9YSMT',
#   'B07KRN58WG',
#   'B0BF16MG5S',
#   'B07VQHQN83',
#   'B09YD3B8M5',
#   'B00FA1B7JM',
#   'B09MJPWRVZ',
#   'B09RPZ1CQ8',
#   'B09DX4S5P3',
#   'B079WCKGV9',
#   'B0989W8CPC',
#   'B09KGCDJ69',
#   'B00C3IBZCO',
#   'B08JLPTQX2',
#   'B0151IE88A',
#   'B09P8CXNH1',
#   'B08JMDNW1G',
#   'B08DTZ1R31',
#   'B0B5P7Z7P2',
#   'B09Y8RT7WL',
#   'B0B2WDDFMD',
#   'B01LWU54YY',
#   'B075GWPG1H',
#   'B0B7WX6PWC',
#   'B096G8BQYL',
#   'B0B7XK5KKL',
#   'B09MZJ8FC5',
#   'B0B1YCGHDQ',
#   'B07WGJXXQX',
#   'B0B68VLKMR',
#   'B01M0ZUIYP',
#   'B0B6P8GFM4',
#   'B09B49K68D',
#   'B0B7DHHH6Q',
#   'B09NWK1BTX',
#   'B09LVFG41Z',
#   'B08CMKK79N',
#   'B0B8HPHYB9',
#   'B08CDSXHRD',
#   'B097N54662',
#   'B07PN9BXZH',
#   'B09B554RRY',
#   'B09TNNJ632',
#   'B0BBR5L54B'],
#  'B07ZR9FV9R': ['B0811KH4PQ',
#   'B07ZRB2LB8',
#   'B07ZR9FV9R',
#   'B07ZR9DQ1H',
#   'B0BC69B95D',
#   'B088R7J2KJ',
#   'B0BD4TCZH5',
#   'B08KXK8FKJ',
#   'B0BBM11321',
#   'B0BHHV525T',
#   'B09YXSPFDP',
#   'B08YR5QPNP',
#   'B0BHWNLMNZ',
#   'B091DG1F1D',
#   'B088R85D98',
#   'B0BF9R16PS',
#   'B07ZTD5TH9',
#   'B0BDLCSX1P',
#   'B09PV7SHH1',
#   'B0BD78WT4C',
#   'B0822CWQP8',
#   '4046056037',
#   'B0B11K7WTR',
#   'B088R7PFTD',
#   'B0BDLFGYBZ',
#   'B07YTV6VWT'],
#  'B0811KH4PQ': ['B07ZR9FV9R',
#   'B07ZRB2LB8',
#   'B08KXK8FKJ',
#   'B07ZR9DQ1H',
#   'B0BC69B95D',
#   'B0BB2Q4S3V',
#   'B0811KH4PQ',
#   'B09SDWVD2X',
#   'B0BD4TCZH5',
#   'B0BCJZ7DW5',
#   'B0BBM11321',
#   'B0BF8WP7Z8',
#   'B08RRLH7T9',
#   'B081YVGY7Y',
#   'B09Z2HCQNW',
#   'B08ZHVHTMH',
#   'B07ZPF4LK1',
#   'B0822CWQP8',
#   'B0BG93C5DR',
#   'B0BGG5G3CQ',
#   'B0BDLFGYBZ',
#   'B0BGRNM3GH',
#   'B0BGN1JHWY',
#   'B07ZPGC343',
#   'B07PSZ8395',
#   'B0BHPMRWBD',
#   'B07ZPDX8TQ',
#   'B0BHHSL7LQ',
#   'B0BFHGR4KX',
#   'B09PV7SHH1',
#   'B0BF935DM4',
#   'B09J3RF6H7',
#   'B07ZVJMVPR',
#   'B00SH2RT1G',
#   'B08MWJJDLP',
#   'B014KNX4BE',
#   'B0BDLCSX1P',
#   'B0848HYSWR',
#   'B07SNP54DB',
#   'B0031ZF4Q6',
#   'B0BDLBFFGW',
#   'B09DK3TZ8Q',
#   'B0B11K7WTR',
#   'B0BDS9NPJ4',
#   'B0BDLCT515',
#   'B0786WWQR3',
#   'B01HELXUJK',
#   'B0BFDJFR1Q',
#   'B09NGJB3JN',
#   'B09SPWS5D6',
#   'B07ZZZXD63',
#   'B081SGSM4L',
#   'B0BDJGFWP4',
#   'B0BFNBW8Q6',
#   'B0BCFQKN8P',
#   'B07ZTD5TH9',
#   'B00MLXV2SS',
#   'B0948T72KR',
#   'B08MWD17FV',
#   'B0BGT7SCKB',
#   'B0B3M329XQ',
#   'B00FIWNDNG',
#   'B09PV8QR6L',
#   'B09MK2LQ5X',
#   'B089YQ5XC9',
#   'B09JR1HW5P',
#   'B0B9S8FQGM'],
#  'B07YS5HN6B': ['B08LDFWSMR',
#   'B08LDC7FZJ',
#   'B089QZWJTB',
#   'B07YS5HN6B',
#   'B0B1LN1CR5',
#   'B089DNMV22',
#   'B07QYYZLQP',
#   'B0B4NP789G',
#   'B07QYYLDZS',
#   'B08FC22RM2',
#   'B09Y19L5N9',
#   'B096MHVCG8',
#   'B08FHVB83C',
#   'B09MY6874N',
#   'B093GZ6DQ6',
#   'B09S5YDRQP',
#   'B0B7185PB9',
#   'B098WVJHNN',
#   'B07WZZV6WK',
#   'B07WGBMBMC',
#   'B098XGMQB8',
#   'B01GGKZ2SC',
#   'B07CWNJLQ8',
#   'B0BBDQJWYQ',
#   'B01GGKYKQM',
#   'B0BBDXLLQY',
#   'B08V5HY36V',
#   'B093H2N5F5',
#   'B07TQYL1GY',
#   'B089GFWZG4',
#   'B004044SMS'],
#  'B08LDFWSMR': ['B07YS5HN6B',
#   'B08LDC7FZJ',
#   'B08PTZQNXH',
#   'B09X1JC7FV',
#   'B09WZTNG9L',
#   'B09ZLDP4ZR',
#   'B08ZN71F7F',
#   'B09QHTNKWJ',
#   'B09CYZRKD6',
#   'B08CMPBMHZ'],
#  'B08PTZQNXH': ['B08PV3XKM2',
#   'B09WCZXSCH',
#   'B0922Q6QHK',
#   'B07Q4RS77F',
#   'B07YS5HN6B',
#   'B09HSHR3BH',
#   'B00DY25GBO',
#   'B09X2WZQSV',
#   'B08LDFWSMR',
#   'B08NB6Q5BL',
#   'B088RD6T3K',
#   'B09245QW52',
#   'B07RX3JWSB',
#   'B0B6B53QDM',
#   'B0B99SXCP8',
#   'B0B5GHK4HK',
#   'B09XJ251XK',
#   'B09P8KM9Z6',
#   'B0B99QRPDF',
#   'B01GGKYLW0',
#   'B08CN4DP59',
#   'B09XTR4HGZ',
#   'B07QPNRGYH',
#   'B09HXLXBBF',
#   'B07PP1X4MJ',
#   'B01GGKYN0A',
#   'B09WZVCMC4',
#   'B0B6HGS45F',
#   'B088FSHMQ3',
#   'B06XXT4HVJ',
#   'B0BFWNC7BL',
#   'B01N21I3CI',
#   'B09HY1KMWC',
#   'B088PK9HS8',
#   'B07GWPRPG4',
#   'B08FDN8G1X',
#   'B093KVQ1HF',
#   'B09XHVJ6ZD',
#   'B07PSGGFM1',
#   'B09FX2V7YH'],
#  'B08PV3XKM2': ['B08PTZQNXH',
#   'B0B6HGS45F',
#   'B09Y1VPG5Z',
#   'B087B7BNZV',
#   'B09XHQKQGN',
#   'B0B8Z6DB54',
#   'B003ZSW458',
#   'B09H6SBCVK',
#   'B09VTP886M',
#   'B0B1J6SN87',
#   'B09H6X38GC',
#   'B07Z75HBR2',
#   'B09KPDY1FQ',
#   'B0B6B53QDM',
#   'B08BPDVBHF',
#   'B0B1MBBP5M',
#   'B01MT9YU1J',
#   'B0BDRHC79Z',
#   'B000UX89AA',
#   'B08M9HLQ8D',
#   'B09P8KM9Z6',
#   'B09NKRC68S',
#   'B009RP9Z46'],
#  'B09Y1VPG5Z': ['B09CYZRKD6',
#   'B07WT36LPN',
#   'B09Y1K569N',
#   'B0BBVK3BTG',
#   'B0BBLMNCMJ',
#   'B0998J9Y9D',
#   'B091PT7ZHX',
#   'B09P8KM9Z6',
#   'B07QPS7L6Y',
#   'B0BGXCFBWR',
#   'B09Y1VPG5Z',
#   'B0BF4ZSFT1',
#   'B085DH3KJG',
#   'B088PK9HS8',
#   'B09Y1BK42B',
#   'B09YL7BNKQ',
#   'B08L6Q43HF',
#   'B07PLSDPYN',
#   'B09JS95ZVH',
#   'B08F4XFFWY',
#   'B0B5MHJL1T',
#   'B0B3HPNY7V',
#   'B09S642Y37',
#   'B091SSJVY2',
#   'B09PDHJNS4',
#   'B07PRVL4KY',
#   'B07PCLY6LT',
#   'B08L523DNW',
#   'B0B1J6SN87',
#   'B0952RHQNM',
#   'B0B1537VZF',
#   'B0776YC2KF',
#   'B08CBDZM6L',
#   'B08YRKT5LY',
#   'B0BBGYBLHT',
#   'B07JD69ZYT',
#   'B08BP75NYD',
#   'B00K5CN73A',
#   'B09WH6Y3WQ',
#   'B0B2WHGT5P',
#   'B086Z38HP9',
#   'B09VYYJR3V',
#   'B095GNGP6S',
#   'B09983XPM9',
#   'B09JGJR226',
#   'B09Y5HH44X',
#   'B07PPY9N62',
#   'B096TW9VH9',
#   'B09MQ4KZ27',
#   'B09ZPCTZV3',
#   'B01E9IZUSU',
#   'B01GGKYN0A',
#   'B09KQLLRJL',
#   'B092H5S945',
#   'B07NT191B1',
#   'B0B8JTP7NL'],
#  'B09Y1K569N': ['B09Y1VPG5Z',
#   'B09CYZRKD6',
#   'B0922Q6QHK',
#   'B0BBVK3BTG',
#   'B09BVCJPDG',
#   'B08FDJ36XW',
#   'B088FSHMQ3',
#   'B09CYMV578',
#   '1407193554',
#   'B08M9C6DGL',
#   '1473215269',
#   'B09XTR4HGZ',
#   'B07WT36LPN',
#   'B08GL7F15X',
#   'B00DWXME9C',
#   'B01GGKYN0A',
#   'B08JVG5XK6'],
#  'B07MCTZBMB': ['B07SP3WV77',
#   'B098PBNHKM',
#   'B089MGRYY7',
#   'B098QDNVDT',
#   'B08RGRVKJL',
#   'B08ML7RQQQ',
#   'B08R8G64PK',
#   'B08CNHHVRW',
#   'B09YVRVNQK',
#   'B07STKWFX9',
#   'B08RGT4DBD',
#   'B07MCTZBMB',
#   'B089MGZSGF',
#   'B08RG977GR',
#   'B08R8G42WS',
#   'B098TJ49G3',
#   'B06Y12PQJ8',
#   'B08KF73HSH'],
#  'B089MGRYY7': ['B089MGZSGF',
#   'B07MCTZBMB',
#   'B0BCJXLNNW',
#   'B09YVRVNQK',
#   'B097CXGBWX',
#   'B08HT5GVS8',
#   'B08R8G64PK',
#   'B07MGH37NL',
#   'B09TPWSFZ4'],
#  'B08CVY3M6K': ['B07JRFVDQ6',
#   'B08CGZPBDD',
#   'B08CVY3M6K',
#   'B01LY4151V',
#   'B07W9CNH29',
#   'B099N1477L',
#   'B0BHWNQB9G',
#   'B08T6WTVBG',
#   'B079S74M6N',
#   'B0828RYV3R',
#   'B09QPR6LKM',
#   'B06WWPFM9Z'],
#  'B07JRFVDQ6': ['B07JRFVDQ6',
#   'B0828RYV3R',
#   'B09QPS7QD8',
#   'B08L7B2G73',
#   'B0B2WGKKYN',
#   'B071JDDJGY',
#   'B0824R99HC',
#   'B0986QDLPM',
#   'B09QPJGQG4',
#   'B086T8PZPG',
#   'B09HZCZ4LC',
#   'B08YF57GPQ',
#   'B083X36N8G',
#   'B00FGIYCLE'],
#  'B07XC7QMND': ['B08HL79J5S',
#   'B08KGMQ8JG',
#   'B07XC7QMND',
#   'B01J5FS2JQ',
#   'B0B3SSF2YQ',
#   'B09DHY7XHL',
#   'B09BN3PMQF',
#   'B0B8DX4ZKL',
#   'B000LWCPV4',
#   'B09FQ8T587',
#   'B0B4GNSWLC',
#   'B0BC8V23L1',
#   'B095WWCJ8C',
#   'B0B441GHBY',
#   'B07VQ7YQW4',
#   'B00SFZWE60',
#   'B0BCVWCSDY',
#   'B01FM3CPIE',
#   'B08HLT4TL4',
#   'B08B66J4DZ',
#   'B0BG4QFNXC',
#   'B0B2K3QRBZ',
#   'B0B3RLL3B5',
#   'B0B9XL3MR3',
#   'B0B66MLP1C',
#   'B0B93CYK1G',
#   'B073R78ZQ4',
#   'B0B4GNPJ5Y',
#   'B00VTMZ508',
#   'B0B4KBWH2N',
#   'B012TPA576',
#   'B0B3XFBMNQ',
#   'B09DTZKR8S',
#   'B08HL8DZHM',
#   'B07YFJ7V5Y',
#   'B09TYSFRF5',
#   'B07THKRWWC',
#   'B08KTM9T74',
#   'B07JMV4X1N',
#   'B0B58S4G9Y',
#   'B091383DR8',
#   'B09QLN6GFC',
#   'B08G1HSX76',
#   'B06XMZ99XL',
#   'B07GZ2WQF6',
#   'B09QZY2F6V',
#   'B0B76KW53V',
#   'B074G59SYH',
#   'B0B8NC489S',
#   'B09TYV79NV',
#   'B07VD4529F',
#   'B0B38CT6JR',
#   'B0B7J1NW64',
#   'B0B4C2NLZY',
#   'B0BCKSXHR5',
#   'B07DCT7CRX',
#   'B0BBWHKDK7',
#   'B07Z7LB9C6',
#   'B09B6WYMCX',
#   'B01FQS6338'],
#  'B08HL79J5S': ['B08HL8DZHM',
#   'B08HL6W3M9',
#   'B08HL7NV2D',
#   'B08HHSRL1D',
#   'B07XC7QMND',
#   'B08HL79J5S',
#   'B08HHSSZ13',
#   'B07Z7LB9C6',
#   'B0B5QP28GP',
#   'B08PFGN271',
#   'B07QZK3CJH',
#   'B07QZHD8DC',
#   'B07GZ2WQF6',
#   'B096RZQF8X',
#   'B08JGYGQ57',
#   'B0B4C2NLZY',
#   'B0B3XFBMNQ',
#   'B09D43X465',
#   'B09ZTT4G2R',
#   'B093LFCXXL',
#   'B09R8S4VJK',
#   'B0B81J9DLW',
#   'B0B7F9MVNL',
#   'B001KYTULU',
#   'B0B3DGR3Q3',
#   'B00BBLD8CO',
#   'B0B58SM68G',
#   'B0B6QGGCNK',
#   'B09DHY7XHL',
#   'B09DYQLQQ2',
#   'B08KGMQ8JG',
#   'B07J5RV3SW',
#   'B07YJTBN2Y',
#   'B0BC8Z3V9V',
#   'B07TTMMD1R',
#   'B07H4T3JM8',
#   'B01FX9110U',
#   'B0B8DX4ZKL',
#   'B07XY82L1T',
#   'B0B638DCG1',
#   'B0013HI448',
#   'B083J3VTRC',
#   'B07W6D9ZXR'],
#  'B0B5QP28GP': ['B0B8HKTPZ8',
#   'B0B5QLX46V',
#   'B0B5QPDGD6',
#   'B0B5QMBP55',
#   'B07J55PC6J',
#   'B09DYQLQQ2',
#   'B0B8SLSWYJ',
#   'B0B8SMRD31',
#   'B08CMG21TZ',
#   'B0BC7Y8FQH',
#   'B0046MK34G'],
#  'B0B8HKTPZ8': ['B0B5QMBP55',
#   'B0B8HKLJ36',
#   'B0B5QP28GP',
#   'B0B8HJ82FS',
#   'B0B8NCFCFR',
#   'B08HL79J5S',
#   'B0BDXRWTDT',
#   'B0B8SMRD31',
#   'B0B5QLX46V',
#   'B0B5QPDGD6'],
#  'B0B5QMBP55': ['B0B8HKTPZ8', 'B0B8HKLJ36', 'B0B5QLX46V', 'B0B5QP28GP'],
#  'B0B8HKLJ36': ['B0B5QP28GP',
#   'B0B8HKTPZ8',
#   'B0B5QLX46V',
#   'B0B5QPDGD6',
#   'B0B3XKQ69W',
#   'B0B5QMBP55',
#   'B09N13NXV4'],
#  'B0B5QLX46V': ['B0B8HKLJ36',
#   'B0B5QMBP55',
#   'B0B3SSF2YQ',
#   'B08HL79J5S',
#   'B00MOA1R92',
#   'B0B8HKTPZ8',
#   'B09BN3PMQF',
#   'B0B4SKF7ZL',
#   'B0B56CKQ16',
#   'B07XC7QMND'],
#  'B08HL8DZHM': ['B08HL79J5S',
#   'B08HL7NV2D',
#   'B08HHSSZ13',
#   'B083J3VTRC',
#   'B00V9VXEKW',
#   'B08JCLHJ8L',
#   'B07VD4529F',
#   'B08KZF8M9N',
#   'B07MZRDJZR',
#   'B09J4NF2WK',
#   'B0B3RCGQ2H',
#   'B0B5GNK9FY',
#   'B0087PGNOM',
#   'B0B638DCG1',
#   'B08KJKSLG4',
#   'B0B59291TM',
#   'B07XC7QMND',
#   'B07LFCBKVC',
#   'B00B2MNI8G',
#   'B09FQ8T587',
#   'B098P8YKXC',
#   'B08HL8DZHM',
#   'B09NCZ9967',
#   'B0B3XBS1P7',
#   'B07Z7LB9C6',
#   'B0B7GHP34F',
#   'B08HL6W3M9'],
#  'B07GZSLLZH': ['B07H114P4P',
#   'B08WLPHXGR',
#   'B07GZSLLZH',
#   'B095P1LYFD',
#   'B08WLSR31L',
#   'B07WV4XBSP',
#   'B09RMWYTKB',
#   'B09249965M',
#   'B09CQB8MFY',
#   'B07GZY34LP',
#   'B097RC619B',
#   'B07431K27K',
#   'B09KVFBWX1',
#   'B08WJFWG2J',
#   'B0B3212744',
#   'B0972RD6F5',
#   'B097ZKFTC3',
#   'B07WV54L4Z',
#   'B0753929DV',
#   'B09Y27KBDJ',
#   'B089QPVBGB',
#   'B07WY7QZ27',
#   'B07MS83V2L',
#   'B09GKWQJJQ',
#   'B09KVD43Z8',
#   'B09GB5F1T4',
#   'B08WHL2GCG',
#   'B0B4SN4RF5',
#   'B09RN21CG7',
#   'B09V55TH1F',
#   'B0001P0CC0',
#   'B0932XVHZ5',
#   'B07TTS7T3R',
#   'B07GTWD7Z7',
#   'B086JZ2R3Q',
#   'B07H4GTXBK',
#   'B07Y35RPDP',
#   'B07G5NJLGR',
#   'B077G9RB5X',
#   'B096GWRLMD',
#   'B00LN803K0',
#   'B0935DN1BN',
#   'B09NZHFGJY',
#   'B08R8X3HPV',
#   'B077PY79TM',
#   'B086LLYK4S',
#   'B08NVV6QML',
#   'B07GBSQKL5',
#   'B08K3L33Y2',
#   'B01J3B3HJW',
#   'B09RN1DXQ5',
#   'B087DFLF9S',
#   'B07BV58HDQ',
#   'B07WP5QQTJ',
#   'B01L6L46LK',
#   'B09MTV8FYZ',
#   'B0834NJ9MW',
#   'B09X4GNB7B',
#   'B01EA0NF8E',
#   'B09GB6CD1P',
#   'B08FGMNGXK',
#   'B0BG47GNPZ',
#   'B07G5L596T',
#   'B09GB67WH6',
#   'B08J3KMJL3',
#   'B07B8TXNPR',
#   'B08131HFSG',
#   'B07538S1M9',
#   'B07X8MTP5M',
#   'B08TJ2649W',
#   'B09G9B4SH9',
#   'B0B322FBD2',
#   'B09GV96C33',
#   'B098N5CNM3',
#   'B08PKQLBWT',
#   'B01EA0HDRI',
#   'B0BGL8W9BF',
#   'B09Q5MJFR1',
#   'B09GB5XQY5',
#   'B08PKPL4NK',
#   'B07JDSHD4Z',
#   'B096MLG6WR',
#   'B000FWHWGS',
#   'B09Y2BD1Q9',
#   'B01FSGVN4M',
#   'B08HLYB6MW',
#   'B07RXPRB9N',
#   'B07CJGDM9W',
#   'B08WJ8SMRK',
#   'B09MTVD98J',
#   'B003N2P71E',
#   'B08JGC849Z'],
#  'B09V55TH1F': ['B0B3RKDM2Q', 'B09V55TH1F', 'B097F4VKW1', 'B08958WBQN'],
#  'B07V8H9HR6': ['B0764HS4SL',
#   'B07V8H9HR6',
#   'B08TC2XL36',
#   'B09PFYM1CR',
#   'B0BGT8RM1M',
#   'B07QKHTM11',
#   'B07PSGP69B',
#   'B07WBXRBMN',
#   'B07VG4S38C',
#   'B0BCSMDXJT',
#   'B07ZMY8YDX',
#   'B073CPVBYT',
#   'B07WCNWNCC',
#   'B07K6T3V4M',
#   'B09PG1D5D9',
#   'B0927VMTXT',
#   'B008SSY4WQ',
#   'B01M1EEPOB',
#   'B08ZRWTMQH',
#   'B079284SM1',
#   'B07JP39G3J',
#   'B0B18FSSWP',
#   'B01ATHBWXM',
#   'B09JNR1TG6',
#   'B08SVPLGHH',
#   'B088ZR8F1Y',
#   'B01LFANFVY',
#   'B0B8Z7JTD1',
#   'B095HD8S6G',
#   'B09NSL1FY4',
#   'B0B2KM6S9P',
#   'B09BJWL1GQ',
#   'B08Q86QRZB',
#   'B0895TB27G',
#   'B01BVOXVF4',
#   'B09WTX3VC2',
#   'B07V3MP3Z4',
#   'B0B1M6XCSP',
#   'B00QS6ZXH0',
#   'B0B7KXT53K',
#   'B00ITJEBQ8',
#   'B00DW0GLDA',
#   'B07VJ5XJP9',
#   'B000YDO2LG',
#   'B08QFQDXHB',
#   'B07TLVN8TP'],
#  'B073CPVBYT': ['B007UOLH7Y'],
#  'B007UOLH7Y': ['B002VZY62K', 'B0774YX24H', 'B08QYZHYRJ', 'B001HUA7N2'],
#  'B002VZY62K': ['B0B7N4GVBR',
#   'B0774YX24H',
#   'B007UOLH7Y',
#   'B0B7N2Q78X',
#   'B0B7N44FNM',
#   'B002EPBL1Q',
#   'B002VZY62K',
#   'B001P4WGQ6',
#   'B0B7MTZCN9',
#   'B079VXVMPN',
#   'B002TW5U5C',
#   'B077XBJSSV',
#   'B001GLG7C2',
#   'B07PJCMDKR',
#   'B09KM4ZR7C',
#   'B00YPJM7HG',
#   'B000WIQLG2',
#   'B015KXE3UO',
#   'B093QB4PSF',
#   'B0007OEI70',
#   'B00OGMTNT2',
#   'B08ZD81FQ1',
#   'B06XKBSBWK',
#   'B08TLS82Y2',
#   'B08N7V9H7X',
#   'B003ZIQ8K0',
#   'B01LW0GC0R'],
#  'B0774YX24H': ['B002VZY62K',
#   'B0B7N44FNM',
#   'B09BCCLGPG',
#   '1907860045',
#   'B07BMZJSXR',
#   'B001UAAKIG',
#   'B08M3MCY77',
#   'B007UOLH7Y',
#   'B004RYE9IY',
#   'B0B7N4GVBR',
#   'B004MAPFHM',
#   'B01J9VJQGY'],
#  'B09BCCLGPG': ['B094Y19W7K',
#   'B09B78G2YC',
#   'B09BCCLGPG',
#   'B08HZ2F3CZ',
#   'B0BG4BTMJ4',
#   'B08X7L9RL3',
#   'B09FJYP9GK',
#   'B0B5QKZRJC',
#   '1472109791',
#   'B09ZTV34JR',
#   'B09TK6ZKNX',
#   'B07JLFJN2L'],
#  'B0BH8RV9WN': ['B092VK5S1W',
#   'B07YQZWHGZ',
#   'B09ZLGDH56',
#   'B0B6RDBGDY',
#   'B09SKZ7XYS',
#   'B09HXG31SG',
#   'B08CGCG5NR',
#   'B09TPD625R',
#   'B08R5ZH8QM',
#   'B0B31SP2XJ',
#   'B0BH33GWL5',
#   'B07YSWNC3P',
#   'B01MXY8X66',
#   'B0BDYRNNWT',
#   'B0B45TX734',
#   'B08FSL3CD6',
#   'B08438G2FD',
#   'B0BCWVZF1H',
#   'B0845NMW2B',
#   'B00GFQLY0S',
#   'B09ZTNP6QN',
#   'B09FSWB82P',
#   'B08L95C4DJ',
#   'B08Q22CMG8',
#   'B08Y5QGPRK'],
#  'B07YQZWHGZ': ['B07YQZYN67',
#   'B09CTJRDK5',
#   'B09MYHHYRM',
#   'B0B2WLVKBV',
#   'B09WQZWK2L',
#   'B08XVWZ5W4',
#   'B08ZDL7WKN',
#   'B01MSJTHEN',
#   'B0BF4ZDFJ6',
#   'B07W4889BB',
#   'B0B2WGR1FL',
#   'B08X1FFCNH',
#   'B08Y5QGPRK',
#   'B0B68LW3DS',
#   'B08LT9MG2G',
#   'B0986WYLHV',
#   'B07YSLYZCK'],
#  'B07YQZYN67': ['B07YQZWHGZ',
#   'B07WVCGBKG',
#   'B07PQFY4F1',
#   'B07XT3PDC1',
#   'B0B58XP4GY',
#   'B007A28P2G',
#   'B09VZ7VGY6',
#   'B08FFWVV2N',
#   'B09WDL1XQM',
#   'B083BXZFRF',
#   'B0BH8RV9WN'],
#  'B07WVCGBKG': ['B0BF4ZDFJ6',
#   'B07WPD55MG',
#   'B094Y6C6RS',
#   'B0BF4SRLZN',
#   'B0BF4Z184Z',
#   'B0BF4T3L9Y',
#   'B0BF4XHLNQ',
#   'B0BF4T1QPJ',
#   'B09BQP3F3H',
#   'B0BF4YRL12',
#   'B0BF4SRXKT',
#   'B0B2WC4FZ3',
#   'B07L93T7LK',
#   'B013DY5GY4'],
#  'B08Y6MFZXT': ['B0BCY5M2TD',
#   'B099277D7Q',
#   'B08PCGM58Y',
#   'B082VSYX17',
#   'B09MFB8YQX',
#   'B099999999',
#   'B078LY9LZB',
#   'B09FM1LPPT',
#   'B07XFMQ6FK',
#   'B09M6TQ8HM',
#   'B09T9Y4DWG',
#   'B09VPD9H58',
#   'B0B78JC6M6',
#   'B07R6W9NPT'],
#  'B0BCY5M2TD': ['B07X2FH5TT',
#   'B0B37MDZCW',
#   'B0B1TQ2X1H',
#   'B08Z2V87VV',
#   'B0B9BFL5QH',
#   'B09YLF4VHV',
#   'B08H282495',
#   'B08PZJXMND',
#   'B0B25DFK76',
#   'B0BDFYWZ58',
#   'B08H25M88K',
#   'B08H2KJVCF',
#   'B0928VF6ZK',
#   'B00TILP8UE',
#   'B0B74YJLR5',
#   'B09B44P94N',
#   'B09HKNNPSQ',
#   'B07HCYJCZ2',
#   'B0BG21WC1D'],
#  'B07X2FH5TT': ['B07YCQ1FBV',
#   'B09BQCN22F',
#   'B09HKNNPSQ',
#   'B08CDSCG28',
#   'B09BQ8678L',
#   'B09KLFR7SP',
#   'B08M3PL67D',
#   'B07X2FH5TT',
#   'B07K34JR2D',
#   'B08LGZBLRN',
#   'B0B9RVSXWR',
#   'B0B6FM1ZLV',
#   'B07BFJXW4Y',
#   'B09LHC4Q34',
#   'B091NJQQC8',
#   'B0B51FQL5C',
#   'B09984L689',
#   'B08JCTQPXN',
#   'B0999BBMXK',
#   'B09BQ17XLL',
#   'B08G4YF27T',
#   'B0BHXKFWD5',
#   'B0B7GFQQTL',
#   'B0B71V6JB8'],
#  'B07YCQ1FBV': ['B08CDSCG28',
#   'B09BQCN22F',
#   'B07X2FH5TT',
#   'B0BCKF93K8',
#   'B0995CF9VZ',
#   'B0B3DH55T5'],
#  'B082BCP94X': ['B081QMCNP7',
#   'B082BC6BTJ',
#   'B081P2NS7Y',
#   'B0B7RHXKXD',
#   'B075WP24JR',
#   'B07PXYM82F'],
#  'B0B7RHXKXD': ['B0B7RHDW64',
#   'B08WSFKSR3',
#   'B08WMJ7WN4',
#   'B07N3P5VX4',
#   'B091PJNLCB',
#   'B0B7RHXKXD',
#   'B0B3MNSCS8',
#   'B0BCVS9ZV5',
#   'B08WMJC5BC',
#   'B09YCYTVRW',
#   'B09BJ2PKG3',
#   'B00ITAP8P0',
#   'B014KNYLQQ',
#   'B09BVQ1GNZ',
#   'B08TBP17B9',
#   'B079NGJF8V',
#   'B0B1HD4C5K',
#   'B00DCLX8KI',
#   'B08WMJ1WF4',
#   'B07W5CW9MS',
#   'B09FXR1FY2',
#   'B08BHP4PWF',
#   'B09C7N8CLJ',
#   'B09C7LPC7M',
#   'B07HGPCFBN',
#   'B00BC9PJMM'],
#  'B0B7RHDW64': ['B0B7RHXKXD',
#   'B09C7N8CLJ',
#   'B08WMJ7WN4',
#   'B09BVQ1GNZ',
#   'B09BVPHSD1',
#   'B08WSFKSR3',
#   'B0B7RHDW64',
#   'B08WMJB5WV',
#   'B08WMJ1WF4',
#   'B08WMJ1WF1',
#   'B09N7Z3JSX',
#   'B00ITAP8P0',
#   'B086VJ7RF7',
#   'B001JF68MY',
#   'B083NTHVJV',
#   'B07NSXTVS8',
#   'B0BC1GR39G',
#   'B08YDY59RP',
#   'B0B3NDQJSP',
#   'B091PJNLCB',
#   'B09C7LPC7M',
#   'B07SQDLL6Q',
#   'B00SRJ3MXI',
#   'B07T3JNTHV',
#   'B092GVMGXX',
#   'B09PY4134Y',
#   'B0BG794FYW',
#   'B09R9YK1HY',
#   'B07V6JY7KB',
#   'B09S5T1BST',
#   'B01MD1KQLK',
#   'B08WMGW1WX',
#   'B0B6BX35HB',
#   'B0BL2NM2R6',
#   'B0BGLPGGFJ',
#   'B0BCVS9ZV5',
#   'B07Y9Q967H',
#   'B0BFRBGRMP',
#   'B002ZB7FRS',
#   'B08SJP7LC4',
#   'B08WMJC5BC',
#   'B079ZT46DG',
#   'B07W11MKKT',
#   'B0141ZO8FC',
#   'B00PIHO3NK',
#   'B09S5L8L4Q',
#   'B09T33KG57',
#   'B07QH9H46K',
#   'B08Y8WJ32Q',
#   'B07N3P5VX4',
#   'B07VMW1PV2',
#   'B01LYPSYHL',
#   'B07W52YN5T',
#   'B011KE34FW',
#   'B09KKV88G7',
#   'B000QVW100',
#   'B0B5658SQT'],
#  'B07NSXTVS8': ['B073NYQ6DD',
#   'B01DLT1ZTQ',
#   'B01L8QWR32',
#   'B075CHM774',
#   'B07NCD6ND2',
#   'B08CMMHWWF',
#   'B0BD88WWQ8',
#   'B07WZNYCD1'],
#  'B073NYQ6DD': ['B07NSXTVS8',
#   'B0B81Q4KHQ',
#   'B09TR5ZNHV',
#   'B08DTPGDFY',
#   'B07JYLN838',
#   'B0987SWS3R',
#   'B09JLQRRX4',
#   'B005CMGTJ2',
#   'B08CMMHWWF',
#   'B0978P13SH',
#   'B01N4UYOD7',
#   '490920217X',
#   'B09PNMXRY5',
#   'B09VB36L68',
#   'B097GYF5QF',
#   'B07XKMYWJ5',
#   'B01DLT1ZTQ',
#   'B085GDPP6K',
#   'B08K8ZT3MY',
#   'B076M7PNJR',
#   'B08B7V3XGK',
#   'B083PQZVFT',
#   'B0BCPCSYJV',
#   'B09ZQBRY35'],
#  'B07JYLN838': ['B07JYLB1WR',
#   'B07JYYS55P',
#   'B07YLC5BYV',
#   '4065292883',
#   'B07F29BW99',
#   'B07BGTV9PS',
#   'B09MVW9W8F',
#   'B00UH9NCT0',
#   'B01G78HLW8'],
#  'B07JYLB1WR': ['B07JYLN838',
#   'B07JYYS55P',
#   'B07JYLB1WR',
#   'B07YLB5GDN',
#   'B0B9RXQLZ4',
#   'B0B2V3C13K',
#   'B0876YZ5HT',
#   'B0BL6QPFJZ',
#   'B09NXMPHCQ',
#   'B01M0RVE02',
#   'B07B45KHNP',
#   'B0B9JZ9H29',
#   'B071XTGPN2',
#   'B0B77FL5TG'],
#  'B0B2LLHB16': ['B0B2LLHB16',
#   'B07XNH4DV8',
#   'B0B72QV9B9',
#   'B0B2LKRTYP',
#   'B09C3DJ25B',
#   'B0B18CK9DV',
#   'B0B9264QRH',
#   'B0B73NLB4D',
#   'B0BB28SJQQ',
#   'B0B4WGZTDS',
#   'B09YRJ98WV',
#   'B0BJ7MY9RH',
#   'B01KNWYGMW',
#   'B0B6VLZJ5N',
#   'B09CM1NNBP',
#   'B09B3837VT',
#   'B09FD6THRV',
#   'B09FF3R7KH',
#   'B0B713YWC6',
#   'B08TBXTN3D',
#   'B0B5WBDHGR',
#   'B09R19DQY3',
#   'B0BJ7K4NYX',
#   'B07XNLCK6D',
#   'B01HJFE2FW',
#   'B08FMKCDWX',
#   'B08DFFCMKQ',
#   'B093V6RJ3B',
#   'B01HILH94S',
#   'B07XS87CGH',
#   'B07VNMGPGL',
#   'B09Z8FPLKP',
#   'B0B6HHQFG3',
#   'B08ZMQT158',
#   'B0B4N6FCYF',
#   'B0B73QT8H1',
#   'B08BW4GDJR',
#   'B07ZG2592D',
#   'B015O6R3J0',
#   'B015J3W7ZI',
#   'B09BCQC2CN',
#   'B0B68Y73SX',
#   'B0BDLJ2463',
#   'B08FJ6PQCX',
#   'B0B7V6ZSS8',
#   'B07DRDRNM8',
#   'B09K7Z9RQ5',
#   'B07VPGT224',
#   'B0B6BQGRC2',
#   'B09H293ZVB',
#   'B0B983P8Z1',
#   'B08KVQ4PN1',
#   'B0B6G6QH5M',
#   'B0B58RBKNJ',
#   'B0B59187JG',
#   'B0B9G95LX9',
#   'B099DP3617',
#   'B0B3JQY9XD',
#   'B0B9XNMJ7R',
#   'B0B7GFKL88',
#   'B0B4WJ4LZZ',
#   'B094N4WJ8Q',
#   'B09YRKHRK4',
#   'B0B19F989G',
#   'B0B8NG1T3P',
#   'B07WG38X9Y',
#   'B0BCVH19XT',
#   'B09V54D5GM',
#   'B09YRJBHRZ',
#   'B09V7PZ8PF',
#   'B0BFWH75NT',
#   'B00VX2OFLY',
#   'B09KKRQXGG',
#   'B09CT2SSLR',
#   'B0BDCSW57Z',
#   'B07H4579X5',
#   'B09K81DHDT',
#   'B0928TMP28',
#   'B0B8NGZ8Z5',
#   'B0B6ZTY7WY',
#   'B0040A5218',
#   'B0B1YMFHYK',
#   'B08JTGQV8F',
#   'B08H1CC8RB',
#   'B099QC6L4L',
#   'B099N5CWRF'],
#  'B0B18CK9DV': ['B0B18DBBFB',
#   'B0B18CZLZB',
#   'B01KNWYGMW',
#   'B09K81DHDT',
#   'B07XNH4DV8',
#   'B0B18CK9DV',
#   'B0B9XNMJ7R',
#   'B09FF3R7KH',
#   'B0B9XN7BMS',
#   'B0BB28SJQQ',
#   'B09CM1NNBP',
#   'B0BKGK9CX1',
#   'B0B4N6FCYF',
#   'B07YS6Q4RC',
#   'B08JTGQV8F',
#   'B083F3P2PM',
#   'B0B586GT88',
#   'B0BJK79785',
#   'B09C3DJ25B',
#   'B09Z8FPLKP',
#   'B0B2LLHB16',
#   'B09C3D7SDB',
#   'B0BFB9YT37',
#   'B09FD6THRV',
#   'B0BHP35CGJ',
#   'B0B1YNXWMH',
#   'B0BJ7K4NYX',
#   'B0B1YMFHYK',
#   'B07B5VPNZQ',
#   'B0BBVWLRGC',
#   'B0B49VWV6K',
#   'B09V54ZDZH',
#   'B09K81LB29',
#   'B09C3DCKZD',
#   'B08CVP3JYV',
#   'B09Z8CCZG9',
#   'B09TCXMPKK',
#   'B09TR18D6K',
#   'B0B6VJYZXY',
#   'B0B9XM87JL',
#   'B0BBLBKHC4',
#   'B0B6VLZJ5N',
#   'B0B9B8VBC9',
#   'B09TQZNKBB',
#   'B0B8NGZ8Z5',
#   'B07VNMGPGL',
#   'B09FDVTMYV',
#   'B09B3837VT',
#   'B08CVQG6YY',
#   'B0BHS4L4MV',
#   'B08DJ4NSRX',
#   'B0B72RRS7B',
#   'B099N5CWRF',
#   'B0BKQJ3MYZ',
#   'B09MCYQQX6',
#   'B08H1CC8RB',
#   'B00NNWXU68',
#   'B0BJ7MY9RH',
#   'B09CSSCTL2',
#   'B0B8NG1T3P',
#   'B0BBV8Z76K',
#   'B07G3WRXMV',
#   'B0B49DR3ZJ',
#   'B09835PG2K',
#   'B0B4VD6HF7',
#   'B08FTFRXJT',
#   'B08FJ6PQCX',
#   'B0BBMDT9WN',
#   'B0BBYSNT26',
#   'B0BC1J2512',
#   'B00BUPN6UA',
#   'B072HYJBHX',
#   'B07SX13TY1',
#   'B010BSNOGC',
#   'B0B7GGB9RW',
#   'B09V7PZ8PF',
#   'B07V7D3YPF',
#   'B09XXRQS4L',
#   'B0B9XM9WRX',
#   'B08NTS1HXV',
#   'B09922X26C',
#   'B08JB5S33F',
#   'B07R7PYYMC',
#   'B08KPTHRY6',
#   'B09MHFLKXB',
#   'B099F8TXVX',
#   'B0B1YQV2TH',
#   'B07ZG1JM47',
#   'B07H9D3KHD',
#   'B0B28FH1QF',
#   'B08FMKCDWX',
#   'B0B5KYGKK9',
#   'B07D7697X8',
#   'B07QPMS3CX',
#   'B07W1B94HT',
#   'B07XD9DH43',
#   'B0888RFFP2',
#   'B09K7Z9RQ5',
#   'B0B1YMYGZ3',
#   'B07BQQDW8H'],
#  'B083F3P2PM': ['B083F4DKL2',
#   'B01KNWYGMW',
#   'B083F3P2PM',
#   'B0B18DBBFB',
#   'B07XNH4DV8',
#   'B0B5WBDHGR',
#   'B07XKBLL8F',
#   'B08LSL593L',
#   'B0BJ7K4NYX',
#   'B09K81DHDT',
#   'B0B18CK9DV',
#   'B09FF3R7KH',
#   'B0B6VJYZXY',
#   'B0B9FQCWV4',
#   'B07VPGT224',
#   'B0BGLKXFVJ',
#   'B0BFB9YT37',
#   'B09J16ZJ5S',
#   'B089YQ8GR1',
#   'B0B1VPMDZW',
#   'B08C9WM4ZH',
#   'B0BH9D1S5V',
#   'B0B5STNFNK',
#   'B08D7WGLWN',
#   'B0B68Y73SX',
#   'B0B5GVW9TJ',
#   'B092323P8M',
#   'B07VKS8M3X',
#   'B09835PG2K',
#   'B08G8CCPQV',
#   'B0B9XQ166F',
#   'B08C9M2KXQ',
#   'B0B7NKC5Y1',
#   'B07VRZK1GS',
#   'B08ZMQT158',
#   'B0B378B2MC',
#   'B08M3MHZGN',
#   'B09TSTPGD4',
#   'B0B3XG26YN',
#   'B0B4RMB67X',
#   'B0BDWT9VFN',
#   'B08CVP3JYV',
#   'B09V7PZ8PF',
#   'B0BB28SJQQ',
#   'B0B5W7G5CH',
#   'B0B4V4C4K7',
#   'B0B4N6FCYF',
#   'B0B2W8FN6N',
#   'B09V54ZDZH',
#   'B08DFFCMKQ',
#   'B08C9P9XZM',
#   'B00FC67RMQ',
#   'B07VRW4YZQ',
#   'B09KKRQXGG',
#   'B09CGVZ51D',
#   'B0B5GW397N',
#   'B0BBVRDFKC',
#   'B0B241J9QR',
#   'B01HMNUE5I',
#   'B098723MM4',
#   'B0BHP35CGJ',
#   'B0B983P8Z1',
#   'B07FYQ7F6P',
#   'B09B3837VT',
#   'B09C3DJ25B',
#   'B0B45GHLKT',
#   'B0B765JJKS',
#   'B07ZFZT1DH',
#   'B06XCJ4FR8',
#   'B0BHLK35W8',
#   'B0BFB9TXPS',
#   'B09VBV5JTN',
#   'B0BFF6XM5Y',
#   'B0B6BQGRC2',
#   'B0B72Q5Z1W',
#   'B09872HC81',
#   'B08KQHDCGL',
#   'B08JTGQV8F'],
#  'B074SZT52L': ['B09W9R88ZK',
#   'B085SVQXWG',
#   'B07L8X2ZPV',
#   'B0849PDYSR',
#   'B074SZT52L',
#   'B0182KUYA0',
#   'B076HMNGVF',
#   'B004FPQREO',
#   'B01N0IO1IT',
#   'B088RK12NB',
#   'B075D8GD46',
#   'B07JLD4VMG',
#   'B082VP752X',
#   'B084ZR8KNW',
#   'B07M6PGQ95',
#   'B07R2BGVDM',
#   'B00GYDH84I',
#   'B08QC8NZ29',
#   'B07WRB98R5',
#   'B09JSK4JSR',
#   'B005KQTT4W',
#   'B08P74PBX1',
#   'B078SBVMMX',
#   'B07R2C4RCB',
#   'B0888VC7DS',
#   'B0B49K8HNJ',
#   'B07WRB53BG',
#   'B07CNJT1NB',
#   'B000Q87YLE',
#   'B09Z6P7WMV',
#   'B076HTSV8W',
#   'B001GHL884',
#   'B09TNQ4FVQ',
#   'B07B49KDRS',
#   'B07R1774S1',
#   'B0953F6LCK',
#   'B003IB4BBC',
#   'B09NQN8TVQ',
#   'B0BF14M88M'],
#  'B075D8GD46': ['B098MJ1RG5', 'B0B3RXGT7V', 'B09125PPHC', 'B08LZWBF6X'],
#  'B098MJ1RG5': ['B075FQ8ZMP',
#   'B075DCSF2D',
#   'B086P7QCWM',
#   'B0B4B19TR1',
#   'B075D9LS5F',
#   'B000WI8ZY8',
#   'B09M7J3CQW',
#   'B075DF8FY7',
#   'B001GHL884',
#   'B00915S6W4',
#   'B06XYVV6XX'],
#  'B075FQ8ZMP': ['B075D9LS5F',
#   'B08CXQW989',
#   'B08RMTQSVK',
#   'B0B4B1YQ9W',
#   'B09Y5YYW86',
#   'B07D21FZ1F',
#   'B005KQTT4W',
#   'B08VRRL37Z',
#   'B08ZL72Y7W',
#   'B075FQ8ZMP',
#   'B08QC8NZ29'],
#  'B08RMTQSVK': ['B08RNCNYTP',
#   'B08NW5XN3B',
#   'B013ICNQLQ',
#   'B07TNTJXVK',
#   'B0B312QZZR',
#   'B09M6RBM9Z',
#   'B07ZRVCRMZ',
#   'B091KJCJ31',
#   'B083Q283J8'],
#  'B08RNCNYTP': ['B08RMTQSVK',
#   'B08RN6K9XB',
#   'B096RHM71Z',
#   'B08RN4HZH9',
#   'B0876SHMD3',
#   'B0BK88FG8R'],
#  'B08FYFHN6R': ['B08FYFVQ2G',
#   'B08FYDX8JT',
#   'B08FYFHN6R',
#   'B09VL1FWLN',
#   'B089SK323R',
#   'B0B3XBD4KX',
#   'B0B9QSRPP6',
#   'B09NNGCTT5',
#   'B07RWSRJ3X',
#   'B0B8MP432V',
#   'B08F5C3YTJ',
#   'B07TT668D1',
#   'B099ZCJT6D',
#   'B08F59PDVM',
#   'B0B5XG7SWR',
#   'B089SJZF6V',
#   'B0B51QNVLV',
#   'B09XQVGBSH',
#   'B07Z3T763B',
#   'B0B74BB9LK',
#   'B0B5ML2M9M',
#   'B0738QSV24',
#   'B09C1MCTLH',
#   'B00PC8PD7K',
#   'B09PH32KPX',
#   'B0B9HBRC65',
#   'B08VWK7PBV',
#   'B08S7K59Y2',
#   'B0BB6YTN54'],
#  'B0B8MP432V': ['B0B8M47DGH', 'B0BB6ZMJDN', 'B089CSWM1C'],
#  'B0B8M47DGH': ['B0B8MP432V', 'B07HGTXF95', 'B0B1PLJ3QR', 'B09XQVGBSH'],
#  'B07HGTXF95': ['B07J2R8LNL',
#   'B07HJS5QXM',
#   'B07J2R8LNK',
#   'B07HGTXF95',
#   'B00I3LUYNG',
#   'B08VD6SRBZ',
#   'B00NBR70DO',
#   'B072J49RNL',
#   'B08VDJYLS5',
#   'B08NXRX27D',
#   'B08VDP4Y3S',
#   'B07HGJJ7GB',
#   'B07WD58H6R',
#   'B09MKH7HDX',
#   'B06X92G8HG',
#   'B08PFQ2895',
#   'B01M6WNWR6',
#   'B087JVV8FK',
#   'B00NBR6RDS',
#   'B083J88QRS',
#   'B00W5C0BRS',
#   'B09WV6NV31',
#   'B07HGG1XTS',
#   'B01MG62Z5M',
#   'B07PGR1KF8',
#   'B000I2J4S4',
#   'B086LLYK4S',
#   'B01N6NQ73J',
#   'B0B9N2DS3R',
#   'B079JWJR7S',
#   'B0788T6G4R',
#   'B09HSMT362',
#   'B08H99878P',
#   'B00006L4ST',
#   'B0853P2RM1',
#   'B01LSAMXCS',
#   'B09C92Q9V1',
#   'B08QTYYNDN',
#   'B09QGM78S7',
#   'B08HMWZBXC',
#   'B0BFP9LWQV',
#   'B091363MMN',
#   'B00X3L05VM',
#   'B00MZQU4KI',
#   'B08FB3VLQK',
#   'B08KTG9MN6',
#   'B07N22BN3K',
#   'B09PBNQ865',
#   'B00I3LV336',
#   'B085Z9B989',
#   'B07PHVRRJQ',
#   'B07K46MDW5',
#   'B0BJHXTDZX',
#   'B09TTFPYGQ',
#   'B09JPNNYFD',
#   'B0BDKL7R4W',
#   'B07HGHDPV4',
#   'B087JW59FX',
#   'B07XRX18ZZ',
#   'B085NVNN4S',
#   'B09B2L5VX3',
#   'B08FB35XNP',
#   'B0725P9D3Q',
#   'B08VDRZ8Z7',
#   'B09Y94ML6H',
#   'B06XZZVMCY',
#   'B00A2O7FC0',
#   'B09LLMMH4G',
#   'B086G9M5RF',
#   'B07JK5LNQB',
#   'B0828DR2GW',
#   'B00CBU0IV8',
#   'B08WM3LMJF',
#   'B00PEUX30U',
#   'B088YRN9XF',
#   'B096FYQSCK',
#   'B08FB37439',
#   'B07WD5978Q',
#   'B00NBR7962',
#   'B08ND51MX8',
#   'B07PFXNBXH',
#   'B089WDRN7N',
#   'B01M7Q670L',
#   'B08HDBZNZ9',
#   'B09MZQMYR1',
#   'B08CXMW737',
#   'B099DP3617',
#   'B07VRC551F',
#   'B0725W4HF5',
#   'B08NCCW2MY',
#   'B07PK11GBX',
#   'B095QN9WHH',
#   'B083MNJ2VX',
#   '1542025605',
#   'B09NNJJ4Q3',
#   'B08QTP13DW',
#   'B0B277XVQ6',
#   'B0B4B7J85Y',
#   'B07N2261R6',
#   'B09PFYS1ZZ'],
#  'B08D92GVKN': ['B08D92VK1V',
#   'B08D8MV22Y',
#   'B0746MRZ7K',
#   'B08D9473HS',
#   'B09DDZ9FRB',
#   'B08D92JS3V',
#   'B07VXKP4SH',
#   'B08D92TZM1',
#   'B06VY86NFX',
#   'B08D92GY5H',
#   'B08D94F42S',
#   'B08D92GVKN',
#   'B09BVBYP45',
#   'B08D926NNH'],
#  'B09DDZ9FRB': ['B09DFHC784', 'B09DDZ9FRB', 'B09DFP8H7Q'],
#  'B073XDPN85': ['B077GPKRHB',
#   'B089VQCXJL',
#   'B07BTWC45M',
#   'B07BB7RCFS',
#   'B0B9L2HLWG',
#   'B07BV4FTQ2',
#   'B096ZDDXDC',
#   'B0B7B53QBN',
#   'B08HHYPJ87',
#   'B07D5RMR9H',
#   'B01E6ZFV3U',
#   'B07SNS7BHD',
#   'B073XDPN85',
#   'B0B85SQDWZ',
#   'B097QZL949',
#   'B09QPPGYJQ',
#   'B07PZ2FKB5',
#   'B07BK5NB6H',
#   'B08MW7WNJ4',
#   'B00QI0IDWS',
#   'B07BB84DMM',
#   'B089VZ8KG7',
#   'B08MJ33FL2',
#   'B089W35VTV',
#   'B07GDPHLF7',
#   'B08GZX5RVJ',
#   'B00AYULYLK',
#   'B06ZZFM477',
#   'B07DNMYRGY',
#   'B07BTXKX67',
#   'B0749G2KMD'],
#  'B0B9L2HLWG': ['B00VWJC24U', 'B0B9L3R5RJ', 'B01E6ZFDVA'],
#  'B00VWJC24U': ['B07SJJW9D2',
#   'B07P6313NS',
#   'B00VWM5H0S',
#   'B01AT1YMGM',
#   'B07Y1XFBLK',
#   'B07Y1XSVMM',
#   'B01AT1YNGG',
#   'B00VWLI1JS',
#   'B07P634N49',
#   'B077P4CHY4',
#   'B00VWMHFZ8',
#   'B00VWMHKD0',
#   'B0B9L24R9Z',
#   'B08TGWGYTN',
#   'B07SJJWQ6L',
#   'B07F38W8DK',
#   'B08M96LY9W',
#   'B00VWJC00G',
#   'B00GUDVUXW',
#   'B07L3GHHSZ',
#   'B07D4DFBX8',
#   'B08DQVPMTD',
#   'B00VWM4UD8',
#   'B08RDCWSNP',
#   'B01DBBFOI2',
#   'B01LXTWO9L',
#   'B08RDC6FWG',
#   'B00VWJC24U',
#   'B0152G9CJ6',
#   'B00WZRY1M4',
#   'B01FNL0SHK',
#   'B07S48MND2',
#   'B082YRL82R',
#   'B07VCWCTKB',
#   'B07QQNZBYR',
#   'B07XC5B6LP',
#   'B08RDCBXLG',
#   'B003THETBC',
#   'B07SLNZSJY',
#   'B07C4Z25LF'],
#  'B0B9L24R9Z': ['B0B9L3357M',
#   'B0B9L45BVV',
#   'B082WB4V1T',
#   'B0B9L3R5RJ',
#   'B00AYULYNS',
#   'B0B9L48D3W',
#   'B0B9L2HLWG',
#   'B07C9VPKDM',
#   'B0BJQCMTYV'],
#  'B082WB4V1T': ['B089KDVMWB',
#   'B08ZHY1WB5',
#   'B089KBGXMV',
#   'B08ZHSYWXC',
#   'B082W9RZNL'],
#  '4910526250': ['B0BGSSLP9W',
#   'B0B55TRHFP',
#   '4910526250',
#   'B0BBFGG2BP',
#   'B0B76R2PS1'],
#  'B0B55TRHFP': ['B0BGSQRXFJ', '4480684387', '4832274112'],
#  'B07JM6KB5J': ['B07JM6KB5J',
#   'B071FJ6FBW',
#   'B072FQV72L',
#   'B01NCEC2NT',
#   'B07FLYLSW9',
#   'B07B52KDFZ',
#   'B08M5JWS1W',
#   'B018Y20O8I',
#   'B01N6B2L56',
#   'B01GFJWHZ0',
#   'B01ETJD79S',
#   'B08LQV9R98',
#   'B06XCR71HN',
#   'B01MTUUC5A',
#   'B0BH3WGDCM',
#   'B072R6CLRC',
#   'B0B85399GV',
#   'B07PGPJMXN',
#   'B06XYG1P2G',
#   'B00NLCC3N6',
#   'B07KYZ6X33',
#   'B06Y2DCPMS',
#   'B01N6B2LP1',
#   'B07Q1X5TG1',
#   'B0784CPBFR',
#   'B01MQQAFZB',
#   'B01NCEIPNM',
#   'B09V79NWTC',
#   'B07CLMXDJJ',
#   'B01MYTXYW7',
#   'B01JOXVY58',
#   'B07KJCCLSV',
#   'B06XBZTYHZ',
#   'B07H5MLJL2',
#   'B00JFWHJRQ',
#   'B01GFJWG88',
#   'B09QT6L741',
#   'B09JPMTRRJ',
#   'B08RHSHJ8Y',
#   'B07318ZZLL',
#   'B092MJ3N3L',
#   'B09MRX1Q2N',
#   'B01GFJWJG2',
#   'B07KYY4GSX',
#   'B01M1A2498',
#   'B07Z5GBMF3',
#   'B01MZZI7OI',
#   'B00K77U60U'],
#  'B072FQV72L': ['B071FJ6FBW',
#   'B08LQV9R98',
#   'B07DK93NGP',
#   'B0725YHBDD',
#   'B072FQV72L',
#   'B01MTUUCF5',
#   'B06XYG1P2G',
#   'B06XYPWDWS',
#   'B01MZZI7OI',
#   'B084H8X4SW',
#   'B01GFJWG88',
#   'B01MQQAFZB',
#   'B0BG61MT38',
#   'B01GFPWHZ4',
#   'B06XCR71HN',
#   'B07GJVWHD4',
#   'B0B5P47RS8',
#   'B01N2O4KQC',
#   'B09HR8FZH1',
#   'B0B21DW5DL',
#   'B00BS5SY2C',
#   'B09QMDZHY3',
#   'B06Y2DCPMS',
#   'B0B5P3ZGDW',
#   'B07DWV14T8',
#   'B08Q7ZJDCS',
#   'B00280MUJY',
#   'B07KYZ6X33',
#   'B09JPMTRRJ',
#   'B003X26VS2',
#   'B099WVFPRX',
#   'B000J6DANO',
#   'B01MTUUC5A',
#   'B08FDXPJ3B',
#   'B07F6XB9QQ',
#   'B07JM6KB5J',
#   'B07KYY4GSX',
#   'B01ETJD79S',
#   'B07T8BVYGS'],
#  'B01MQQAFZB': ['B01MYTXYW7',
#   'B01N6B2L56',
#   'B06XBZTYHZ',
#   'B01MQQAFZB',
#   'B01NCEC2NT',
#   'B00U5Q757K',
#   'B01N17TJH0',
#   'B0B76QH3YL',
#   'B07CVDY829',
#   'B074M9DZ4N',
#   'B01GFJWHZ0',
#   'B09G1HKFJT',
#   'B06ZZKQK1M',
#   'B079TXYZLM',
#   'B096463477',
#   'B01N9BU4Y7',
#   'B07KYZ6X33',
#   'B01HBK8VCA',
#   'B0BG81RTL3',
#   'B076CRNNWM',
#   'B079GY9CZK',
#   'B07TV364MZ',
#   'B06XYG1P2G',
#   'B084DPKKDZ',
#   'B01N1UX8RW',
#   'B0B519P2MQ',
#   'B01MTUUG2F',
#   'B07WKN8NQQ',
#   'B01MRROWEQ',
#   'B0932Z1YYX',
#   'B00AYFLHC6',
#   'B09NQG2P4V',
#   'B08HDL6CNQ',
#   'B09JFZDBLM',
#   'B088Z1P45L'],
#  'B0825D6LLT': ['B0978ZRLTL',
#   'B07GMV3FSF',
#   'B07GN1Y9FX',
#   'B0979286H9',
#   'B00DQG9OZ2',
#   'B08TVKNXWH',
#   'B0825D9J4X',
#   'B006FGXQEA'],
#  'B0978ZRLTL': ['B07GMV3FSF',
#   'B0825D6LLT',
#   'B0979286H9',
#   'B0825D9J4X',
#   'B07GN1Y9FX',
#   'B00DQG9OZ2',
#   'B0978ZRLTL',
#   'B00DQGBYDC',
#   'B08JD36C6H',
#   'B007V3YGN6',
#   'B015CH1PJU',
#   'B09NS737DT',
#   'B07VSYZCY5',
#   'B08CMZKB82',
#   'B088HT3HR4',
#   'B0B3MSK746',
#   'B07855LJ99',
#   'B09TW4NNT8',
#   'B00FJRS73G',
#   'B07QBNYJ6X',
#   'B005FYNT3G',
#   'B08KHTRF61',
#   'B0006PKZ22',
#   'B00BHUN798',
#   'B00IHXQ3L2',
#   'B004C0T1GI',
#   'B07SX9BW6T',
#   'B01LXHKR4T',
#   'B009TGPCEU',
#   'B01GISXVQC',
#   'B015CH1NAQ',
#   'B08XC26TK6'],
#  'B01MZB2K7A': ['B01N127VUD',
#   'B01MZB2LBI',
#   'B01N23OCM7',
#   'B0BBWJYH9S',
#   'B01MS8PL71'],
#  'B01N127VUD': ['B01MZB2LBI',
#   'B01MZB2K7A',
#   'B01N23OCM7',
#   'B01MS8PL71',
#   'B01MS8POEI',
#   'B000N6ON72'],
#  'B01MZB2LBI': ['B01MZB2K7A',
#   'B01N23OCM7',
#   'B01N127VUD',
#   'B01MS8POEI',
#   'B000N6ON72',
#   'B01MS8PL71',
#   'B07NMJBHDM',
#   'B07215G36Y'],
#  'B002WHA3GA': ['B08SQM4GK6',
#   'B002WHA3GA',
#   'B091Z5988J',
#   'B004ULKX84',
#   'B07MV7TPTB',
#   'B004ULPCUI',
#   'B09J5FC2ZH',
#   'B004V3HQZ4',
#   'B088RF6GC7',
#   'B07DP4T696',
#   'B007BGZTFM',
#   'B0B4P58VQ6',
#   'B07WNCZQNS',
#   'B07C9CXNBF'],
#  'B07MV7TPTB': ['B010USHUMM',
#   'B0B9X61BCG',
#   'B07B4KDKQD',
#   'B07MV7TPTB',
#   'B088RF6GC7',
#   'B01CSCVGI2'],
#  'B010USHUMM': ['B07QSQN9Z3',
#   'B00UFCL7PU',
#   'B082KKJNXN',
#   'B09TND45N3',
#   'B01N4OR09O',
#   'B00PYEC9RE',
#   'B081DTVW51',
#   'B00FZLZM7K',
#   'B07KNZYLP9',
#   'B06XV95SW1',
#   'B085NLYTB3',
#   'B0B5913NPK',
#   'B07CP32RLN',
#   'B01LEN6HTY',
#   'B09MN9LCQ7',
#   'B0865Z48W9'],
#  'B09WDKLMV6': ['B09WDMC61Y',
#   'B07QLR94S1',
#   'B09KNCS5QD',
#   'B07XR2NWZC',
#   'B08K3LTVPD',
#   'B09QQ8QCT5'],
#  'B09KNCS5QD': ['B08S7JK97N'],
#  'B08S7JK97N': ['B08GQ3M4DD',
#   'B09N6P323M',
#   'B08GYKNCCP',
#   'B07X7CQBJP',
#   'B08K3M6N7C',
#   'B0953798KS',
#   'B09CL4JQDM'],
#  'B09N6P323M': ['B07X37DT9M',
#   'B09N6MVNC7',
#   'B09N6P323M',
#   'B08R8BGDM5',
#   'B09WDKLMV6',
#   'B08K3M6N7C',
#   'B0B4G2H4WC',
#   'B09N6RD4ZS',
#   'B07XR2NWZC',
#   'B0B2CPJFBW',
#   'B08GWYSNTJ',
#   'B08HJWFHC9',
#   'B097RLW67B',
#   'B0B5HKDKMP',
#   'B07K6LL84C',
#   'B0BC1WSLNB',
#   'B08GQ3M4DD',
#   'B07Q769MFM',
#   'B07SHBW7HG',
#   'B0BC23ZNBH',
#   'B07RRHHN23',
#   'B0B8JQZCDR',
#   'B088CX996D',
#   'B09FDJG68V',
#   'B07NCQHS1T',
#   'B09HJYRFYD',
#   'B082WS68D7',
#   'B08L4NQYHV',
#   'B003DOG81U',
#   'B00NABTC8M',
#   'B084DY2CV7',
#   'B09N6KDX5K',
#   'B09FFBN6W7',
#   'B07YXX5584',
#   'B08K3LTVPD',
#   'B07QLRFG8T',
#   'B09PVQ7FRX',
#   'B07X7CQBJP',
#   'B08KGTW3CV',
#   'B09X9LT1BF',
#   'B099M24J56',
#   'B08T5P575X'],
#  'B07XR2NWZC': ['B083GGLKSJ',
#   'B08K3M6N7C',
#   'B07XR2NWZC',
#   'B08ZNTM1X1',
#   'B07X37DT9M',
#   'B07FCCTX45',
#   'B09YHGXY7H',
#   'B09FFF18BQ',
#   'B08X6FV8SV',
#   'B08BW6YQ67',
#   'B07GTWD7Z7',
#   'B099M24J56',
#   'B08K3KKNBY',
#   'B08HHVRM32',
#   'B08JLR2751',
#   'B09YYDFWPM',
#   'B08H5NPHLT',
#   'B005A3FEGW',
#   'B08CNLVYZH',
#   'B01DCEUEFQ',
#   'B09K7HRYVN',
#   'B0BHYHQKNJ',
#   'B087R77BW4',
#   'B08GYKNCCP',
#   'B07NY23WBG',
#   'B0796NQPK4',
#   'B07SV5NQNB',
#   'B08MW5BSBJ',
#   'B07FDHBWT9',
#   'B001DXNRDK',
#   'B091G31KSJ',
#   'B098PHLZ3N',
#   'B09TWP3WQ3',
#   'B07Q769MFM'],
#  'B081W6LM1G': ['B081W6LM1G',
#   'B0B2Q2VVGP',
#   'B07FGSJ5TP',
#   'B07R4PN3MV',
#   'B07R5PXT2L',
#   'B076BVHCWM',
#   'B0B2Q4ZRDW',
#   'B07C23PPC8',
#   'B07DY1BHC3',
#   'B0837FBSJ2',
#   'B0837FX64Z',
#   'B07R5PY4FW',
#   'B00X67CIC2',
#   'B07CBYGV77',
#   'B07FB7SQ1C',
#   'B0837F57BS',
#   'B07R4PN4X6',
#   'B07R8WCWDX',
#   'B07DY1JJVC',
#   'B00OLY38DM',
#   'B086X3H5T1',
#   'B07FB7SQ12',
#   'B07R7RHYZ7',
#   'B07XHY38PS',
#   'B07JQ9R7VR',
#   'B07FB81X4V',
#   'B00JFXMNLW',
#   'B07G5ZXCV2',
#   'B07FJPCLML',
#   'B09MZV99S9',
#   'B076B7479W',
#   'B07ZFZ4BVR',
#   'B07R7RHYYW',
#   'B078NCW7HK',
#   'B08XMCTQ9D',
#   'B07R6NSYR4',
#   'B09JB1V3ZB',
#   'B08DYJX4LJ',
#   'B07DY17V64',
#   'B08P5PPPDV',
#   'B07TWXNDJG',
#   'B083L525NK',
#   'B086X39YHB',
#   'B00X67BISW',
#   'B098BYN3X3',
#   'B07RB279H9',
#   'B00X67IGFA',
#   'B0B38VLXMP',
#   'B09Q3N7W8R',
#   'B07R7RJLBM',
#   'B00X67J4TC',
#   'B0837FC2TV',
#   'B07D8GJY6J',
#   'B096G4T5KQ'],
#  'B07FB81X4V': ['B07R4PN3MV', 'B081W6PG3W'],
#  'B07R4PN3MV': ['B0B2Q2VVGP',
#   'B07R4PN3MV',
#   'B0B2Q4ZRDW',
#   'B07R5PY4FW',
#   'B09MZV99S9',
#   'B07FB7SQ12',
#   'B07RB279GT',
#   'B07R6NS76K',
#   'B07R4PN4X6',
#   'B07R8WCWDX',
#   'B00OLY38DM',
#   'B07FJPCLML',
#   'B07R8WFTRY',
#   'B00X67BISW',
#   'B07XHY38PS',
#   'B07FB8S641',
#   'B076BVHCWM',
#   'B07RB2HS5W',
#   'B07R5PXCYV',
#   'B081W6LM1G',
#   'B07CFHL2FV',
#   'B07R7RHYZ7',
#   'B09JL239W3',
#   'B07FBHYFDT',
#   'B07R7RHYYW',
#   'B07G5ZXCV2',
#   'B07FGSJ5TP',
#   'B0837F8MMG',
#   'B07FB7SQ1C',
#   'B086X3H5T1',
#   'B07FBHJ9BK',
#   'B07RC1S3ZT',
#   'B07R6NSYRJ',
#   'B00X67IGFA',
#   'B07Q1JNC7R',
#   'B07TWXNDJG',
#   'B07DY1BHC3',
#   'B07DY1JJVC',
#   'B09HSLXFWC',
#   'B08F38LY8P',
#   'B07R7RJLC4',
#   'B09MZVL9SB',
#   'B07R5PXT2L',
#   'B07RB279H9',
#   'B07R4PM5K6',
#   'B0837F57BS',
#   'B09P271DCL',
#   'B07FB8S5ZV',
#   'B076B7479W',
#   'B00GXDTO50',
#   'B07CBYGV77',
#   'B07RMHDC1K',
#   'B09FFR4Y4T',
#   'B08F37WNRH',
#   'B0968NQ4FK',
#   'B07G5KHMYK',
#   'B07XGCS878',
#   'B07DY16WP1',
#   'B071XJQDX7',
#   'B01DBY79V4',
#   'B08G99D7F1',
#   'B081W6PG3W',
#   'B0B73G9WMW',
#   'B00A3TCD1M',
#   'B0BBR6FY63',
#   'B07JQ9R7VR',
#   'B077XL5D3M',
#   'B07VGMCT1J',
#   'B08PP2K79Q',
#   'B09JFZRYSF',
#   'B07G5VWF6V',
#   'B09N95QB3F',
#   'B0922K1WRQ',
#   'B0999HKLPS',
#   'B00FS3YB1I',
#   'B07QK34ZR7',
#   'B07G5WLHWY',
#   'B000G04LWM',
#   'B084RKRZ8Y',
#   'B09DL6NC4V',
#   'B08P3GY6GY',
#   'B083L525NK',
#   'B076C2J7KK',
#   'B078NFM152',
#   'B098XTP9F6',
#   'B07JD327P3',
#   'B082X8GG1D',
#   'B07DY17V64',
#   'B0837F11XQ',
#   'B07KC1DYC7',
#   'B00X5N322M',
#   'B07NSPN7BK',
#   'B08FJCJG28',
#   '3849914704',
#   'B07R4PN4QP',
#   'B09PLK51FV',
#   'B08W65132F',
#   'B08DYGRVGQ',
#   'B087QFW458',
#   'B0711HGJG1'],
# ...
#   'B07D4DPD4S',
#   'B07D4F1F3F',
#   'B01N9JG9CM',
#   'B0B6CR9GQ6',
#   'B0B9RBNJ55',
#   'B08128DCNB',
#   'B09D3TH5R5',
#   'B081TBTJRK',
#   'B09M2TQ5KT',
#   'B01K28121U',
#   'B09KHHF13C',
#   'B09K4M5K7P',
#   'B07WK4HR8J',
#   'B08TTYBD3K',
#   'B0847P5H98',
#   'B07HM86QKL',
#   'B07WCL4NQN',
#   'B075ZWHZ7X',
#   'B09KHG349Y',
#   'B092KRXG33',
#   'B0B61QS5GY',
#   'B09C8JV2X1',
#   'B07RBJRNVS',
#   'B017L643R6',
#   'B08PL2S2RP',
#   'B000FNFSPY',
#   'B093L51YK1',
#   'B0BFR95G2X',
#   'B074CL5W23',
#   'B0057DWL16',
#   'B074CK89VC',
#   'B079DTLVQT',
#   'B07VLHGBP1',
#   'B0982V6QVX',
#   'B09W9Z2G38',
#   'B00NAWE7Z4',
#   'B01MXLEVR7',
#   'B0B913DQYS',
#   'B07GWT7NFJ',
#   'B00RXOY6SS',
#   'B00DY4DLVY',
#   'B07K7P2CHQ',
#   'B08QSKZM7S',
#   'B073W4VRZ7',
#   'B084GYSCL9',
#   'B01M36DP4F',
#   'B08ZSDTC5R',
#   'B07BXDN3HH',
#   'B071J378NN',
#   'B07G446MMQ',
#   'B0786NM659',
#   'B0BGQG3FCD'],
#  'B06Y43CVCZ': ['B06Y43CVCZ',
#   'B01LT217MC',
#   'B018U1RYYA',
#   'B01KMZR94M',
#   'B0B15PPZPV',
#   'B084GWB8YC',
#   'B01MR1UIW7',
#   'B01I5DF1U2'],
#  'B07G34JZG2': ['B09N7F1W7Q',
#   'B019GNUT0C',
#   'B07G34JZG2',
#   'B0B7476VYY',
#   'B0859XFRZH',
#   'B07SCJ349Z',
#   'B08JTQ66K7',
#   'B081YPQPXH',
#   'B09165DRLN',
#   'B09QPGP6LR',
#   'B0B3XKYJ4D',
#   'B0B1PW59FS',
#   'B0BGBY7K4M',
#   'B0BGPVHXRW',
#   'B0B6V4672C',
#   'B0BD71WTNC',
#   'B08JTXGVZX',
#   'B07P98KCZJ',
#   'B09BB3MHJS',
#   'B0B8HH81XL',
#   'B0B966C5J3',
#   'B07VJYVNTL',
#   'B09G9Z65HK',
#   'B07T87NDZC',
#   'B09YPTNYCJ',
#   'B09H788RC6',
#   'B08D6N5NY2',
#   'B0BFB18WWY',
#   'B08335JKVV',
#   'B0BB7KXC7V',
#   'B0B96GWZBR',
#   'B0B5GQDGNW',
#   'B0B55QZT8Y',
#   'B09HZMBXQ1',
#   'B09N7CVB84',
#   'B0BC77C1FK',
#   'B07GNC75CG',
#   'B08R73LCQS',
#   'B0BCG9B5WV',
#   'B08QMF257X',
#   'B08ML96C2R',
#   'B07P845Z6W',
#   'B0B9XM5W27',
#   'B08KFWFN57',
#   'B09M87RDL7',
#   'B0B7JKXGN8',
#   'B08332CQH2',
#   'B09LCM415N',
#   'B0BHC79DP1',
#   'B07YYSHJ9J',
#   'B08CHLRYPC',
#   'B0B6VN2335',
#   'B09XWP9TGW',
#   'B07VWPW48C',
#   'B09PQNLBGG',
#   'B0B45SC86L',
#   'B08H2FVFX4',
#   'B09NY5P7LX',
#   'B091KNVCYJ',
#   'B07WDGKGQB',
#   'B08K2RCF8N',
#   'B09DNX9X6D',
#   'B08WS4L87W',
#   'B09X1F1S4W',
#   'B08CHM3R6B',
#   'B09BN7Z3BG',
#   'B09ZPGP17N',
#   'B09QQ7HHFN',
#   'B0BHWBZ4ZJ',
#   'B09FDFRMMV',
#   'B099NBK46G',
#   'B082SQX6TD',
#   'B08D6KVMFV',
#   'B08H2GS69V',
#   'B07YWGCSMN',
#   'B077WYDYYF',
#   'B099WK5Z46',
#   'B09LV82XJ3',
#   'B07YC81BSY',
#   'B0711PVX6Z',
#   'B08X4L1KLZ',
#   'B0BD5MFPMF',
#   'B0B95TGTBP',
#   'B09B6XL56D',
#   'B09ZV43QP9',
#   'B0BBF6DTQ8',
#   'B09M3NJ4LJ',
#   'B09CMLDGVV',
#   'B0BFCPHDRS',
#   'B07PP2RB25',
#   'B01DEURI48',
#   'B0774KK9VJ',
#   'B09SW75ZK9',
#   'B0BBGKZ79B',
#   'B000XJV45S',
#   'B08HHJZSYF',
#   'B07J2PL2JD',
#   'B09PDNDQGD',
#   'B086MJR2NG',
#   'B08F9HQ2B8'],
#  'B07GNC75CG': ['B08335JKVV',
#   'B07GWTFYLM',
#   'B08D6N5NY2',
#   'B09D93PZ3T',
#   'B09165DRLN',
#   'B09F66LFQF',
#   'B0B6TM8K9Q',
#   'B0BD71WTNC',
#   'B083NPZWXX',
#   'B07GNC75CG',
#   'B07G34JZG2',
#   'B019GNUT0C',
#   'B0BC77C1FK',
#   'B09T6QNG3C',
#   'B082SY1GBZ',
#   'B09GV65N9Q',
#   'B0B1PW59FS',
#   'B09C5TW24N',
#   'B087287W8S',
#   'B09BB3MHJS',
#   'B07VNRT1HC',
#   'B08FHMWPDV',
#   'B07P98KCZJ',
#   'B08332CQH2',
#   'B0B8ZGBHPS',
#   'B01AHO08NM',
#   'B07PFPR5H5',
#   'B07GWXLFDG',
#   'B09CMLDGVV',
#   'B085CBSMMF',
#   'B099ZXHQKF',
#   'B07VCRH7PL',
#   'B09ZYBDCB8',
#   'B09LXGD2R6',
#   'B07Y1Q1YDQ',
#   'B0B9XM5W27',
#   'B09KLJFVF5',
#   'B0B6VN2335',
#   'B09DK3TZ8Q',
#   'B09X1FDTD6',
#   'B07LBPT9CC',
#   'B07W8G7XPZ',
#   'B08D918RJQ',
#   'B09P8MLDZZ',
#   'B07GWMD4R9',
#   'B09JK94J61',
#   'B09G9HWLQJ',
#   'B082SY52FR',
#   'B0BHC79DP1',
#   'B08P6P2XHK',
#   'B08D6KVMFV',
#   'B086MJR2NG',
#   'B0B6TLCFYV',
#   'B09SP3R5RH',
#   'B08GFSMY99',
#   'B0B3XKYJ4D',
#   'B09D3J26XN',
#   'B0B8H9LTYR',
#   'B09Y5HYN7J',
#   'B07R217TC2',
#   'B0B4VYYPWD',
#   'B07SCJ349Z',
#   'B004V7DDXE',
#   'B0038IVD3Y',
#   'B07YBX2VP7',
#   'B07PK4C984',
#   'B0B55QZT8Y',
#   'B0B4DKWHLN',
#   'B09NMB5JWH',
#   'B08Q7GYWRB',
#   'B07YYSHJ9J',
#   'B09WK4XVB5',
#   'B081YPQPXH',
#   'B08FWKRRRW',
#   'B07BFBKPLK',
#   'B0BH2F2F7Y',
#   'B091KNVCYJ',
#   'B09MLWM96B',
#   'B09ZK1DMN9',
#   'B07SN12FBH',
#   'B003JOWSD6',
#   'B0BBMRTH12',
#   'B07S75PPZW',
#   'B0B4NQCJBD',
#   'B0B8C635FM',
#   'B09X1DRY2Y',
#   'B09XWP9TGW',
#   'B08JTQ66K7',
#   'B09BN4TCSQ',
#   'B09B52VVXN',
#   'B099K5YT5V',
#   'B085VHTVHY',
#   'B07P845Z6W',
#   'B0B1GZ5243'],
#  'B08332CQH2': ['B07G34JZG2',
#   'B08JTXGVZX',
#   'B0859XFRZH',
#   'B09M87RDL7',
#   'B0BD71WTNC',
#   'B0B3XKYJ4D',
#   'B08332CQH2',
#   'B07SCJ349Z',
#   'B0B7476VYY',
#   'B08QMMF1Q2',
#   'B019GNUT0C',
#   'B09XWP9TGW',
#   'B0B6VN2335',
#   'B09XZZKKSW',
#   'B0BCG9B5WV',
#   'B0BDB3263B',
#   'B09165DRLN',
#   'B09JDGYSQW',
#   'B09ZXN4MLG',
#   'B0B1PW59FS',
#   'B08WJLB99R',
#   'B0BC8Q4QQ5',
#   'B08XVP98NS',
#   'B09NKWCLCZ',
#   'B08ZK3PGH8',
#   'B07T87NDZC',
#   'B0B6V4672C',
#   'B09K64N1DX',
#   'B0B3QRN8CS',
#   'B09QPGP6LR',
#   'B09NY8GN76',
#   'B09LM6C67D',
#   'B01MCRC6H1',
#   'B09BTRLPC7',
#   'B002Y06N78',
#   'B09P7ZPHB6',
#   'B07P98KCZJ',
#   'B0B7JKXGN8',
#   'B09TMW1GVS'],
#  'B08QMMF1Q2': ['B08QMF257X',
#   'B0B4VYYPWD',
#   'B09NPLB294',
#   'B0B1PW59FS',
#   'B07G34JZG2',
#   'B0B1GZ5243',
#   'B07GNC75CG',
#   'B09C5TW24N',
#   'B07SCJ349Z',
#   'B09PY96ZGX',
#   'B07P845Z6W',
#   'B08V1FRJV1',
#   'B0859TVRMF',
#   'B09SYY1JB1',
#   'B08R8FGH5J',
#   'B092PXPHQF',
#   'B0B87DCFV4',
#   'B087JMJGQH',
#   'B097GGR779',
#   'B0BC77C1FK',
#   'B09364MS3M',
#   'B087287W8S',
#   'B07YC81BSY',
#   'B07LBPT9CC',
#   'B07GWXLFDG',
#   'B09NMB5JWH',
#   'B0B8ZGBHPS',
#   'B0B45SC86L',
#   'B07YC89B63',
#   'B07YYSHJ9J',
#   'B09SPF3X4P',
#   'B08X6LMZPG',
#   'B07VJYVNTL',
#   'B0B5DRJ2JY',
#   'B0BD71WTNC',
#   'B0B7JKXGN8',
#   'B09LCM415N',
#   'B09BF4WZCZ'],
#  'B019GNUT0C': ['B019GNUT0C',
#   'B081YPQPXH',
#   'B07SCJ349Z',
#   'B07H9V2CKZ',
#   'B07G34JZG2',
#   'B01B5XLM5W',
#   'B091KLF4B1',
#   'B0B7476VYY',
#   'B091KNVCYJ',
#   'B09QPGP6LR',
#   'B08FHMWPDV',
#   'B09NMB5JWH',
#   'B0BB7KXC7V',
#   'B09165DRLN',
#   'B0859XFRZH',
#   'B09TRCQQH1',
#   'B0BFB18WWY',
#   'B0BHWBZ4ZJ',
#   'B0B3XKYJ4D',
#   'B0BD71WTNC',
#   'B08CHLRYPC',
#   'B0B1PW59FS',
#   'B09PBPVVB6',
#   'B0B517MMXT',
#   'B0B7JKXGN8',
#   'B0BC77C1FK',
#   'B0B55QZT8Y',
#   'B08JTXGVZX',
#   'B09XWP9TGW',
#   'B0B6V4672C',
#   'B07VJYVNTL',
#   'B09H788RC6',
#   'B08R73LCQS',
#   'B09HZMBXQ1',
#   'B0B9XM5W27',
#   'B09VPHVT2Z',
#   'B07P98KCZJ',
#   'B09ZPGP17N',
#   'B07YYSHJ9J',
#   'B0B7J7S1R7',
#   'B08H2FVFX4',
#   'B09XM8W9Z5',
#   'B08CHM3R6B',
#   'B09VMYX2FC',
#   'B09PJD5492',
#   'B011TQQ9RG',
#   'B0B5GQDGNW',
#   'B0BGPVHXRW',
#   'B09CH44769',
#   'B0B8HH81XL',
#   'B09PTG981X',
#   'B08MCKGSSS',
#   'B0BGBY7K4M',
#   'B08Q7GYWRB',
#   'B09SW75ZK9',
#   'B0B9JHXQ4B',
#   'B0B6VN2335',
#   'B09PDNDQGD',
#   'B09M87RDL7',
#   'B08TZYQP9J',
#   'B096S2CTHS',
#   'B0B45SC86L',
#   'B07T87NDZC',
#   'B09PYB7K7W',
#   'B01N522SM2',
#   'B08JTQ66K7',
#   'B09XXRLMKB',
#   'B08335JKVV',
#   'B071D8THD2',
#   'B08GFLBXSZ',
#   'B0B95TGTBP',
#   'B0B66337DX',
#   'B07WSV83VC',
#   'B095W99H1C',
#   'B09Y1LVGYN',
#   'B09DK48BKQ',
#   'B08XMHR2C7',
#   'B09W9MS685',
#   'B09Q63QJLD',
#   'B09YQ4QHWH',
#   'B0711PVX6Z',
#   'B09PY96ZGX',
#   'B09BMR3Z6L',
#   'B07TFT59B2',
#   'B09FDFRMMV',
#   'B01DEURI48',
#   'B08V1FRJV1',
#   'B07WDGKGQB',
#   'B0B284QPJK',
#   'B07ST84PF5',
#   'B07215381G',
#   'B0928LVPNW',
#   'B09DK3TZ8Q',
#   'B099WK5Z46',
#   'B078NPDRHL',
#   'B08DTT5V3M',
#   'B09NY8GN76',
#   'B09364MS3M',
#   'B08K2RCF8N',
#   'B09HRCSRW8'],
#  'B09XWP9TGW': ['B09XWP9TGW',
#   'B09M87RDL7',
#   'B09Y1LVGYN',
#   'B09PQNLBGG',
#   'B09T2RNVK9',
#   'B0BBGKZ79B',
#   'B07SCJ349Z',
#   'B0BD71WTNC',
#   'B0BDVM4YL6',
#   'B0B3XKYJ4D',
#   'B0BB7KXC7V',
#   'B09K64N1DX',
#   'B09CTHF76Y',
#   'B0859XFRZH',
#   'B0BGBY7K4M',
#   'B08F25LGMZ',
#   'B082F9WQHH',
#   'B09KX4L8PV',
#   'B0BH2F2F7Y',
#   'B09Y81XDK7',
#   'B09498J5XC',
#   'B083QDTCCY',
#   'B07GNP5LDH',
#   'B0B8SFD1GZ',
#   'B09LQFNBCD',
#   'B0BJ27JP2H',
#   'B07VWPW48C',
#   'B0BDYFRH9Y',
#   'B086MJR2NG',
#   'B0BFB18WWY',
#   'B0012VQG9K',
#   'B06ZXXQGZ8',
#   'B0BCG9B5WV',
#   'B09NQWSF2C',
#   'B07YYSGKRV',
#   'B000FQORIA',
#   'B0B17S7J1F',
#   'B08KZW1DN5',
#   'B08332CQH2',
#   'B0BG5FKFF4',
#   'B09BN7Z3BG',
#   'B0B45SC86L',
#   'B096K2KXN6',
#   'B091FRPBL3',
#   'B09BB3MHJS',
#   'B0B7JKXGN8',
#   'B07LBPT9CC',
#   'B09W45DVRB',
#   'B08L4ZZBK5',
#   'B07G34JZG2',
#   'B07MDMXZKK',
#   'B08JTXGVZX',
#   'B09PY96ZGX',
#   'B0B6VN2335',
#   'B0B5GSTPQ7',
#   'B09C3HLCX3',
#   'B07X534DKT',
#   'B09TKRYSLH',
#   'B0967YFNYS',
#   'B09FF583CV'],
#  'B08MY2VQTD': ['B08MY1C7RK',
#   'B08MY34MG4',
#   'B084CZKNW8',
#   'B096493S5S',
#   'B08MXZH7FY',
#   'B07Y1GL1J4'],
#  'B08MY34MG4': ['B08MY2VQTD', 'B08MY1C7RK', 'B08MXZH7FY'],
#  'B08MY1C7RK': ['B08MY34MG4', 'B08MXZH7FY', 'B086BC8F21'],
#  'B08MXZH7FY': ['B08MY1C7RK',
#   'B08MY2VQTD',
#   'B08MY34MG4',
#   'B09MVW2CXY',
#   'B092W8QFPZ'],
#  'B09MVW2CXY': ['B09CSZ2NC7',
#   'B08MY2VQTD',
#   'B00Q8UC068',
#   'B09NDCB58Z',
#   'B09MVW2CXY',
#   'B08PFGN271',
#   'B011WPS48Q'],
#  'B09YY846HG': ['B07BF9XMHF'],
#  'B07BF9XMHF': ['B009AVW2MY', 'B08MGHRDF7'],
#  'B009AVW2MY': ['B08G4HPRCR', 'B000XJ7FW4'],
#  'B07PWD3DVX': ['B09PDMLCWP', 'B09BYZQY6S', 'B09D3FYFHZ', 'B08DJ58FF7'],
#  'B09PDMLCWP': ['B09PDMLCWP',
#   'B09DP2XV1V',
#   'B099ZFBQ9P',
#   'B08T9SPHH9',
#   'B099Z3F8KX',
#   'B08XTV2JMX',
#   'B015Y17S9U',
#   'B0B38W2HCT',
#   'B01NBR7K7H',
#   'B09F6CYWJ6',
#   'B0B2RPWBNR',
#   'B08PL143RF',
#   'B07G85KZ41',
#   'B07BFNF3Z2',
#   'B0914GC19R',
#   'B09NGNHGTH',
#   'B00J4EQVPG',
#   'B09D3FYFHZ',
#   'B08NB141J5',
#   'B08D66NC11',
#   'B08P5HDMDJ',
#   'B09LV34WDH',
#   'B099ZHYW9N',
#   'B085PTF63L',
#   'B0B8RNNBRQ',
#   'B007B9NV8Q',
#   'B0B2P64PMT',
#   'B0B5ZLMM5L',
#   'B09QKQK799',
#   'B0BFX33FPD',
#   'B09BCSK9NH',
#   'B08R3Z6G9K',
#   'B08JGPR7C9',
#   'B08LKRTRFW',
#   'B00HR1I90I',
#   'B09M3VZPRY',
#   'B07BJ297T8',
#   'B0756BNQWP',
#   'B09T3BLCBP',
#   'B08BZD8F83',
#   'B019DNTN98',
#   'B08BJTBVTZ',
#   'B0B7JB6QF3',
#   'B09V7RG9Q4',
#   'B09J8D3WZV',
#   'B00LN803LE',
#   'B079X9F3HP',
#   'B08ZL6QF8Q',
#   'B08PFFXK3H',
#   'B07L9TBX1M',
#   'B0B121C8JX',
#   'B0BD54SWDY',
#   'B07CMXW94H',
#   'B07YFB7CW2',
#   'B08YWKM4LY',
#   'B09GFPYRC6',
#   'B07PNBFQCN',
#   'B098JNC3HG',
#   'B06XQ39PMF',
#   'B0964Q5VNN',
#   'B08RRZ5LMW',
#   'B07NYYMTXR',
#   'B09QBYYM8F',
#   'B08JZ6YCLW',
#   'B08L97R52R',
#   'B07K7HPCVJ',
#   'B08T5NHYGD',
#   'B09JYYKNNV',
#   'B0B4MTJ6XN',
#   'B08PPBF9C6',
#   'B0B21W79YC',
#   'B07415HRW7',
#   'B07GB4NQ2F',
#   'B07T11MRR5',
#   'B09MQWW98T',
#   'B01N3ZGAP8',
#   'B07H7F4L87',
#   'B0B5K2MSZ6',
#   'B0834YLWDM',
#   'B008RWH7OU',
#   'B07CGHFCBN',
#   'B07TY8M3QK',
#   'B07PPDCPHN',
#   'B0BB9NYHHK',
#   'B07K78NX3B',
#   'B0972K4JMS',
#   'B07S1S79LF',
#   'B083S6SYTJ',
#   'B08NC86GQW',
#   'B07XFNPNC3',
#   'B09XQ1Q2PY',
#   'B08ZDDLJFB',
#   'B0919HLBF7',
#   'B07G7XZJ1R',
#   'B08V912QJM',
#   'B0986NRV4S',
#   'B09TGYXQVH'],
#  'B08PL143RF': ['B08PFFXK3H',
#   'B08RXMRSZ8',
#   'B08PL143RF',
#   'B09D7Z9KK1',
#   'B08YWKM4LY',
#   'B09D3FYFHZ',
#   'B08WRXRQ5M',
#   'B0B8ZDXTHF',
#   'B08RRZ5LMW',
#   'B0B8RNNBRQ',
#   'B09LV34WDH',
#   'B08RRX69PJ',
#   'B083LPT18D',
#   'B08C74ZJDT',
#   'B0959QJFD3',
#   'B098KYLL2B',
#   'B09MD15RMT',
#   'B09TK8H3CD',
#   'B09MYYZ6HC',
#   'B07QS46M6K',
#   'B09DKWYDG6',
#   'B00DEVX0QI',
#   'B0922HF6H4',
#   'B08DCNBR53',
#   'B09DYNVSRM',
#   'B08BL1SWDJ',
#   'B0B12LMNXZ',
#   'B00WKI4MS6',
#   'B09PQS9YJ5',
#   'B09GB8NQ8B',
#   'B07SWL9931',
#   'B07NRW9NF6',
#   'B08ZDDLJFB',
#   'B095CJ9W1D',
#   'B09CTP8P7S',
#   'B083S6SYTJ',
#   'B0B62PY5P8',
#   'B0991WGP7Q',
#   'B0B3ND7K45',
#   'B071CFBXXZ',
#   'B076D5N5JY',
#   'B09DCL6XD6',
#   'B0B1CWPH4M',
#   'B09BYZQY6S',
#   'B08F2DCHKZ',
#   'B08XZK1CH8',
#   'B01J43ILNG',
#   'B07RKWKT6L',
#   'B08PP6BLLK'],
#  'B08PL2S2RP': ['B00336WT3O',
#   'B098QYBMJ8',
#   'B07FK7JFN5',
#   'B0894GHHVT',
#   'B004R2CG5Y',
#   'B07L1554S2'],
#  'B07FK7JFN5': ['B088KL8H4V',
#   'B07FK7JFN5',
#   'B091MFPYSP',
#   'B008PCAOJ2',
#   'B00EX8KVRW',
#   'B07GBSQKL5',
#   'B094MLLB5Z',
#   'B097B3SRLB',
#   'B093XNC8QH',
#   'B0B3MTW12D',
#   'B07BNLF5R1',
#   'B08RFBCR7W'],
#  'B07GBSQKL5': ['B07GBSQKL5',
#   'B08G8MMSPV',
#   'B07YDQTRWB',
#   'B07GBSV9CQ',
#   'B07GBS74KF',
#   'B08G8FSZ8Q',
#   'B092JHDFD6',
#   'B0B93PFPW6',
#   'B08G82XS95',
#   'B08XTB7N13',
#   'B0832D2Q5H',
#   '347332924X',
#   'B09CKPXQ87',
#   'B093GPGTS5',
#   'B098JT7WQ4',
#   'B09YDGBC4W',
#   'B07PV1863W',
#   'B09B2GT37T',
#   'B07LBG4M6B',
#   'B072JT6KYS',
#   'B00IUAJG84',
#   'B06XXGNMHB',
#   'B07ZHH5K8Q',
#   'B01H6JS4IC',
#   'B07KVZ3FSF',
#   'B087LY1M1R',
#   'B01I2GVSNQ',
#   'B09ZP9WC31',
#   'B0021IOTTW',
#   'B0B1887T7W',
#   'B071LND5MW',
#   'B097XRZT69',
#   'B09FP78B6J',
#   'B08FCLMYD4',
#   'B09B2H9218',
#   'B0B1J4ZP4T',
#   'B09BYZG56R',
#   'B09WR3T2Z5',
#   'B002WDTO2I',
#   'B08QN5HRKK',
#   'B0041M3L0Y',
#   'B07B121KBX'],
#  'B09NJP4BNH': ['B091B9WPPZ',
#   'B091B9N8FT',
#   'B0B82M6KVL',
#   'B00JO0CI98',
#   'B015OGFXTM',
#   'B09TZ5K8PS',
#   'B007PZJOQ4'],
#  'B0B82M6KVL': ['B0B82J6F4V',
#   'B09JT679BX',
#   'B09L1FSJ45',
#   'B07WP3PSYL',
#   'B0B3J9KFPQ',
#   'B09V1D5NSG',
#   'B07TV364MZ',
#   'B09P418GFH',
#   'B00NFRTVY6',
#   'B09QKVB8BB',
#   'B08PV1Z94J',
#   'B09WV514CS',
#   'B09BP15S29',
#   'B086KZ1Q72',
#   'B0045XA94K',
#   'B015MZQ7DG',
#   'B00F1DNYPE'],
#  'B09Q2RRKMG': ['B09Q2QMRHG',
#   'B09QS2JBLT',
#   'B09QCR5DNL',
#   'B09MQMW5TD',
#   'B0B14G3X1Y',
#   'B09LHJ29CT',
#   'B09QXDNQQ4',
#   'B09SHZRR51',
#   'B09PTMYXDQ',
#   'B0BG12JB1T',
#   'B08QDHD2RJ',
#   'B09HKX6HRB',
#   'B08Q7DPNJP',
#   'B0B9GYM9FD'],
#  'B09Q2QMRHG': ['B09Q2RRKMG',
#   'B09Q2RKYLM',
#   'B09N3H1MZ5',
#   'B09Q2QMRHG',
#   'B0778NMQYR',
#   'B09PQK2893',
#   'B09WTHK7TC'],
#  'B09N3H1MZ5': ['B0B7JKQSMF',
#   'B0B394B64C',
#   'B09N3H1MZ5',
#   'B09NBXCBCK',
#   'B09NFK9YMT',
#   'B09ND632LG',
#   'B09N92S7TQ',
#   'B09QSMN9TG',
#   'B09NBWFSHL',
#   'B09TT71R2G',
#   'B09WDQTTGL',
#   'B09XX7L78T',
#   'B09MF4LX73',
#   'B09N6NXTZ1',
#   'B0B6HX7RG5',
#   'B09HKX6HRB',
#   'B07PDCPLHK',
#   'B0B7JH1H1M',
#   'B07B2WRNZD',
#   'B09NLX7HXK',
#   'B09NPLKSZ2',
#   'B09NFL37HD',
#   'B09PN5KNHY',
#   'B09YY1C8T9',
#   'B09MTWFCLY',
#   'B09N3QPVT7',
#   'B09MF3QKX1',
#   'B0B214YGK1',
#   'B09S5QWKWW',
#   'B09N3QJ1MC',
#   'B09V2816GH',
#   'B0B394VJMD',
#   'B09N6N1HWP',
#   'B09NPKQ69H'],
#  'B0B7JKQSMF': ['B09N3H1MZ5',
#   'B09NBXCBCK',
#   'B0B394B64C',
#   'B09XW7YCV6',
#   'B09XWCVR5D',
#   'B09TT71R2G',
#   'B09YY1C8T9',
#   'B09NBXFKDN',
#   'B09NFK9YMT',
#   'B09V2816GH',
#   'B09NBWFSHL',
#   'B09NPLJ1WK',
#   'B0B394VJMD',
#   'B09QSMN9TG',
#   'B0B7JH1H1M',
#   'B09N3QPVT7',
#   'B09ND632LG',
#   'B09PV2NYHN'],
#  'B09NBXCBCK': ['B09N3H1MZ5',
#   'B09NPLJ1WK',
#   'B09BCJW7YK',
#   'B09QSNYCJJ',
#   'B09NBXCBCK',
#   'B0B81Z32Y5',
#   'B09QXDNQQ4',
#   'B09NFL37HD',
#   'B09NBXFKDN',
#   'B09XWCVR5D'],
#  'B07BJ297T8': ['B078PDLYB4',
#   'B08745FPZ7',
#   'B07ZLMR35N',
#   'B08P2RG39R',
#   'B07PWD3DVX',
#   'B08DJ58FF7',
#   'B0783BP7BL',
#   'B09JBYP1HS',
#   'B09HNTKT8P',
#   'B08YJC63BT',
#   'B0B748PVK8',
#   'B09TKWT89G',
#   'B097RD3RHN',
#   'B08Z3KW3M4',
#   'B08157CJZM',
#   'B07BJ297T8',
#   'B08ZL6QF8Q',
#   'B09MS66WM6',
#   'B09PDMLCWP',
#   'B08641KML3',
#   'B07FQRT5QH'],
#  'B08DJ58FF7': ['B089GTVMVS',
#   'B08DJ58FF7',
#   'B09TKWT89G',
#   'B09JLQ2MWW',
#   'B07FY57K63',
#   'B01E94O9G8',
#   'B005FI5UM0',
#   'B0B2JVG57D',
#   'B09MWB29XC',
#   'B07X9DNFSW',
#   'B0814RHRSB',
#   'B0B2RPWBNR',
#   'B0B7HZCBR5',
#   'B0772TG6KS',
#   'B0BB9XFP3J',
#   'B097RH5BTL',
#   'B0B2WKBW6X',
#   'B0BBWF1VJB',
#   'B08QCPX22B',
#   'B0B8RNNBRQ',
#   'B07592M8BT',
#   'B09Q2PBWNW',
#   'B07DVGB62J',
#   'B09NQW43SJ',
#   'B09P85SCHV',
#   'B09L78T81M',
#   'B08NDZPLHM',
#   'B0B9XXZ2W1'],
#  'B08LG3163B': ['B08G856CZS',
#   'B08G8GD1B4',
#   'B08LG3163B',
#   'B09H2B2JWK',
#   'B07T9K7DN9',
#   'B08LKG6X8X',
#   'B0995WCF3Q',
#   'B0B886DKRL'],
#  'B08G856CZS': ['B08G8GD1B4',
#   'B08LG3163B',
#   'B08LKG6X8X',
#   'B09T3FY3JD',
#   'B09KN1H685',
#   'B09HK9SR9F'],
#  'B08G8GD1B4': ['B08LKG6X8X', 'B08G856CZS'],
#  'B08LKG6X8X': ['B08LG3163B', 'B08G856CZS', 'B09HK9SR9F'],
#  'B081VKB2RV': ['B09K3Z9524',
#   'B081VKB2RV',
#   'B09JST7X36',
#   'B00MIZ6FKY',
#   'B08GKP4311',
#   'B095HLZYR5',
#   'B0B3RKDM2Q',
#   'B09L4RKLL8',
#   'B07GSDZ71G',
#   'B06ZZWZK9D',
#   'B09TZY6W66',
#   'B09K3Y5QN7'],
#  'B09JST7X36': ['B09JSSY2YG', 'B086WCM8TL', 'B08BCHYT29'],
#  'B09JSSY2YG': ['B09JST7X36'],
#  'B071RMD93K': ['B0716CJ8XH',
#   'B0894FXQ6B',
#   'B09KY1J65M',
#   'B09QWG1JT8',
#   'B08PQKPGMH',
#   'B07FK6WM3W',
#   'B08CVNJDXQ',
#   'B086X5H8M4',
#   'B08319YYJR',
#   'B01ER3SHUK',
#   'B01ER3SJN0',
#   'B07DZPK6YQ',
#   'B09Q5VDH3X',
#   'B01JS9NXE8',
#   'B01E5BS312',
#   'B07F14F3N7',
#   'B07MKTPWGL',
#   'B07PYY2LWG',
#   'B0B1QB98X3',
#   'B08MCJ12ZJ',
#   'B01KHILBSE',
#   'B08HMGVKDN',
#   'B08BZV9XVN',
#   'B072L36BXX'],
#  'B08PQKPGMH': ['B0BC7LX4XW',
#   'B08PQ8YV84',
#   'B08C1C2FS3',
#   'B08KYJVKQW',
#   'B08CMNLCDP',
#   'B0B6PN7JLZ',
#   'B07QBP3XD2',
#   'B08M5SQ9FP',
#   'B09N39G934',
#   'B08HV1D86V',
#   'B0BHSLQZYQ'],
#  'B08C1C2FS3': ['B09F9FQCTG',
#   'B08BZWFTKP',
#   'B08VRYZ5W9',
#   'B07DZBVW9D',
#   'B08C1C2FS3',
#   'B08V5GN1VR',
#   'B093C6MPKG'],
#  ...}

# %%
k = []
v = []

for item in next_item_dict:
    k.append(item)
    v.append(next_item_dict[item])
    
df_next = pd.DataFrame({'item': k, 'next_item': v})
df_next = df_next.explode('next_item').reset_index(drop=True)
df_next
# Out:
#                 item   next_item
# 0         B00X81MA0Q  B07Y1RZMHJ
# 1         B00X81MA0Q  B07G77V6GG
# 2         B00X81MA0Q  B00X81MA0Q
# 3         B00X81MA0Q  B0035FZIBI
# 4         B00X81MA0Q  B00X81MA0Q
# ...              ...         ...
# 12245636  B08F5L1V72  B08F5L1V72
# 12245637  B08F5L1V72  B0995MT4H4
# 12245638  B08PHT7SC7  B08685TJPN
# 12245639  B08LVHF6GG  B08LVPH7CV
# 12245640  B08LVHF6GG  B09PRQHV9F
#
# [12245641 rows x 2 columns]

# %%
next_item_map['B09W9FND7K']
# Out:
# ['B09JSPLN1M', 'B078WW2WN5', 'B07ZF23YBP', 'B09W9FND7K', 'B08PPNZXBC']

# %%
top200 = df_next['next_item'].value_counts().index.tolist()[:200]
top200
# Out:
# ['B07QPV9Z7X',
#  'B09NQGVSPD',
#  'B0BD5MFPMF',
#  'B01NCX3W3O',
#  'B00NTCH52W',
#  'B01N40PO2M',
#  'B0B1MPZWJG',
#  'B08GWS298V',
#  'B09VKWKZ16',
#  'B07XKBLL8F',
#  'B01MXLEVR7',
#  'B07RHT52HX',
#  'B0BD3XQ9RQ',
#  'B0BDML9477',
#  'B07N8QY3YH',
#  'B0BD88WWQ8',
#  'B09VKWL89R',
#  'B088FSHMQ3',
#  'B08CN3G4N9',
#  'B091V2X68B',
#  'B0922JX27X',
#  'B0BDZ16ZG4',
#  'B0B19YG4MB',
#  'B019GNUT0C',
#  'B07S9FXKZQ',
#  'B09D76FT9D',
#  'B001RYNMDA',
#  'B08YKJ17NF',
#  'B00NTCHCU2',
#  'B07WD58H6R',
#  'B09BBX1T4S',
#  'B00CWNMV4G',
#  'B0935DN1BN',
#  'B09QFPZ9B7',
#  'B09HGGV5R5',
#  'B004BIG55Q',
#  'B014I8SSD0',
#  'B0B18DBBFB',
#  'B098B8PFXY',
#  'B0991FVFQJ',
#  'B08GYKNCCP',
#  'B09BTKNGN5',
#  'B08H93ZRK9',
#  'B09QFPYX34',
#  'B09SWS16W6',
#  'B01B8R6PF2',
#  'B08F2NDB39',
#  'B07H27J698',
#  'B0B18CK9DV',
#  'B014I8SIJY',
#  'B0BCQLVFBM',
#  'B0931VRJT5',
#  'B01KNWYGMW',
#  'B07MLFBJG3',
#  'B0B1Q3QML1',
#  'B00HZV9WTM',
#  'B08ZMQT158',
#  'B077B9X3SB',
#  'B0B9B1Y8R5',
#  'B08LSNJQ1N',
#  'B07XXZP2CK',
#  'B07PNL5STG',
#  'B009Q8492W',
#  'B09C7BRP5Y',
#  'B0BFH812PF',
#  'B013ICNQLQ',
#  'B0BFXGM3GY',
#  'B08CB4Q2YT',
#  'B082T6DHB6',
#  'B01BY9RTNQ',
#  'B0BD5NZ6C6',
#  'B09QFN2DYJ',
#  'B071D8THD2',
#  'B0B61MQD58',
#  'B0935JRJ59',
#  'B09TSW3H27',
#  'B0B6QV81SQ',
#  'B09MTWFCLY',
#  'B07PLSDPYN',
#  'B099DP3617',
#  'B01MDQQIKF',
#  'B07WWY33BK',
#  'B00PGT2BWU',
#  'B0BB5VQ1L8',
#  'B08DJ18C85',
#  'B09MGHBDZC',
#  'B08L5TKXW3',
#  'B08H99BPJN',
#  'B07SYYQ374',
#  'B098RJXBTY',
#  'B07TV364MZ',
#  'B08T19F29G',
#  'B092323P8M',
#  'B07QS4NMW6',
#  'B07JG9TFSB',
#  'B00CWNMXQW',
#  'B09BZR9JFG',
#  'B088QY2JR5',
#  'B09Y9JMPBN',
#  'B009SK9CTS',
#  'B009DIQTJQ',
#  'B07PMR72ZG',
#  'B07PMQDWVP',
#  'B07CNRN566',
#  'B09TDL7R7N',
#  'B06Y2B4BFH',
#  'B0B7WVWRR6',
#  'B07P91XMV1',
#  'B0B2Q2VVGP',
#  'B095SJYYV3',
#  'B0BFJGXWDV',
#  'B0B6QWY8Q7',
#  'B07Z66MK6L',
#  'B094NW9YS2',
#  'B09QFJNDQX',
#  'B07JDSHD4Z',
#  'B081S1N1JS',
#  'B07DGMWKK9',
#  'B099K5YT5V',
#  'B089SJRZ42',
#  'B08QDTSQY5',
#  'B08CB4T8HY',
#  'B00GWUSE1O',
#  'B08N6G596X',
#  'B07QDR3JD4',
#  'B0865RL4PH',
#  'B086LBQK8G',
#  'B0B94K673S',
#  'B0B41G4RP7',
#  'B078NPDRHL',
#  'B07CVX3516',
#  'B07PHPXHQS',
#  'B0B5TWNXX4',
#  'B0B6FLPH73',
#  'B07G34JZG2',
#  'B00PGT81AG',
#  'B07SBCZPWL',
#  'B00PGT8304',
#  'B0B8D4CWZ4',
#  'B07T1Y9TWH',
#  'B01BEPNPF6',
#  'B07P95S37K',
#  'B08PKLFM9T',
#  'B07CZ4DLCP',
#  'B07SDFLVKD',
#  'B07TV22X9M',
#  'B07NGVRYWX',
#  'B09QFZ8KCB',
#  'B0BDJ9PJXQ',
#  'B07LGVV9C9',
#  'B094WRT8PD',
#  'B08LSL593L',
#  'B01BKOITTI',
#  'B00552K0GM',
#  'B000H6W2GW',
#  'B0B6QSYFGL',
#  'B00PGT94YI',
#  'B08TV24K42',
#  'B0BFRLFFPR',
#  'B08LVHKSM5',
#  'B006CKZWD2',
#  'B09C6RTP2S',
#  'B0BFD9P93X',
#  'B07C8117SR',
#  'B098B79SJL',
#  'B07XLML2YS',
#  'B072FHHZFH',
#  'B07KWYGTC6',
#  'B06ZZDRCDW',
#  'B008MJ0X3U',
#  'B08FDJ36XW',
#  'B008F8PMUC',
#  'B00E3862DE',
#  'B0B2Q4ZRDW',
#  'B07RTJV6G4',
#  'B0BG3WZ2D3',
#  'B09Y5HH44X',
#  'B06XZH8SKF',
#  'B0BCPD9YYB',
#  'B07CS9D1R6',
#  'B0BFH6D9XB',
#  'B09P4BKWPL',
#  'B08XG8XBJ8',
#  'B081FWVSG8',
#  'B07S829LBX',
#  'B07Z662186',
#  'B00JR76TKW',
#  'B07RN64P2R',
#  'B015RRW2JM',
#  'B00HZV9YE0',
#  'B0BDJM32H4',
#  'B08N36XNTT',
#  'B07T3ZRFL2',
#  'B0BD5QRHV7',
#  'B08J7PQGD7',
#  'B07QQZD49D',
#  'B078NR6ZK3',
#  'B082T6P545',
#  'B0BKPVWQYZ',
#  'B09QLW7HS2']

# %%
df_valid_sess['last_item'] = df_valid_sess['prev_items'].apply(lambda x: str2list(x)[-1])
df_valid_sess['next_item_prediction'] = df_valid_sess['last_item'].map(next_item_map)
df_valid_sess
# Out:
#                                                prev_items   next_item locale  \
# 0       ['B002IJM4DW' 'B006ZZ7OYO' 'B00B81RHGK' 'B002I...  B09J286JSD     ES
# 1                             ['B0BGG3G8KB' 'B0BGG42C62']  B0BGG553DF     DE
# 2                ['B09D3NXCBL' 'B09D3NXCBL' 'B0B7WBCT28']  B0B7VKTZ61     JP
# 3                             ['B08VJJWCR4' 'B00M8VCL2Y']  B07SY9MRWJ     JP
# 4                ['B07DXVRY1C' 'B093K2BHBS' 'B08156Z37H']  B09QXG9HSL     UK
# ...                                                   ...         ...    ...
# 360619                        ['B07TJTQN2F' 'B07TQ8KP4Y']  B07TJTQWR6     DE
# 360620                        ['B08P2N83KV' 'B08QMRWQMF']  B08P2QM1DN     FR
# 360621  ['B08V4Q8VJ1' 'B09M7LCX8P' 'B079QF67S8' 'B007Z...  B01G7G6XDI     ES
# 360622                        ['B09JFJNPRZ' 'B00C6VIA6C']  B07PSL8RBN     JP
# 360623                        ['B0BFVS2KCG' 'B0BD6FLV2R']  B0BGXSMLX1     JP
#
#          last_item                               next_item_prediction
# 0       B0B65L184L                                       [B09J286JSD]
# 1       B0BGG42C62  [B0BGG3G8KB, B0BGG553DF, B0BGG3BS14, B0B24QYW2...
# 2       B0B7WBCT28               [B0B7VKTZ61, B0B48YPVS6, B09NBM7H1L]
# 3       B00M8VCL2Y  [B079QB3DS5, B079PTGNTW, B07J266Z6N, B0BFGDZ1B...
# 4       B08156Z37H  [B07DXVRY1C, B093K2BHBS, B07DXVSR99, B07KGZGWF...
# ...            ...                                                ...
# 360619  B07TQ8KP4Y  [B00CHU8T22, B07TJTQWR6, B07TP46QQY, B07TQ8KP4...
# 360620  B08QMRWQMF  [B08P2N83KV, B08P2QM1DN, B08CZ1F3RH, B01F8TY7I...
# 360621  B007ZY4COE  [B07GTNW9FV, B007ZY4D0W, B0173NA0AG, B01G70GFA...
# 360622  B00C6VIA6C  [B01966X1CC, B00C6VIA6C, B06XNVVD51, B09H2PV7L...
# 360623  B0BD6FLV2R                           [B0BGXMSQHX, B0BFVPNXNN]
#
# [360624 rows x 5 columns]

# %%
df_test_sess['last_item'] = df_test_sess['prev_items'].apply(lambda x: str2list(x)[-1])
df_test_sess['next_item_prediction'] = df_test_sess['last_item'].map(next_item_map)
df_test_sess
# Out:
#                                                prev_items   next_item locale  \
# 0                             ['B08GYKF2BH' 'B08H1H4B7P']  B08C7YCWQK     UK
# 1       ['B01M62IRCV' 'B01M62IRCV' 'B08HLSXQS9' 'B08DS...  B07259BPG2     UK
# 2                ['B0B51PL552' 'B07L559LLY' 'B004X56S5Y']  B004X5AZJ4     UK
# 3                             ['B08Z4BGRFV' 'B09T77T7N9']  B09FPQ6NXB     UK
# 4       ['B07ZYWFFFP' 'B07N9JFGZD' 'B07LCBKPQ2' 'B07LC...  B00B5AN3M6     UK
# ...                                                   ...         ...    ...
# 360621  ['B014R0RUEM' 'B002SWIJ7Y' 'B00QK0KOY6' 'B002S...  B001FMHUNW     JP
# 360622                        ['B0B9JRSDSX' 'B0B9JQBN63']  B07BB5QRTS     JP
# 360623  ['B0B8ND2ZCV' 'B0BHZ6NGR3' 'B0BHZ2GNNR' 'B0B8N...  B09JGFGV3N     UK
# 360624                        ['B09FDV3QDW' 'B09FDV3QDW']  B09TKR9BGM     JP
# 360625           ['B0B6H8GRW8' 'B0B6H8GRW8' 'B0B1HVCYHG']  B0BG8K9XN3     JP
#
#          last_item                               next_item_prediction
# 0       B08H1H4B7P   [B08C7YCWQK, B08GYKF2BH, B09CNP8LSK, B000TRQGN4]
# 1       B0B1LX67RZ  [B0B5QGZHR8, B09XC9DV7G, B09SYM81WM, B07259BPG...
# 2       B004X56S5Y                           [B004X5AZJ4, B09Z3X7DN4]
# 3       B09T77T7N9   [B08GPVCWSK, B098KYLL2B, B09F6DQTH8, B0B6GRK25W]
# 4       B09FY639HT                           [B086C6WYTB, B09QG2SDDL]
# ...            ...                                                ...
# 360621  B002SWIJ7Y               [B00QK0KOY6, B014R0RUEM, B00CW9QXG2]
# 360622  B0B9JQBN63  [B0B9JRSDSX, B0B9JRMZCY, 484707257X, B0BDKLK1Z...
# 360623  B0B8NGDRKZ                           [B0BC888VLM, B0BC8BKBWJ]
# 360624  B09FDV3QDW  [B0B1J5CX4W, B09FDV3QDW, B0B7S525JP, B07Y3GXQJ...
# 360625  B0B1HVCYHG  [B09G9YFHS7, B09NBR2NQK, B0B1HWM5LW, B0B6H8GRW...
#
# [360626 rows x 5 columns]

# %%
preds = []

for _, row in tqdm(df_test_sess.iterrows(), total=len(df_test_sess)):
    pred_orig = row['next_item_prediction']
    pred = pred_orig
    prev_items = str2list(row['prev_items'])
    if type(pred) == float:
        pred = top200[:100]
    else:
        if len(pred_orig) < 100:
            for i in top200:
                if i not in pred_orig and i not in prev_items:
                    pred.append(i)
                if len(pred) >= 100:
                    break
        else:
            pred = pred[:100]
    preds.append(pred)
# Out:
# 100%|██████████| 360626/360626 [00:41<00:00, 8708.18it/s]

# %%
df_test_sess['next_item_prediction'] = preds
df_test_sess
# Out:
#                                                prev_items   next_item locale  \
# 0                             ['B08GYKF2BH' 'B08H1H4B7P']  B08C7YCWQK     UK
# 1       ['B01M62IRCV' 'B01M62IRCV' 'B08HLSXQS9' 'B08DS...  B07259BPG2     UK
# 2                ['B0B51PL552' 'B07L559LLY' 'B004X56S5Y']  B004X5AZJ4     UK
# 3                             ['B08Z4BGRFV' 'B09T77T7N9']  B09FPQ6NXB     UK
# 4       ['B07ZYWFFFP' 'B07N9JFGZD' 'B07LCBKPQ2' 'B07LC...  B00B5AN3M6     UK
# ...                                                   ...         ...    ...
# 360621  ['B014R0RUEM' 'B002SWIJ7Y' 'B00QK0KOY6' 'B002S...  B001FMHUNW     JP
# 360622                        ['B0B9JRSDSX' 'B0B9JQBN63']  B07BB5QRTS     JP
# 360623  ['B0B8ND2ZCV' 'B0BHZ6NGR3' 'B0BHZ2GNNR' 'B0B8N...  B09JGFGV3N     UK
# 360624                        ['B09FDV3QDW' 'B09FDV3QDW']  B09TKR9BGM     JP
# 360625           ['B0B6H8GRW8' 'B0B6H8GRW8' 'B0B1HVCYHG']  B0BG8K9XN3     JP
#
#          last_item                               next_item_prediction
# 0       B08H1H4B7P  [B08C7YCWQK, B08GYKF2BH, B09CNP8LSK, B000TRQGN...
# 1       B0B1LX67RZ  [B0B5QGZHR8, B09XC9DV7G, B09SYM81WM, B07259BPG...
# 2       B004X56S5Y  [B004X5AZJ4, B09Z3X7DN4, B07QPV9Z7X, B09NQGVSP...
# 3       B09T77T7N9  [B08GPVCWSK, B098KYLL2B, B09F6DQTH8, B0B6GRK25...
# 4       B09FY639HT  [B086C6WYTB, B09QG2SDDL, B07QPV9Z7X, B09NQGVSP...
# ...            ...                                                ...
# 360621  B002SWIJ7Y  [B00QK0KOY6, B014R0RUEM, B00CW9QXG2, B07QPV9Z7...
# 360622  B0B9JQBN63  [B0B9JRSDSX, B0B9JRMZCY, 484707257X, B0BDKLK1Z...
# 360623  B0B8NGDRKZ  [B0BC888VLM, B0BC8BKBWJ, B07QPV9Z7X, B09NQGVSP...
# 360624  B09FDV3QDW  [B0B1J5CX4W, B09FDV3QDW, B0B7S525JP, B07Y3GXQJ...
# 360625  B0B1HVCYHG  [B09G9YFHS7, B09NBR2NQK, B0B1HWM5LW, B0B6H8GRW...
#
# [360626 rows x 5 columns]

# %%
preds = []

for _, row in tqdm(df_valid_sess.iterrows(), total=len(df_valid_sess)):
    pred_orig = row['next_item_prediction']
    pred = pred_orig
    prev_items = str2list(row['prev_items'])
    if type(pred) == float:
        pred = top200[:100]
    else:
        if len(pred_orig) < 100:
            for i in top200:
                if i not in pred_orig and i not in prev_items:
                    pred.append(i)
                if len(pred) >= 100:
                    break
        else:
            pred = pred[:100]
    preds.append(pred)
# Out:
# 100%|██████████| 360624/360624 [00:33<00:00, 10893.38it/s]

# %%
df_valid_sess['next_item_prediction'] = preds
df_valid_sess
# Out:
#                                                prev_items   next_item locale  \
# 0       ['B002IJM4DW' 'B006ZZ7OYO' 'B00B81RHGK' 'B002I...  B09J286JSD     ES
# 1                             ['B0BGG3G8KB' 'B0BGG42C62']  B0BGG553DF     DE
# 2                ['B09D3NXCBL' 'B09D3NXCBL' 'B0B7WBCT28']  B0B7VKTZ61     JP
# 3                             ['B08VJJWCR4' 'B00M8VCL2Y']  B07SY9MRWJ     JP
# 4                ['B07DXVRY1C' 'B093K2BHBS' 'B08156Z37H']  B09QXG9HSL     UK
# ...                                                   ...         ...    ...
# 360619                        ['B07TJTQN2F' 'B07TQ8KP4Y']  B07TJTQWR6     DE
# 360620                        ['B08P2N83KV' 'B08QMRWQMF']  B08P2QM1DN     FR
# 360621  ['B08V4Q8VJ1' 'B09M7LCX8P' 'B079QF67S8' 'B007Z...  B01G7G6XDI     ES
# 360622                        ['B09JFJNPRZ' 'B00C6VIA6C']  B07PSL8RBN     JP
# 360623                        ['B0BFVS2KCG' 'B0BD6FLV2R']  B0BGXSMLX1     JP
#
#          last_item                               next_item_prediction
# 0       B0B65L184L  [B09J286JSD, B07QPV9Z7X, B09NQGVSPD, B0BD5MFPM...
# 1       B0BGG42C62  [B0BGG3G8KB, B0BGG553DF, B0BGG3BS14, B0B24QYW2...
# 2       B0B7WBCT28  [B0B7VKTZ61, B0B48YPVS6, B09NBM7H1L, B07QPV9Z7...
# 3       B00M8VCL2Y  [B079QB3DS5, B079PTGNTW, B07J266Z6N, B0BFGDZ1B...
# 4       B08156Z37H  [B07DXVRY1C, B093K2BHBS, B07DXVSR99, B07KGZGWF...
# ...            ...                                                ...
# 360619  B07TQ8KP4Y  [B00CHU8T22, B07TJTQWR6, B07TP46QQY, B07TQ8KP4...
# 360620  B08QMRWQMF  [B08P2N83KV, B08P2QM1DN, B08CZ1F3RH, B01F8TY7I...
# 360621  B007ZY4COE  [B07GTNW9FV, B007ZY4D0W, B0173NA0AG, B01G70GFA...
# 360622  B00C6VIA6C  [B01966X1CC, B00C6VIA6C, B06XNVVD51, B09H2PV7L...
# 360623  B0BD6FLV2R  [B0BGXMSQHX, B0BFVPNXNN, B07QPV9Z7X, B09NQGVSP...
#
# [360624 rows x 5 columns]

# %%
df_valid_sess.iloc[14]
# Out:
# prev_items                                    ['B015SXO11M' 'B013QNUN3Q']
# next_item                                                      B07C6MQJN2
# locale                                                                 DE
# last_item                                                      B013QNUN3Q
# next_item_prediction    [B015SXO11M, B07C6MQJN2, B088VSJMFJ, B07QPV9Z7...
# Name: 14, dtype: object

# %%
# mrr for valid
mrr_valid = []
for i in tqdm(range(len(df_valid_sess))):
    mrr = 0.0
    ground_truth = df_valid_sess.iloc[i]['next_item']
    for i, item in enumerate(df_valid_sess.iloc[i]['next_item_prediction']):
        if item == ground_truth:
            mrr = 1.0 / (i + 1)
            break
    mrr_valid.append(mrr)
mrr_valid = np.array(mrr_valid).mean()
mrr_valid
# Out:
# 100%|██████████| 360624/360624 [00:31<00:00, 11363.23it/s]
# 0.24021385273916246

# %%
# mrr for test
mrr_test = []
for i in tqdm(range(len(df_test_sess))):
    mrr = 0.0
    ground_truth = df_test_sess.iloc[i]['next_item']
    for i, item in enumerate(df_test_sess.iloc[i]['next_item_prediction']):
        if item == ground_truth:
            mrr = 1.0 / (i + 1)
            break
    mrr_test.append(mrr)
mrr_test = np.array(mrr_test).mean()
mrr_test
# Out:
# 100%|██████████| 360626/360626 [00:33<00:00, 10914.50it/s]
# 0.24074462120638251

# %%
df_pred['last_item'] = df_pred['prev_items'].apply(lambda x: str2list(x)[-1])
df_pred['next_item_prediction'] = df_pred['last_item'].map(next_item_map)
df_pred
# Out:
#                                                prev_items locale   last_item  \
# 0       ['B08V12CT4C' 'B08V1KXBQD' 'B01BVG1XJS' 'B09VC...     DE  B099NQFMG7
# 1                ['B00R9R5ND6' 'B00R9RZ9ZS' 'B00R9RZ9ZS']     DE  B00R9RZ9ZS
# 2       ['B07YSRXJD3' 'B07G7Q5N6G' 'B08C9Q7QVK' 'B07G7...     DE  B07G7Q5N6G
# 3       ['B08KQBYV43' '3955350843' '3955350843' '39553...     DE  3955350843
# 4       ['B09FPTCWMC' 'B09FPTQP68' 'B08HMRY8NG' 'B08TB...     DE  B09J945WQR
# ...                                                   ...    ...         ...
# 316966                        ['B077SZ2C3Y' 'B0B14M3VZX']     UK  B0B14M3VZX
# 316967  ['B08KFHDPY9' 'B0851KTSRZ' 'B08KFHDPY9' 'B0851...     UK  B081YDH55K
# 316968  ['B07PY1N81F' 'B07Q1Z8SQN' 'B07PY1N81F' 'B07Q1...     UK  B09HL11V5B
# 316969                        ['B01MCQMORK' 'B09JYZ325W']     UK  B09JYZ325W
# 316970           ['B0B8JX92YJ' 'B09TN4MP6V' 'B0BG2LZQSL']     UK  B0BG2LZQSL
#
#                                      next_item_prediction
# 0       [B099NS1XPG, B099NR3X6D, B08496TCCQ, B09WDSH4C...
# 1       [B004ZXMV4Q, B00R9R5ND6, B095TQTZXY, B08WC5CF5...
# 2       [B08C9Q7QVK, B07G7Q5N6G, B07YSRXJD3, B0B5QNFWJ...
# 3       [395535086X, 3955350843, 3772476953, 395535087...
# 4       [B09J8V18FL, B09J8T6TTH, B09J8SKX9G, B09J8V9RQ...
# ...                                                   ...
# 316966               [B08X9L5RGD, B09Y4HKGKT, B07V5FL8G6]
# 316967  [B0989BHLSY, B09895QPQF, B09CPNS7XV, B09CPP92Q...
# 316968  [B09HKZBNZH, B09HZSRJWW, B09HL141QC, B07PY1NG3...
# 316969  [B08FB464L7, B09C8RQ8NT, B08QTGSCL3, B07L5YWCQ...
# 316970                           [B09XPX59JK, B09TN4MP6V]
#
# [316971 rows x 4 columns]

# %%
preds = []

for _, row in tqdm(df_pred.iterrows(), total=len(df_pred)):
    pred_orig = row['next_item_prediction']
    pred = pred_orig
    prev_items = str2list(row['prev_items'])
    if type(pred) == float:
        pred = top200[:100]
    else:
        if len(pred_orig) < 100:
            for i in top200:
                if i not in pred_orig and i not in prev_items:
                    pred.append(i)
                if len(pred) >= 100:
                    break
        else:
            pred = pred[:100]
    preds.append(pred)
# Out:
# 100%|██████████| 316971/316971 [00:31<00:00, 10034.69it/s]

# %%
df_pred['next_item_prediction'] = preds
df_pred
# Out:
#                                                prev_items locale   last_item  \
# 0       ['B08V12CT4C' 'B08V1KXBQD' 'B01BVG1XJS' 'B09VC...     DE  B099NQFMG7
# 1                ['B00R9R5ND6' 'B00R9RZ9ZS' 'B00R9RZ9ZS']     DE  B00R9RZ9ZS
# 2       ['B07YSRXJD3' 'B07G7Q5N6G' 'B08C9Q7QVK' 'B07G7...     DE  B07G7Q5N6G
# 3       ['B08KQBYV43' '3955350843' '3955350843' '39553...     DE  3955350843
# 4       ['B09FPTCWMC' 'B09FPTQP68' 'B08HMRY8NG' 'B08TB...     DE  B09J945WQR
# ...                                                   ...    ...         ...
# 316966                        ['B077SZ2C3Y' 'B0B14M3VZX']     UK  B0B14M3VZX
# 316967  ['B08KFHDPY9' 'B0851KTSRZ' 'B08KFHDPY9' 'B0851...     UK  B081YDH55K
# 316968  ['B07PY1N81F' 'B07Q1Z8SQN' 'B07PY1N81F' 'B07Q1...     UK  B09HL11V5B
# 316969                        ['B01MCQMORK' 'B09JYZ325W']     UK  B09JYZ325W
# 316970           ['B0B8JX92YJ' 'B09TN4MP6V' 'B0BG2LZQSL']     UK  B0BG2LZQSL
#
#                                      next_item_prediction
# 0       [B099NS1XPG, B099NR3X6D, B08496TCCQ, B09WDSH4C...
# 1       [B004ZXMV4Q, B00R9R5ND6, B095TQTZXY, B08WC5CF5...
# 2       [B08C9Q7QVK, B07G7Q5N6G, B07YSRXJD3, B0B5QNFWJ...
# 3       [395535086X, 3955350843, 3772476953, 395535087...
# 4       [B09J8V18FL, B09J8T6TTH, B09J8SKX9G, B09J8V9RQ...
# ...                                                   ...
# 316966  [B08X9L5RGD, B09Y4HKGKT, B07V5FL8G6, B07QPV9Z7...
# 316967  [B0989BHLSY, B09895QPQF, B09CPNS7XV, B09CPP92Q...
# 316968  [B09HKZBNZH, B09HZSRJWW, B09HL141QC, B07PY1NG3...
# 316969  [B08FB464L7, B09C8RQ8NT, B08QTGSCL3, B07L5YWCQ...
# 316970  [B09XPX59JK, B09TN4MP6V, B07QPV9Z7X, B09NQGVSP...
#
# [316971 rows x 4 columns]

# %%
df_pred['next_item_prediction'].apply(len).describe()
# Out:
# count    316971.0
# mean        100.0
# std           0.0
# min         100.0
# 25%         100.0
# 50%         100.0
# 75%         100.0
# max         100.0
# Name: next_item_prediction, dtype: float64

# %%
df_pred[['locale', 'next_item_prediction']].to_parquet('submission_task1_2.parquet', engine='pyarrow')

# %%
df_my_pred = pd.read_parquet("/root/autodl-tmp/xiaolong/WorkSpace/Amazon-KDDCUP-23/predictions/SASRec_Next/kdd_cup_2023/2023-03-28-01-44-20.parquet")
df_my_pred.head(5)
# Out:
#   locale                               next_item_prediction
# 0     DE  [B0B6BHYW9N, B092D6TVGH, B0B139RW78, B09Z16NCJ...
# 1     DE  [B094P14PNJ, B08R5KGSXJ, B08Z3DG88N, B08PVJNH6...
# 2     DE  [B07Q329STR, B07V6QXGHX, B07JN5LBS7, B09QFWT3G...
# 3     DE  [B077PBQF2X, B07RKWV54M, B07BR4X8L6, B07X43718...
# 4     DE  [B0BGMHNNGQ, B09CXDNFRC, B08WZ2F7K9, B08PT4XZF...

# %%
df_my_pred2 = pd.read_parquet("/root/autodl-tmp/xiaolong/WorkSpace/Amazon-KDDCUP-23/predictions/SASRec2/kdd_cup_2023/2023-03-27-20-06-42.parquet")
df_my_pred2.head(5)
# Out:
#   locale                               next_item_prediction
# 0     DE  [B099NS1XPG, B07LG5T3V9, B099NR3X6D, B086CJF45...
# 1     DE  [B004ZXMV4Q, B095TQTZXY, B07WDK8PPN, B08WC5CF5...
# 2     DE  [B000KSLHNQ, B0BJ7H1822, B0B6MZZ674, B0B5QNFWJ...
# 3     DE  [395535086X, B089K81TDV, B09KNCTB5F, 377247695...
# 4     DE  [B09J8TWRV3, B09J8SKX9G, B089CVQ2FS, B07JGZH51...

# %%
df_my_pred.iloc[123456]
# Out:
# locale                                                                 JP
# next_item_prediction    [B09HKQQBCH, B096ZQNMHH, B07Q73VM9Y, B099K6PP3...
# Name: 123456, dtype: object

# %%
df_my_pred2.iloc[123456]
# Out:
# locale                                                                 JP
# next_item_prediction    [B00A6LHPZ6, B000MU34Y2, B000MU4YKA, B00AXUC3M...
# Name: 123456, dtype: object

# %%
df_my_pred['next_item_prediction'].apply(len).describe()
# Out:
# count    316971.0
# mean        100.0
# std           0.0
# min         100.0
# 25%         100.0
# 50%         100.0
# 75%         100.0
# max         100.0
# Name: next_item_prediction, dtype: float64

# %%
df_pred[['locale', 'next_item_prediction']].iloc[0]['next_item_prediction']
# Out:
# ['B099NS1XPG',
#  'B099NR3X6D',
#  'B08496TCCQ',
#  'B09WDSH4CD',
#  'B07QPV9Z7X',
#  'B09NQGVSPD',
#  'B0BD5MFPMF',
#  'B01NCX3W3O',
#  'B00NTCH52W',
#  'B01N40PO2M',
#  'B0B1MPZWJG',
#  'B08GWS298V',
#  'B09VKWKZ16',
#  'B07XKBLL8F',
#  'B01MXLEVR7',
#  'B07RHT52HX',
#  'B0BD3XQ9RQ',
#  'B0BDML9477',
#  'B07N8QY3YH',
#  'B0BD88WWQ8',
#  'B09VKWL89R',
#  'B088FSHMQ3',
#  'B08CN3G4N9',
#  'B091V2X68B',
#  'B0922JX27X',
#  'B0BDZ16ZG4',
#  'B0B19YG4MB',
#  'B019GNUT0C',
#  'B07S9FXKZQ',
#  'B09D76FT9D',
#  'B001RYNMDA',
#  'B08YKJ17NF',
#  'B00NTCHCU2',
#  'B07WD58H6R',
#  'B09BBX1T4S',
#  'B00CWNMV4G',
#  'B0935DN1BN',
#  'B09QFPZ9B7',
#  'B09HGGV5R5',
#  'B004BIG55Q',
#  'B014I8SSD0',
#  'B0B18DBBFB',
#  'B098B8PFXY',
#  'B0991FVFQJ',
#  'B08GYKNCCP',
#  'B09BTKNGN5',
#  'B08H93ZRK9',
#  'B09QFPYX34',
#  'B09SWS16W6',
#  'B01B8R6PF2',
#  'B08F2NDB39',
#  'B07H27J698',
#  'B0B18CK9DV',
#  'B014I8SIJY',
#  'B0BCQLVFBM',
#  'B0931VRJT5',
#  'B01KNWYGMW',
#  'B07MLFBJG3',
#  'B0B1Q3QML1',
#  'B00HZV9WTM',
#  'B08ZMQT158',
#  'B077B9X3SB',
#  'B0B9B1Y8R5',
#  'B08LSNJQ1N',
#  'B07XXZP2CK',
#  'B07PNL5STG',
#  'B009Q8492W',
#  'B09C7BRP5Y',
#  'B0BFH812PF',
#  'B013ICNQLQ',
#  'B0BFXGM3GY',
#  'B08CB4Q2YT',
#  'B082T6DHB6',
#  'B01BY9RTNQ',
#  'B0BD5NZ6C6',
#  'B09QFN2DYJ',
#  'B071D8THD2',
#  'B0B61MQD58',
#  'B0935JRJ59',
#  'B09TSW3H27',
#  'B0B6QV81SQ',
#  'B09MTWFCLY',
#  'B07PLSDPYN',
#  'B099DP3617',
#  'B01MDQQIKF',
#  'B07WWY33BK',
#  'B00PGT2BWU',
#  'B0BB5VQ1L8',
#  'B08DJ18C85',
#  'B09MGHBDZC',
#  'B08L5TKXW3',
#  'B08H99BPJN',
#  'B07SYYQ374',
#  'B098RJXBTY',
#  'B07TV364MZ',
#  'B08T19F29G',
#  'B092323P8M',
#  'B07QS4NMW6',
#  'B07JG9TFSB',
#  'B00CWNMXQW']

# %%
df_my_pred['next_item_prediction'].iloc[0]
# Out:
# array(['B08L9CZ7BW', 'B095C349SJ', 'B07PHQ22FY', 'B099XL3VS4',
#        'B08X12TS8R', 'B09Z16NCJT', 'B0B2X3LC93', 'B08DY7S8DR',
#        'B08HDCY9VR', 'B0BCGXM4WH', 'B0BGJDSD38', 'B085QYQ112',
#        'B0BDFTFPZ3', 'B088GNP6TB', 'B09F3P3DQD', 'B0851LN8QG',
#        'B0BH8NYPV6', 'B0BL768TBK', 'B08FCZPSH2', 'B07Y22TWNF',
#        '3735880266', 'B08CY2WJFF', 'B0B7R1SVSG', 'B09YPR8BBJ',
#        'B08Q7SX3V6', 'B0BDM9JYGJ', 'B096HSYFL2', 'B0B63D692W',
#        'B07XZF3JFZ', 'B08X18GCYD', 'B0B7CBD6M6', 'B08CS1WFN8',
#        'B08QW43S2L', 'B07CZ4DLCP', 'B09P4B2VS2', 'B08151FJRJ',
#        'B0851MXXR3', 'B09FPV7NF8', 'B00F5UX7EQ', 'B095CSPRRF',
#        'B093SYL61B', 'B09DDDR9WV', 'B0B3264C64', 'B07H2BZ5TP',
#        'B0B9XTSD8Z', 'B08X23BH9M', 'B085QZ2FJT', 'B085QZ6FLD',
#        'B08Q7HL9QV', 'B0B5CYGH1B', 'B0BD5JBWKW', 'B0B6ZPHNHQ',
#        'B07GQNC5KQ', 'B099MWSH7B', 'B00FFTDZTY', '3473491764',
#        'B09NLCC7TD', 'B0BCGV6372', 'B0BHJKVMB4', 'B09P4BKWPL',
#        'B09JCH4D5B', 'B08X16LL57', 'B09JRGQ336', 'B095C2SYR3',
#        'B09C8C651H', 'B09H293ZVB', 'B0B829LLGR', 'B09FPNMXM4',
#        'B0B1JHG2BH', 'B0BCCYXYWP', 'B07XMBR4CC', 'B07CN16KSD',
#        'B0851MXXR2', 'B0BFG4RB8M', 'B095CQSMFV', 'B0BD7MLFH5',
#        'B09SFTDW9W', 'B0B421SKTL', 'B09QH8B75D', 'B099K6PP31',
#        'B093MQKMJ1', 'B093SYKSFZ', 'B0B8291RBN', 'B09JRGQ335',
#        'B07XYX3WNY', 'B07K13Z1Q4', 'B0B7WMRFFJ', 'B0BFB1769F',
#        'B09QH8XMJC', 'B09ZNYZN94', 'B098NZVNLM', 'B00EFP60HI',
#        'B07WX1HLQR', 'B09GW1PY5V', 'B07HGD1ZS9', 'B098Q3CCC6',
#        'B07T3ZRFL2', 'B07WSMF23F', 'B085DZRHJ1', 'B092VQCBRV'],
#       dtype=object)
